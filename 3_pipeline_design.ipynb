# %% [markdown]
# ## 3. 整体流程设计
#
# 本notebook对应[这一篇blog](https://hanqiu92.github.io/blogs/2020/LP_dual_simplex_solver_3_202004/)中的内容，主要包括第一阶段问题（寻找对偶可行基）以及数值稳定性控制手段的实现。
#
# 首先仍然是一些准备工作：导入相关的计算工具包、从文件util_lec_3.py中读取前两个notebook中完成的类。

# %%
import numpy as np
import scipy.sparse as sp
from scipy.sparse import csc_matrix,csr_matrix,coo_matrix
from util_lec_3 import *

# %% [markdown]
# ### 第一阶段问题（寻找对偶可行基）

# %% [markdown]
# 在第一阶段，我们通过求解问题
# $$
#   \begin{aligned}
#     \min \ & c^T x \\
#     s.t. \ & Ax = 0; \\
#            & -I(l \leq -\infty) \leq x \leq I(u \geq \infty). \\
#   \end{aligned}\tag{1}
# $$
#
# 来寻找初始对偶可行基。根据其形式可知，在实现中只需要改变输入$b$,$l$和$u$，然后调用DS迭代步即可。
#
# 此外，我们还需要加入对第一和第二阶段（寻找最优基）求解过程的管理。这里，我先考虑以下简单的逻辑：
# 1. 如果初始基对偶可行，直接进入第二阶段；
# 2. 否则，求解第一阶段问题，然后根据求解结果判断：
#     1. 如果返回的基的状态是对偶可行的，那么继续进入第二阶段；
#     2. 否则，直接退出求解过程并返回“对偶不可行”。
#
# 这一部分逻辑可以直接在此前留出的内部函数_solve中实现。

# %%
class DualSimplexSolverPlus1(DualSimplexSolver):
    '''
    在DualSimplexSolver的基础上加入第一阶段的处理
    '''
    def _solve_phase_one(self,problem,sol,basis):
        '''
        基于原始问题构造第一阶段问题（b' \gets 0, l' \gets -I(l = -\infty), u' \gets I(u = \infty)），
        然后调用DS迭代步求解
        '''
        m,n = problem.m,problem.n
        l_,u_ = np.zeros((m,)),np.zeros((m,))
        l_[problem.bool_lower_unbounded] = -100
        u_[problem.bool_upper_unbounded] = 100
        problemPhase1 = Problem(problem.A,np.zeros((n,)),problem.c,l_,u_)
        problemPhase1,solPhase1,basis = self._refactorize(problemPhase1,sol=None,basis=basis)
        statusPhase1,problemPhase1,solPhase1,basis = self._loop(problemPhase1,solPhase1,basis)
        return statusPhase1,problemPhase1,solPhase1,basis
    
    def _solve_phase_two(self,problem,sol,basis):
        problem,sol,basis = self._refactorize(problem,sol,basis)
        status,problem,sol,basis = self._loop(problem,sol,basis)
        return status,problem,sol,basis

    def _solve(self,problem,sol,basis):
        '''
        加入简单的两阶段处理逻辑
        '''
        infeas_dict,status_str = problem.check_sol_status(sol)
        if infeas_dict['unbnd']: ## 判断基是否对偶可行（sign和上下界一致）
            ## 若对偶不可行，通过第一阶段问题寻找可行基
            print('Enter phase 1.')
            statusPhase1,problemPhase1,solPhase1,basis = self._solve_phase_one(problem,sol,basis)
            ## 用第一阶段所得的基更新原始问题的解
            sol.sign = solPhase1.sign.copy()
            problem,sol,basis = self._refactorize(problem,sol,basis)
            
            ## 对第一阶段结果进行分析
            if statusPhase1 in (SolveStatus.OPT,SolveStatus.PRIMAL_INFEAS):
                ## 再次检查基是否对偶可行（或者存在原始变量无界）
                bool_unbnd = problem.eval_unbnd(sol)
                if np.any(bool_unbnd):
                    ## 对偶不可行，打印当前结果并退出
                    problem.check_sol_status(sol,print_func=print,print_header='phase 1 check ')
                    return SolveStatus.DUAL_INFEAS,problem,sol,basis
                else:
                    ## 找到初始对偶可行基，跳转到第二阶段
                    pass
            else:
                ## 第一阶段求解过程存在问题，打印当前结果并退出
                problem.check_sol_status(sol,print_func=print,print_header='phase 1 check ')
                return SolveStatus.DUAL_INFEAS,problem,sol,basis
             
        ## 求解第二阶段问题
        print('Enter phase 2.')
        status,problem,sol,basis = self._solve_phase_two(problem,sol,basis)
        return status,problem,sol,basis

# %% [markdown]
# 下面，继续通过测试问题来评估上面第一阶段实现的效果。下面的测试函数与前一个notebook中的测试函数的主要区别在于：
# * 去除了（为了保证对偶可行而引入的）虚拟上下界；
# * 加入了更多的参数和求解信息输出以更好地进行比较。

# %%
from util import *
import time
import traceback
import glob
np.set_printoptions(suppress=False,precision=4)

def test(solve_func,max_problem_size=1e20,model_fnames=None,output_fname=None,random_seed=None):
    '''
    测试函数，各参数的定义如下：
    solve_func对应所实现的DS求解流程入口
    problem_size代表最大可容许的问题矩阵A的非零元素个数，用于约束测试问题的难度
    model_fnames对应一个测试问题路径的list，进一步提供了只对部分问题进行测试的选项
    output_fname对应结果输出路径，可输出PuLP和实现的DS流程对各测试问题的求解结果和时间，用于后续数据分析
    random_seed可指定随机种子，用于在存在随机性的求解流程（例如随机扰动）中固定随机项，保证多次调用的结果的稳定性
    '''
    if output_fname is not None:
        ## 打开输出文件并写入表头
        f = open(output_fname,'w+')
        f.write('model name\tsize\ttime solver\tobj solver\ttime pulp\tobj pulp\tobj matched?\n')
    
    if random_seed is None:
        ## 用当前时间作为随机种子
        random_seed = int(time.time())
    print('random seed = {}.'.format(random_seed))
    
    evaluator = Evaluator()
    if model_fnames is None:
        ## 默认读取所有测试问题
        model_fnames = sorted(glob.glob('netlib/*.SIF'))
    for fname in model_fnames:
        model_name = fname.split('/')[-1].split('.')[0]

        ## 读取测试问题
        A_dict,b_dict,sense_dict,c_dict,l_dict,u_dict,m,n,row_key,col_key = read_mps(fname)
        A,b,sense,c,l,u = dicts_to_computable(A_dict,b_dict,sense_dict,c_dict,l_dict,u_dict,m,n)

        ## 根据测试问题大小进行筛选
        if A.nnz < max_problem_size:
            evaluator.reset(A,b,sense,c,l,u)
            size = (A.shape,A.nnz)
            print('\nProblem name: {}, size: ({},{}).'.format(model_name,A.shape,A.nnz))
            
            time_pulp,time_ds,obj_pulp,obj_ds = np.nan,np.nan,np.nan,np.nan
            bool_match = False
            try:
                ## 调用PuLP求解
                tt = time.time()
                print("[----Launch PuLP----]")
                x_pulp,lam_pulp,status_pulp = solve_pulp(A_dict,b_dict,sense_dict,c_dict,l_dict,u_dict,
                                                         m,n,msg=1)
                time_pulp = time.time() - tt

                ## 调用实现的DS流程求解
                np.random.seed(random_seed)
                tt = time.time()
                print("[----Launch Solver----]")
                status_ds,sol_ds,basis_ds = solve_func(A,b,sense,c,l,u)
                x_ds = sol_ds.x
                time_ds = time.time() - tt
                
                ## 比较求解结果
                obj_pulp = evaluator.eval_primal_obj(x_pulp)
                obj_ds = evaluator.eval_primal_obj(x_ds)
                print("[----Begin evaluation----]")
                print(f"PuLP Eval: {evaluator.eval_str(x_pulp)} Status: {status_pulp}.")
                print(f"Solver Eval: {evaluator.eval_str(x_ds)} Status: {status_ds}.")
                print(f"Elapsed time: PuLP = {time_pulp:.3f}, Solver = {time_ds:.3f}.")
                bool_match = np.abs(obj_ds - obj_pulp) <= 1e-4 * np.abs(obj_pulp)
                print(f"Two solvers {'match' if bool_match else 'mismatch'}: "
                      f"PuLP = {obj_pulp:.4e}, Solver = {obj_ds:.4e}.")

            except Exception as e:
                print(repr(e))
                print(traceback.print_exc())
                
            if output_fname is not None:
                ## 输出求解结果
                f.write(f"{model_name}\t{size}\t{time_ds:.3f}\t{obj_ds:.4e}\t"
                        f"{time_pulp:.3f}\t{obj_pulp:.4e}\t{bool_match}\n")

    if output_fname is not None:
        f.close()

# %%
## 进行测试
ds_p = DualSimplexSolverPlus1()
test(ds_p.solve,max_problem_size=1000)
# Out:
# random seed = 1585376904.
#
# Problem name: ADLITTLE, size: ((56, 97),383).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 1.
# 6   Obj Primal -1.8677e+06 Dual -1.8677e+06  Primal Inf 4.4291e+03 (32)
# phase 1 check   Obj Primal -1.8677e+20 Dual -1.8677e+20  Primal Inf 6.7291e+17 (57)  Dual Inf 1.8677e+04 (22)  Con Inf 3.0400e+01 (20)  Bnd err 23
# [----Begin evaluation----]
# PuLP Eval: con inf=2.6769e-05,var inf=0.0000e+00,obj=2.2549e+05. Status: 1.
# Solver Eval: con inf=4.4291e+17,var inf=0.0000e+00,obj=-1.8677e+20. Status: SolveStatus.DUAL_INFEAS.
# Elapsed time: PuLP = 0.109, Solver = 0.015.
# Two solvers mismatch: PuLP = 2.2549e+05, Solver = -1.8677e+20.
#
# Problem name: AFIRO, size: ((27, 32),83).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 1.
# 5   Obj Primal -1.7774e+02 Dual -1.7774e+02  Primal Inf 7.9960e+02 (12)
# phase 1 check   Obj Primal -1.7774e+16 Dual -1.7774e+16  Primal Inf 1.1996e+17 (16)  Dual Inf 1.7774e+00 (4)  Bnd err 4
# [----Begin evaluation----]
# PuLP Eval: con inf=9.5400e-06,var inf=0.0000e+00,obj=-4.6475e+02. Status: 1.
# Solver Eval: con inf=7.9960e+16,var inf=0.0000e+00,obj=-1.7774e+16. Status: SolveStatus.DUAL_INFEAS.
# Elapsed time: PuLP = 0.014, Solver = 0.012.
# Two solvers mismatch: PuLP = -4.6475e+02, Solver = -1.7774e+16.
#
# Problem name: BLEND, size: ((74, 83),491).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 1.
# 19   Obj Primal -2.4542e+03 Dual -2.4542e+03  Primal Inf 1.7801e+03 (34)
# phase 1 check   Obj Primal -2.4542e+17 Dual -2.4542e+17  Primal Inf 3.0801e+17 (47)  Dual Inf 2.4542e+01 (12)  Con Inf 1.2034e+02 (19)  Bnd err 13
# [----Begin evaluation----]
# PuLP Eval: con inf=5.1313e-06,var inf=2.4893e-10,obj=-3.0812e+01. Status: 1.
# Solver Eval: con inf=1.4666e+17,var inf=2.9331e+16,obj=-2.4542e+17. Status: SolveStatus.DUAL_INFEAS.
# Elapsed time: PuLP = 0.018, Solver = 0.018.
# Two solvers mismatch: PuLP = -3.0812e+01, Solver = -2.4542e+17.
#
# Problem name: KB2, size: ((43, 41),286).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 2.
# 67   Obj Primal -1.7499e+03 Dual -1.7499e+03
# [----Begin evaluation----]
# PuLP Eval: con inf=2.1180e-04,var inf=0.0000e+00,obj=-1.7499e+03. Status: 1.
# Solver Eval: con inf=9.7017e-09,var inf=0.0000e+00,obj=-1.7499e+03. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.017, Solver = 0.034.
# Two solvers match: PuLP = -1.7499e+03, Solver = -1.7499e+03.
#
# Problem name: RECIPELP, size: ((91, 180),663).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 2.
# 23   Obj Primal -3.4546e+02 Dual -3.4546e+02  Primal Inf 1.6800e+02 (14)
# [----Begin evaluation----]
# PuLP Eval: con inf=0.0000e+00,var inf=0.0000e+00,obj=-2.6662e+02. Status: 1.
# Solver Eval: con inf=1.2100e+02,var inf=4.7000e+01,obj=-3.4546e+02. Status: SolveStatus.PRIMAL_INFEAS.
# Elapsed time: PuLP = 0.059, Solver = 0.016.
# Two solvers mismatch: PuLP = -2.6662e+02, Solver = -3.4546e+02.
#
# Problem name: SC105, size: ((105, 103),280).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 1.
# 104   Obj Primal 2.5818e-14 Dual 0.0000e+00
# Enter phase 2.
# 131   WARN err pivot size 1.7347e-18.
# 134   WARN err DSE accuracy -3.5418e+21.
# 136   Obj Primal -5.2202e+01 Dual -5.2202e+01  Con Inf 5.0075e+01 (1)
# [----Begin evaluation----]
# PuLP Eval: con inf=1.0630e-04,var inf=0.0000e+00,obj=-5.2202e+01. Status: 1.
# Solver Eval: con inf=3.3247e-12,var inf=6.8019e-14,obj=-5.2202e+01. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.021, Solver = 0.074.
# Two solvers match: PuLP = -5.2202e+01, Solver = -5.2202e+01.
#
# Problem name: SC205, size: ((205, 203),551).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 1.
# 274   Obj Primal 9.1859e-13 Dual 0.0000e+00
# Enter phase 2.
# 282   WARN err pivot size 4.1633e-17.
# 283   WARN err pivot size -9.6927e-33.
# 284   WARN err FTRAN/BTRAN pivot consistency -3.5260e-01.
# 284   WARN err DSE accuracy -9.0613e+49.
# 289   WARN err pivot size -0.0000e+00.
# 291   Obj Primal nan Dual -1.7704e+03  Primal Inf nan (15)  Bnd err 1
# [----Begin evaluation----]
# PuLP Eval: con inf=7.3930e-04,var inf=0.0000e+00,obj=-5.2202e+01. Status: 1.
# Solver Eval: con inf=inf,var inf=nan,obj=nan. Status: SolveStatus.PRIMAL_INFEAS.
# Elapsed time: PuLP = 0.061, Solver = 0.157.
# Two solvers mismatch: PuLP = -5.2202e+01, Solver = nan.
#
# Problem name: SC50A, size: ((50, 48),130).
# [----Launch PuLP----]
# [----Launch Solver----]
# /Users/hanqiu/dual_simplex_solve/util_lec_3.py:515: RuntimeWarning: divide by zero encountered in double_scalars
#   alpha_primal = (-primal_gap - delta_xBI) / xB_grad[idxI]
# /Users/hanqiu/dual_simplex_solve/util_lec_3.py:516: RuntimeWarning: invalid value encountered in multiply
#   sol.x[basis.idxB] += alpha_primal * xB_grad
# /Users/hanqiu/dual_simplex_solve/util_lec_3.py:528: RuntimeWarning: divide by zero encountered in true_divide
#   eta_vec = -xB_grad0 / xB_grad0[idxI]
# /Users/hanqiu/dual_simplex_solve/util_lec_3.py:528: RuntimeWarning: invalid value encountered in true_divide
#   eta_vec = -xB_grad0 / xB_grad0[idxI]
# /Users/hanqiu/dual_simplex_solve/util_lec_3.py:529: RuntimeWarning: divide by zero encountered in double_scalars
#   eta_vec[idxI] += 1 / xB_grad0[idxI]
# /Users/hanqiu/dual_simplex_solve/util_lec_3.py:352: RuntimeWarning: divide by zero encountered in double_scalars
#   betaI = betaI0 / alpha_j / alpha_j
# /Users/hanqiu/dual_simplex_solve/util_lec_3.py:353: RuntimeWarning: invalid value encountered in multiply
#   self.DSE_weights += xB_grad0 * (xB_grad0 * betaI - 2 / alpha_j * tau)
# /Users/hanqiu/dual_simplex_solve/util_lec_3.py:353: RuntimeWarning: divide by zero encountered in double_scalars
#   self.DSE_weights += xB_grad0 * (xB_grad0 * betaI - 2 / alpha_j * tau)
# /Users/hanqiu/dual_simplex_solve/util_lec_3.py:353: RuntimeWarning: invalid value encountered in subtract
#   self.DSE_weights += xB_grad0 * (xB_grad0 * betaI - 2 / alpha_j * tau)
# /Users/hanqiu/dual_simplex_solve/util_lec_3.py:370: RuntimeWarning: invalid value encountered in greater
#   bool_primal_inf = (primal_inf > problem.primal_upper_bound_tol[idxB]) | \
# /Users/hanqiu/dual_simplex_solve/util_lec_3.py:371: RuntimeWarning: invalid value encountered in less
#   (primal_inf < problem.primal_lower_bound_tol[idxB])
# /Users/hanqiu/dual_simplex_solve/util_lec_3.py:379: RuntimeWarning: invalid value encountered in true_divide
#   idxI = np.argmax(np.square(primal_inf)/basis.DSE_weights)
# /Users/hanqiu/dual_simplex_solve/util_lec_3.py:388: RuntimeWarning: invalid value encountered in less
#   idxL_bounded = np.where((sol.sign == VarStatus.AT_LOWER_BOUND.value) & (s_grad < 0))[0] ## 处于下界，要求s>=0
# /Users/hanqiu/dual_simplex_solve/util_lec_3.py:389: RuntimeWarning: invalid value encountered in greater
#   idxU_bounded = np.where((sol.sign == VarStatus.AT_UPPER_BOUND.value) & (s_grad > 0))[0] ## 处于上界，要求s<=0
# /Users/hanqiu/dual_simplex_solve/util_lec_3.py:197: RuntimeWarning: invalid value encountered in greater
#   primal_inf_cnt = np.sum((primal_inf > self.primal_upper_bound_tol) | \
# /Users/hanqiu/dual_simplex_solve/util_lec_3.py:198: RuntimeWarning: invalid value encountered in less
#   (primal_inf < self.primal_lower_bound_tol))
# /Users/hanqiu/dual_simplex_solve/util_lec_3.py:212: RuntimeWarning: invalid value encountered in greater
#   con_inf_cnt = np.sum(np.abs(primal_con_inf) > CON_TOL) + np.sum(np.abs(dual_con_inf) > CON_TOL)
# /Users/hanqiu/dual_simplex_solve/util.py:207: RuntimeWarning: invalid value encountered in greater_equal
#   return ( np.sum(err[(err >= 0) & (self.sense <= 0)]) - \
# /Users/hanqiu/dual_simplex_solve/util.py:208: RuntimeWarning: invalid value encountered in less_equal
#   np.sum(err[(err <= 0) & (self.sense >= 0)]) )
# Enter phase 1.
# 32   Obj Primal -3.9199e-15 Dual 0.0000e+00
# Enter phase 2.
# 54   Obj Primal -6.4575e+01 Dual -6.4575e+01
# [----Begin evaluation----]
# PuLP Eval: con inf=3.7800e-05,var inf=0.0000e+00,obj=-6.4575e+01. Status: 1.
# Solver Eval: con inf=1.3034e-12,var inf=0.0000e+00,obj=-6.4575e+01. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.035, Solver = 0.045.
# Two solvers match: PuLP = -6.4575e+01, Solver = -6.4575e+01.
#
# Problem name: SC50B, size: ((50, 48),118).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 1.
# 18   Obj Primal -3.3729e+01 Dual -3.3729e+01  Primal Inf 3.5185e+02 (9)
# phase 1 check   Obj Primal -3.3729e+15 Dual -3.3729e+15  Primal Inf 5.5185e+16 (11)  Dual Inf 3.3729e-01 (2)  Con Inf 2.5000e+00 (5)  Bnd err 2
# [----Begin evaluation----]
# PuLP Eval: con inf=6.3949e-14,var inf=0.0000e+00,obj=-7.0000e+01. Status: 1.
# Solver Eval: con inf=3.5185e+16,var inf=0.0000e+00,obj=-3.3729e+15. Status: SolveStatus.DUAL_INFEAS.
# Elapsed time: PuLP = 0.045, Solver = 0.018.
# Two solvers mismatch: PuLP = -7.0000e+01, Solver = -3.3729e+15.
#
# Problem name: SCAGR7, size: ((129, 140),420).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 1.
# 9   Obj Primal -6.9126e+05 Dual -6.9126e+05  Primal Inf 5.7911e+03 (61)
# phase 1 check   Obj Primal -6.9126e+19 Dual -6.9126e+19  Primal Inf 1.0091e+18 (115)  Dual Inf 6.9126e+03 (43)  Con Inf 1.8190e+01 (14)  Bnd err 43
# [----Begin evaluation----]
# PuLP Eval: con inf=4.5610e-04,var inf=0.0000e+00,obj=-2.3314e+06. Status: 1.
# Solver Eval: con inf=5.4185e+17,var inf=3.7253e+16,obj=-6.9126e+19. Status: SolveStatus.DUAL_INFEAS.
# Elapsed time: PuLP = 0.032, Solver = 0.015.
# Two solvers mismatch: PuLP = -2.3314e+06, Solver = -6.9126e+19.
#
# Problem name: SHARE2B, size: ((96, 79),694).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 1.
# 24   Obj Primal -4.1200e+03 Dual -4.1200e+03  Primal Inf 7.2765e+03 (48)
# phase 1 check   Obj Primal -4.1200e+17 Dual -4.1200e+17  Primal Inf 8.9765e+17 (65)  Dual Inf 4.1200e+01 (13)  Con Inf 1.6562e+03 (50)  Bnd err 17
# [----Begin evaluation----]
# PuLP Eval: con inf=2.1444e-04,var inf=0.0000e+00,obj=-4.1573e+02. Status: 1.
# Solver Eval: con inf=2.4273e+17,var inf=3.8396e+15,obj=-4.1200e+17. Status: SolveStatus.DUAL_INFEAS.
# Elapsed time: PuLP = 0.021, Solver = 0.023.
# Two solvers mismatch: PuLP = -4.1573e+02, Solver = -4.1200e+17.
#
# Problem name: STOCFOR1, size: ((117, 111),447).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 1.
# 19   Obj Primal -1.7927e+05 Dual -1.7927e+05  Primal Inf 1.9719e+03 (57)
# phase 1 check   Obj Primal -1.7927e+19 Dual -1.7927e+19  Primal Inf 7.6719e+17 (114)  Dual Inf 1.7927e+03 (57)  Con Inf 4.5153e+01 (40)  Bnd err 57
# [----Begin evaluation----]
# PuLP Eval: con inf=6.7603e-04,var inf=0.0000e+00,obj=-4.1132e+04. Status: 1.
# Solver Eval: con inf=1.8918e+17,var inf=4.0055e+15,obj=-1.7927e+19. Status: SolveStatus.DUAL_INFEAS.
# Elapsed time: PuLP = 0.044, Solver = 0.040.
# Two solvers mismatch: PuLP = -4.1132e+04, Solver = -1.7927e+19.
#
# Problem name: VTP-BASE, size: ((198, 203),908).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 1.
# 2   Obj Primal 0.0000e+00 Dual 0.0000e+00
# Enter phase 2.
# 47   WARN err pivot size -0.0000e+00.
# 49   Obj Primal nan Dual 4.7018e+04  Primal Inf nan (41)  Dual Inf 4.0000e+00 (1)
# [----Begin evaluation----]
# PuLP Eval: con inf=2.6682e-03,var inf=0.0000e+00,obj=1.2983e+05. Status: 1.
# Solver Eval: con inf=inf,var inf=nan,obj=nan. Status: SolveStatus.PRIMAL_INFEAS.
# Elapsed time: PuLP = 0.081, Solver = 0.080.
# Two solvers mismatch: PuLP = 1.2983e+05, Solver = nan.

# %% [markdown]
# 上面的求解结果显示，目前实现的两阶段DS过程对于大多数问题并不work。特别地，根据phase 1 check输出结果可以看出，许多测试问题的第一阶段问题并不能被正确求解，导致求解过程过早退出。造成这种现象的一部分（主要）原因是DS迭代过程_loop没有对数值误差进行有效处理；下面，我将实现一些解决方案。

# %% [markdown]
# ### Robust Ratio Test

# %% [markdown]
# 在这一小节中，我将实现robust ratio test。blog中已经介绍了该方法的基本思路，这里简单地回顾一下步骤：
# 1. 计算各列$j$的临界对偶步长$\alpha_j$和区间$[\alpha_j^-,\alpha_j^+]$；
# 2. 用二分法确定对偶步长上界$\alpha_{dual}^+$和对应的列$j^+$；
# 3. 找到所有$\alpha_j$落在区间$[\alpha_{j^+},\alpha_{dual}^+)$中的列$j$，并选择$|\delta s_j|$最大的一个。
#
# 下面是具体的代码实现。

# %%
def ratio_test(problem,sol,basis,s_grad,dual_grad):
    '''
    ratio test. 
    
    输入
    problem,sol,basis: 问题、解和基
    s_grad: s的单位变化量
    dual_grad: 对偶目标的单位变化量（即对偶梯度）
    
    输出
    status: 求解状态
    idxJ: 选择的列在N=L\cup U中的位置
    idxNJ: 选择的列在\{1,\cdots,m\}中的位置
    alpha_dual: 对偶步长
    flip_list: 需要翻转类型的列的list
    check_list: 有可能对偶不可行、需要做shift的列的list
    '''
    idxN,boolN = basis.idxN,basis.boolN

    ## 统计可能会约束对偶步长的对偶变量的下标/列
    idxL_bounded = np.where((sol.sign == VarStatus.AT_LOWER_BOUND.value) & (s_grad < -ZERO_TOL))[0]## 处于下界，要求s>=0
    idxU_bounded = np.where((sol.sign == VarStatus.AT_UPPER_BOUND.value) & (s_grad > ZERO_TOL))[0]## 处于上界，要求s<=0
    idxF = np.where((sol.sign == VarStatus.OTHER.value) & boolN)[0]## free变量，要求s==0
    idxF_bounded = idxF[(np.abs(s_grad[idxF]) > ZERO_TOL)]
    elems_bounded = np.concatenate([idxL_bounded,idxU_bounded,idxF_bounded])

    if len(elems_bounded) == 0:
        ## 没有列可以约束对偶步长，因此对偶步长可以无限大，从而对偶目标无界/原始解不可行
        status,idxJ,idxNJ,alpha_dual,flip_list,check_list = SolveStatus.PRIMAL_INFEAS,-1,-1,0,[],[]
        return status,idxJ,idxNJ,alpha_dual,flip_list,check_list

    ## 针对可能约束对偶步长的列，进一步判断其是否可以做bound flip；如果可行，则进行相关计算
    bool_not_both_bounded = problem.bool_not_both_bounded[elems_bounded]
    s_grad_bounded = s_grad[elems_bounded]
    ## 计算bound filp对对偶梯度的影响
    s_grad_abs_bounded = np.abs(s_grad_bounded)
    dual_grad_delta_flipped = problem.bounds_gap[elems_bounded] * s_grad_abs_bounded
    if (np.sum(dual_grad_delta_flipped) <= dual_grad - DUAL_TOL) and (not np.any(bool_not_both_bounded)):
        ## 如果所有约束列都可以做bound flip，而且flip完对偶的梯度仍是正数，则对偶目标无界/原始解不可行
        status,idxJ,idxNJ,alpha_dual,flip_list,check_list = SolveStatus.PRIMAL_INFEAS,-1,-1,0,[],[]
        return status,idxJ,idxNJ,alpha_dual,flip_list,check_list

    ## step 1: 计算每个约束变量对应bound flip的临界对偶步长
    alpha_dual_allowed = - sol.s[elems_bounded] / s_grad_bounded
    alpha_dual_allowed_ub = alpha_dual_allowed + DUAL_TOL / s_grad_abs_bounded

    ## step 2: 通过二分法确定对偶步长上界alpha_dual_ub和对应的列idxs_pivot_ub
    ## 首先，确定alpha_dual_ub搜索的上界alpha_dual_ub_ub和下界alpha_dual_ub_lb
    idxs_pivot_ub = []
    if np.any(bool_not_both_bounded):
        ## 存在不可flip的列，可以大幅降低搜索上界
        alpha_dual_ub_ub = np.min(alpha_dual_allowed_ub[bool_not_both_bounded])
        ## 找到对应最小步长的不可flip列之前的所有列
        idxs_remain = np.where(alpha_dual_allowed_ub < alpha_dual_ub_ub)[0]
        if len(idxs_remain) == 0:
            ## 如果idxs_remain为空，可以直接确定alpha_dual_ub
            alpha_dual_ub = alpha_dual_ub_lb = alpha_dual_ub_ub
            idxs_pivot_ub = list(np.where(alpha_dual_allowed_ub == alpha_dual_ub)[0])
        elif np.sum(dual_grad_delta_flipped[idxs_remain]) <= dual_grad - DUAL_TOL:
            ## 如果idxs_remain全部flip完对偶的梯度仍是正数，可以直接确定alpha_dual_ub
            alpha_dual_ub = alpha_dual_ub_lb = alpha_dual_ub_ub
            idxs_pivot_ub = list(np.where(alpha_dual_allowed_ub == alpha_dual_ub)[0])
        else:
            ## 否则需要进一步搜索
            alpha_dual_ub_lb = np.min(alpha_dual_allowed_ub)
            alpha_dual_ub_ub = np.max(alpha_dual_allowed_ub[idxs_remain])
    else:
        ## 考虑全部列
        alpha_dual_ub_lb = np.min(alpha_dual_allowed_ub)
        alpha_dual_ub_ub = np.max(alpha_dual_allowed_ub)
        idxs_remain = np.arange(len(elems_bounded),dtype=int)

    if len(idxs_pivot_ub) == 0:
        ## 根据区间[alpha_dual_ub_lb,alpha_dual_ub_ub]做二分查找
        dual_grad_tmp = dual_grad - DUAL_TOL
        alpha_dual_ub = (alpha_dual_ub_lb + alpha_dual_ub_ub) / 2
        while len(idxs_remain) > 2 and dual_grad_tmp >= 0 and (alpha_dual_ub_ub - alpha_dual_ub_lb) > 2 * DUAL_TOL / PIVOT_TOL:
            bool_selected = alpha_dual_allowed_ub[idxs_remain] <= alpha_dual_ub
            if not np.any(bool_selected):
                ## 没有覆盖任何列，直接扩大下界
                alpha_dual_ub_lb = alpha_dual_ub
                alpha_dual_ub = (alpha_dual_ub_lb + alpha_dual_ub_ub) / 2
                continue

            ## 计算dual_grad的变化量
            idxs_selected = idxs_remain[bool_selected]
            delta_dual_grad = np.sum(dual_grad_delta_flipped[idxs_selected])
            if (dual_grad_tmp < delta_dual_grad):
                ## 超过dual_grad，降低上界
                idxs_remain = idxs_selected
                alpha_dual_ub_ub = alpha_dual_ub
            else:
                ## 不超过dual_grad，扩大下界
                dual_grad_tmp -= delta_dual_grad
                idxs_remain = idxs_remain[~bool_selected]
                alpha_dual_ub_lb = alpha_dual_ub
            alpha_dual_ub = (alpha_dual_ub_lb + alpha_dual_ub_ub) / 2

        if len(idxs_remain) > 1:
            ## 如果二分查找留下多个列未处理，很可能是一个小区间[alpha_dual_ub_lb,alpha_dual_ub_ub]中包含多个列，直接排序搜索
            idxs_remain = idxs_remain[np.argsort(alpha_dual_allowed_ub[idxs_remain])]
            delta_dual_grads = np.cumsum(dual_grad_delta_flipped[idxs_remain])
            idx_first_exceeding = int(np.sum(delta_dual_grads <= dual_grad_tmp)) ## 找到首个超过dual_grad的列
            if idx_first_exceeding < len(idxs_remain):
                idxs_pivot_ub = [idxs_remain[idx_first_exceeding]]
            else:
                idxs_pivot_ub = [idxs_remain[-1]]
            alpha_dual_ub = alpha_dual_allowed_ub[idxs_pivot_ub[0]]
        elif len(idxs_remain) == 1:
            ## 如果二分查找后只留下一个列未处理，那么选取该列和对应的对偶步长作为上界
            idxs_pivot_ub = list(idxs_remain)
            alpha_dual_ub = alpha_dual_allowed_ub[idxs_pivot_ub[0]]
        else:
            ## 理论上二分查找后至少有一个列未处理；报错，并当做primal inf退出
            print('error! length of remain idxs = 0.')
            status,idxJ,idxNJ,alpha_dual,flip_list,check_list = SolveStatus.PRIMAL_INFEAS,-1,-1,0,[],[]
            return status,idxJ,idxNJ,alpha_dual,flip_list,check_list

    ## step 3: 根据alpha_dual_ub确定区间，找出所有应考虑的列，并从中选出|s_grad|最大的一个
    alpha_dual_lb = min(alpha_dual_allowed[idxs_pivot_ub])
    idxs_pivot = idxs_pivot_ub
    idxs_selected = np.where((alpha_dual_allowed < alpha_dual_ub) & (alpha_dual_allowed >= alpha_dual_lb))[0]
    if len(idxs_selected) > 0:
        idxs_selected = list(set(list(idxs_selected) + idxs_pivot))
    else:
        idxs_selected = idxs_pivot
    idx_pivot = idxs_selected[np.argmax(s_grad_abs_bounded[idxs_selected])]
    idxNJ = elems_bounded[idx_pivot]
    alpha_dual = alpha_dual_allowed[idx_pivot]

    ## step 4: 进行一些后处理
    if s_grad_abs_bounded[idx_pivot] <= PIVOT_TOL:
        if s_grad_abs_bounded[idx_pivot] <= DUAL_TOL:
            ## pivot size过小，直接进入回滚流程（下面进一步实现）
            status,idxJ,idxNJ,alpha_dual,flip_list,check_list = SolveStatus.ROLLBACK,-1,-1,0,[],[]
            return status,idxJ,idxNJ,alpha_dual,flip_list,check_list

    bool_flip = (alpha_dual_allowed_ub <= alpha_dual)
    flip_list = elems_bounded[bool_flip]
    alpha_dual = max(alpha_dual,ZERO_TOL) ## 扩大对偶步长至某个阈值
    idxJ = np.where(idxN == idxNJ)[0]
    ## 获取需要检查对偶可行性的列
    check_list = elems_bounded[alpha_dual_allowed_ub <= alpha_dual]
    if idxNJ not in check_list:
        check_list = np.array(list(check_list) + [idxNJ])
    return SolveStatus.ONGOING,idxJ,idxNJ,alpha_dual,flip_list,check_list

class DualSimplexSolverPlus2(DualSimplexSolverPlus1):
    '''
    在DualSimplexSolverPlus1的基础上加入robust ratio test
    在这一版中暂时不考虑shift
    '''
    
    def _ratio_test(self,problem,sol,basis,s_grad,dual_grad):
        ## 去除返回值中的check list，以保证_step对_ratio_test调用的返回值是正确的
        return ratio_test(problem,sol,basis,s_grad,dual_grad)[:-1]

# %% [markdown]
# 下面通过测试来看一下robust ratio test的效果。

# %%
ds_p = DualSimplexSolverPlus2()
# test(ds_p.solve,1000)
test(ds_p.solve,10000) ## 扩大问题尺寸，进行更多测试
# Out:
# random seed = 1585377012.
#
# Problem name: ADLITTLE, size: ((56, 97),383).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 1.
# 24   Obj Primal -1.1344e-09 Dual 0.0000e+00
# Enter phase 2.
# 110   Obj Primal 2.2549e+05 Dual 2.2549e+05
# [----Begin evaluation----]
# PuLP Eval: con inf=2.6769e-05,var inf=0.0000e+00,obj=2.2549e+05. Status: 1.
# Solver Eval: con inf=1.5539e-10,var inf=0.0000e+00,obj=2.2549e+05. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.020, Solver = 0.069.
# Two solvers match: PuLP = 2.2549e+05, Solver = 2.2549e+05.
#
# Problem name: AFIRO, size: ((27, 32),83).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 1.
# 11   Obj Primal -1.1369e-14 Dual 0.0000e+00
# Enter phase 2.
# 19   Obj Primal -4.6475e+02 Dual -4.6475e+02
# [----Begin evaluation----]
# PuLP Eval: con inf=9.5400e-06,var inf=0.0000e+00,obj=-4.6475e+02. Status: 1.
# Solver Eval: con inf=1.3500e-13,var inf=0.0000e+00,obj=-4.6475e+02. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.014, Solver = 0.016.
# Two solvers match: PuLP = -4.6475e+02, Solver = -4.6475e+02.
#
# Problem name: AGG, size: ((488, 163),2410).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 1.
# 19   Obj Primal -2.7378e-11 Dual 0.0000e+00
# Enter phase 2.
# 138   Obj Primal -3.5992e+07 Dual -3.5992e+07
# [----Begin evaluation----]
# PuLP Eval: con inf=7.0118e-02,var inf=0.0000e+00,obj=-3.5992e+07. Status: 1.
# Solver Eval: con inf=2.2573e-07,var inf=1.1648e-10,obj=-3.5992e+07. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.042, Solver = 0.086.
# Two solvers match: PuLP = -3.5992e+07, Solver = -3.5992e+07.
#
# Problem name: AGG2, size: ((516, 302),4284).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 1.
# 20   Obj Primal 0.0000e+00 Dual 0.0000e+00
# Enter phase 2.
# 169   Obj Primal -2.0239e+07 Dual -2.0239e+07
# [----Begin evaluation----]
# PuLP Eval: con inf=6.1704e-02,var inf=0.0000e+00,obj=-2.0239e+07. Status: 1.
# Solver Eval: con inf=2.0749e-08,var inf=5.8208e-11,obj=-2.0239e+07. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.070, Solver = 0.112.
# Two solvers match: PuLP = -2.0239e+07, Solver = -2.0239e+07.
#
# Problem name: AGG3, size: ((516, 302),4300).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 1.
# 20   Obj Primal 0.0000e+00 Dual 0.0000e+00
# Enter phase 2.
# 179   Obj Primal 1.0312e+07 Dual 1.0312e+07
# [----Begin evaluation----]
# PuLP Eval: con inf=4.5744e-02,var inf=0.0000e+00,obj=1.0312e+07. Status: 1.
# Solver Eval: con inf=1.4735e-08,var inf=0.0000e+00,obj=1.0312e+07. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.060, Solver = 0.118.
# Two solvers match: PuLP = 1.0312e+07, Solver = 1.0312e+07.
#
# Problem name: BANDM, size: ((305, 472),2494).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 1.
# 354   Obj Primal 1.0993e-12 Dual 0.0000e+00
# Enter phase 2.
# 637   Obj Primal -1.5863e+02 Dual -1.5863e+02
# [----Begin evaluation----]
# PuLP Eval: con inf=9.5659e-05,var inf=0.0000e+00,obj=-1.5863e+02. Status: 1.
# Solver Eval: con inf=7.4034e-10,var inf=7.4650e-13,obj=-1.5863e+02. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.054, Solver = 0.450.
# Two solvers match: PuLP = -1.5863e+02, Solver = -1.5863e+02.
#
# Problem name: BEACONFD, size: ((173, 262),3375).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 2.
# 123   Obj Primal 3.3592e+04 Dual 3.3592e+04
# [----Begin evaluation----]
# PuLP Eval: con inf=4.3903e-11,var inf=0.0000e+00,obj=3.3592e+04. Status: 1.
# Solver Eval: con inf=2.9035e-08,var inf=0.0000e+00,obj=3.3592e+04. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.041, Solver = 0.059.
# Two solvers match: PuLP = 3.3592e+04, Solver = 3.3592e+04.
#
# Problem name: BLEND, size: ((74, 83),491).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 1.
# 54   Obj Primal 5.6913e-13 Dual 0.0000e+00
# Enter phase 2.
# 103   Obj Primal -3.0812e+01 Dual -3.0812e+01
# [----Begin evaluation----]
# PuLP Eval: con inf=5.1313e-06,var inf=2.4893e-10,obj=-3.0812e+01. Status: 1.
# Solver Eval: con inf=4.8240e-11,var inf=1.6582e-12,obj=-3.0812e+01. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.022, Solver = 0.062.
# Two solvers match: PuLP = -3.0812e+01, Solver = -3.0812e+01.
#
# Problem name: BNL1, size: ((643, 1175),5121).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 1.
# 49   Obj Primal 4.4465e-13 Dual 0.0000e+00
# Enter phase 2.
# 750   WARN err DSE accuracy -1.6010e-04.
# 751   WARN err DSE accuracy 1.8013e-04.
# 882   WARN err DSE accuracy -1.0770e-04.
# 884   WARN err DSE accuracy 5.8287e-04.
# 932   WARN err DSE accuracy 1.0454e-04.
# 934   WARN err DSE accuracy -5.1606e-04.
# 937   WARN err DSE accuracy 3.1633e-04.
# 938   WARN err DSE accuracy -7.8370e-04.
# 939   WARN err DSE accuracy 3.4612e-04.
# 944   WARN err DSE accuracy -3.5458e-03.
# 950   WARN err DSE accuracy 6.3763e-03.
# 958   WARN err DSE accuracy -7.7375e-03.
# 959   WARN err DSE accuracy -1.4293e-03.
# 960   WARN err DSE accuracy 1.7127e-03.
# 964   WARN err DSE accuracy 1.7546e-03.
# 966   WARN err DSE accuracy 9.3319e-04.
# 967   WARN err DSE accuracy 9.3312e-04.
# 970   WARN err DSE accuracy -9.7564e-04.
# 986   WARN err DSE accuracy 1.4582e-03.
# 996   WARN err DSE accuracy 2.7776e-02.
# 998   WARN err DSE accuracy -5.0402e-04.
# 1000   Obj Primal 1.9759e+03 Dual 1.9759e+03  Primal Inf 4.6311e+02 (37)
# 1008   WARN err DSE accuracy 2.0693e+02.
# 1009   WARN err DSE accuracy 2.0693e+02.
# 1010   WARN err DSE accuracy 2.8165e+04.
# 1012   WARN err DSE accuracy 2.7777e+00.
# 1023   WARN err DSE accuracy 1.2207e-04.
# 1025   WARN err DSE accuracy 2.4235e-04.
# 1029   WARN err DSE accuracy 1.4581e-03.
# 1057   Obj Primal 1.9776e+03 Dual 1.9776e+03
# [----Begin evaluation----]
# PuLP Eval: con inf=2.6652e-04,var inf=0.0000e+00,obj=1.9776e+03. Status: 1.
# Solver Eval: con inf=3.6513e-08,var inf=7.2897e-10,obj=1.9776e+03. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.114, Solver = 0.753.
# Two solvers match: PuLP = 1.9776e+03, Solver = 1.9776e+03.
#
# Problem name: BOEING1, size: ((351, 473),3574).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 1.
# 2   Obj Primal -4.4791e-13 Dual 0.0000e+00
# Enter phase 2.
# 461   Obj Primal -3.3521e+02 Dual -3.3521e+02
# [----Begin evaluation----]
# PuLP Eval: con inf=1.3845e-04,var inf=0.0000e+00,obj=-3.3521e+02. Status: 1.
# Solver Eval: con inf=3.1929e-09,var inf=1.9228e-11,obj=-3.3521e+02. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.082, Solver = 0.486.
# Two solvers match: PuLP = -3.3521e+02, Solver = -3.3521e+02.
#
# Problem name: BOEING2, size: ((166, 162),1215).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 1.
# 42   Obj Primal 1.0630e-12 Dual 0.0000e+00
# Enter phase 2.
# 170   Obj Primal -3.1502e+02 Dual -3.1502e+02
# [----Begin evaluation----]
# PuLP Eval: con inf=2.0468e-05,var inf=0.0000e+00,obj=-3.1502e+02. Status: 1.
# Solver Eval: con inf=2.1622e-09,var inf=2.0105e-12,obj=-3.1502e+02. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.038, Solver = 0.169.
# Two solvers match: PuLP = -3.1502e+02, Solver = -3.1502e+02.
#
# Problem name: BORE3D, size: ((233, 315),1429).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 2.
# 188   Obj Primal 1.3731e+03 Dual 1.3731e+03
# [----Begin evaluation----]
# PuLP Eval: con inf=3.1757e-04,var inf=0.0000e+00,obj=1.3731e+03. Status: 1.
# Solver Eval: con inf=1.2492e-10,var inf=1.0750e-11,obj=1.3731e+03. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.056, Solver = 0.153.
# Two solvers match: PuLP = 1.3731e+03, Solver = 1.3731e+03.
#
# Problem name: BRANDY, size: ((220, 249),2148).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 2.
# 327   Obj Primal 1.5185e+03 Dual 1.5185e+03
# [----Begin evaluation----]
# PuLP Eval: con inf=1.9453e-04,var inf=0.0000e+00,obj=1.5185e+03. Status: 1.
# Solver Eval: con inf=1.7232e-08,var inf=1.1833e-11,obj=1.5185e+03. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.069, Solver = 0.415.
# Two solvers match: PuLP = 1.5185e+03, Solver = 1.5185e+03.
#
# Problem name: CAPRI, size: ((271, 353),1767).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 1.
# 24   Obj Primal 2.3959e-14 Dual 0.0000e+00
# Enter phase 2.
# 330   Obj Primal 2.6900e+03 Dual 2.6900e+03
# [----Begin evaluation----]
# PuLP Eval: con inf=4.8150e-04,var inf=0.0000e+00,obj=2.6900e+03. Status: 1.
# Solver Eval: con inf=4.4430e-11,var inf=1.5987e-14,obj=2.6900e+03. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.065, Solver = 0.375.
# Two solvers match: PuLP = 2.6900e+03, Solver = 2.6900e+03.
# Problem name: DEGEN2, size: ((444, 534),3978).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 1.
# 116   Obj Primal 1.6904e-12 Dual 0.0000e+00
# Enter phase 2.
# 612   Obj Primal -1.4352e+03 Dual -1.4352e+03
# [----Begin evaluation----]
# PuLP Eval: con inf=1.1102e-16,var inf=0.0000e+00,obj=-1.4352e+03. Status: 1.
# Solver Eval: con inf=9.3961e-12,var inf=3.2416e-12,obj=-1.4352e+03. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.072, Solver = 0.400.
# Two solvers match: PuLP = -1.4352e+03, Solver = -1.4352e+03.
#
# Problem name: E226, size: ((223, 282),2578).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 1.
# 168   Obj Primal -7.0900e-14 Dual 0.0000e+00
# Enter phase 2.
# 371   Obj Primal -1.8752e+01 Dual -1.8752e+01
# [----Begin evaluation----]
# PuLP Eval: con inf=9.3338e-06,var inf=0.0000e+00,obj=-1.8752e+01. Status: 1.
# Solver Eval: con inf=3.0661e-10,var inf=7.0406e-13,obj=-1.8752e+01. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.044, Solver = 0.222.
# Two solvers match: PuLP = -1.8752e+01, Solver = -1.8752e+01.
#
# Problem name: ETAMACRO, size: ((400, 688),2409).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 1.
# 93   Obj Primal -3.1767e-14 Dual 0.0000e+00
# Enter phase 2.
# 413   WARN err DSE accuracy 2.2030e-04.
# 666   WARN err DSE accuracy 1.2670e-02.
# 722   Obj Primal -7.5572e+02 Dual -7.5572e+02
# [----Begin evaluation----]
# PuLP Eval: con inf=6.3500e-05,var inf=0.0000e+00,obj=-7.5572e+02. Status: 1.
# Solver Eval: con inf=8.4325e-09,var inf=1.6038e-10,obj=-7.5572e+02. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.056, Solver = 0.429.
# Two solvers match: PuLP = -7.5572e+02, Solver = -7.5572e+02.
#
# Problem name: FFFFF800, size: ((524, 854),6227).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 2.
# 202   WARN err DSE accuracy -9.8410e-04.
# 264   WARN err DSE accuracy -4.6343e-02.
# 271   WARN err DSE accuracy -3.9785e-02.
# 282   WARN err DSE accuracy -4.5860e-04.
# 285   WARN err DSE accuracy -2.3830e-04.
# 288   WARN err DSE accuracy 1.1673e-02.
# 306   WARN err DSE accuracy 2.9311e-03.
# 325   WARN err DSE accuracy 1.7965e-04.
# 332   WARN err DSE accuracy 1.2696e-04.
# 333   WARN err DSE accuracy -8.0812e-04.
# 334   WARN err DSE accuracy 2.3152e-03.
# 335   WARN err DSE accuracy -1.2164e-03.
# 340   WARN err DSE accuracy 1.6658e+00.
# 341   WARN err DSE accuracy -6.2865e-03.
# 342   WARN err DSE accuracy 7.0155e-04.
# 343   WARN err DSE accuracy -9.7848e-03.
# 344   WARN err DSE accuracy -6.1741e-03.
# 345   WARN err DSE accuracy 2.7753e-03.
# 346   WARN err DSE accuracy 1.3033e-01.
# 347   WARN err DSE accuracy 3.9818e-03.
# 349   WARN err DSE accuracy -1.9220e+00.
# 350   WARN err DSE accuracy -1.0986e-03.
# 351   WARN err DSE accuracy 9.7656e-04.
# 353   WARN err DSE accuracy -1.5749e-03.
# 355   WARN err DSE accuracy 1.7194e-02.
# 356   WARN err DSE accuracy -6.6998e+01.
# 357   WARN err DSE accuracy 2.7935e+00.
# 358   WARN err DSE accuracy 7.0004e-02.
# 359   WARN err DSE accuracy 1.4902e-01.
# 360   WARN err DSE accuracy 5.2150e-04.
# 364   WARN err DSE accuracy 1.7778e-03.
# 377   WARN err DSE accuracy 7.4509e+00.
# 378   WARN err DSE accuracy 1.0301e-03.
# 379   WARN err DSE accuracy -2.0539e+01.
# 380   WARN err DSE accuracy 1.1986e+01.
# 381   WARN err DSE accuracy 3.0162e-03.
# 382   WARN err DSE accuracy -1.0014e-03.
# 384   WARN err DSE accuracy 3.6969e-03.
# 395   WARN err DSE accuracy -3.8520e-01.
# 398   WARN err DSE accuracy 5.6276e-02.
# 408   WARN err DSE accuracy 3.0251e-04.
# 413   WARN err DSE accuracy 1.0276e-03.
# 414   WARN err DSE accuracy 9.3291e-04.
# 416   WARN err DSE accuracy 1.5634e-04.
# 429   WARN err DSE accuracy -9.4762e-04.
# 435   WARN err DSE accuracy -2.0506e-04.
# 451   WARN err DSE accuracy -4.9686e-02.
# 454   WARN err DSE accuracy 2.0377e-04.
# 457   WARN err DSE accuracy 2.7448e-02.
# 458   WARN err DSE accuracy 1.1757e-03.
# 467   WARN err DSE accuracy 1.2278e-01.
# 468   WARN err DSE accuracy 2.5512e-03.
# 486   WARN err DSE accuracy -2.7504e-02.
# 489   WARN err DSE accuracy -6.0512e-02.
# 494   WARN err DSE accuracy -1.6154e-03.
# 496   WARN err DSE accuracy -6.3114e-04.
# 498   WARN err DSE accuracy -1.4027e-03.
# 537   WARN err DSE accuracy -1.5741e-04.
# 554   WARN err DSE accuracy 3.1833e-02.
# 555   WARN err DSE accuracy 3.9887e+00.
# 557   WARN err DSE accuracy 2.8125e-03.
# 562   WARN err DSE accuracy -1.0496e-04.
# 572   WARN err DSE accuracy 3.3997e-02.
# 579   WARN err DSE accuracy -3.7877e+00.
# 580   WARN err DSE accuracy 1.2255e-04.
# 589   WARN err DSE accuracy 1.2504e-03.
# 592   WARN err DSE accuracy 1.9068e-03.
# 594   WARN err DSE accuracy 3.0152e-03.
# 595   WARN err DSE accuracy 9.6772e-04.
# 598   WARN err DSE accuracy -1.1465e-04.
# 605   WARN err DSE accuracy -5.0655e-03.
# 607   WARN err DSE accuracy 1.7542e+01.
# 609   WARN err DSE accuracy 3.8818e+01.
# 613   WARN err DSE accuracy -9.1543e-04.
# 616   WARN err DSE accuracy -3.5176e-03.
# 619   WARN err DSE accuracy 1.5437e+02.
# 629   WARN err DSE accuracy -6.7001e-02.
# 631   WARN err DSE accuracy 6.5716e-01.
# 633   WARN err DSE accuracy 1.4297e-01.
# 635   WARN err DSE accuracy -1.2602e-01.
# 637   WARN err DSE accuracy -1.2601e-01.
# 640   WARN err DSE accuracy 1.1911e-01.
# 641   WARN err DSE accuracy 1.1973e+00.
# 642   WARN err DSE accuracy 1.3908e-02.
# 643   WARN err DSE accuracy 6.0914e-01.
# 644   WARN err DSE accuracy -3.3593e-02.
# 649   WARN err DSE accuracy 1.5004e+02.
# 653   WARN err DSE accuracy 3.7657e-03.
# 660   WARN err DSE accuracy 7.1996e-02.
# 662   WARN err DSE accuracy -1.0932e-01.
# 674   WARN err DSE accuracy 2.3809e-02.
# 687   WARN err DSE accuracy 1.9650e-01.
# 688   WARN err DSE accuracy 4.1943e-03.
# 689   WARN err DSE accuracy -5.0908e-02.
# 695   WARN err DSE accuracy 1.9053e-01.
# 703   WARN err DSE accuracy 2.6026e-01.
# 704   WARN err DSE accuracy 1.0985e+00.
# 705   WARN err DSE accuracy 1.5688e-02.
# 706   WARN err DSE accuracy -2.5066e+02.
# 707   WARN err DSE accuracy 2.8351e-01.
# 709   WARN err DSE accuracy 1.0985e+00.
# 724   WARN err DSE accuracy -5.4546e-02.
# 725   WARN err DSE accuracy -2.7217e-03.
# 726   WARN err DSE accuracy -2.7231e-03.
# 736   WARN err DSE accuracy -2.4507e-02.
# 738   WARN err DSE accuracy -6.7005e-02.
# 740   WARN err DSE accuracy -2.4494e-02.
# 747   WARN err DSE accuracy 1.8074e-02.
# 750   WARN err DSE accuracy 4.4739e-02.
# 753   WARN err DSE accuracy -1.2602e-01.
# 754   WARN err DSE accuracy -6.0603e-03.
# 761   WARN err DSE accuracy 4.0415e-03.
# 763   WARN err DSE accuracy 1.0003e+00.
# 765   WARN err DSE accuracy 2.7294e-04.
# 779   WARN err DSE accuracy 1.4629e-03.
# 788   WARN err DSE accuracy 1.3321e-04.
# 789   WARN err DSE accuracy 1.4049e-04.
# 804   WARN err DSE accuracy -6.1572e-03.
# 805   WARN err DSE accuracy -2.1746e-03.
# 807   WARN err DSE accuracy 2.5512e-03.
# 815   WARN err DSE accuracy 4.9711e-03.
# 816   WARN err DSE accuracy 1.0057e+00.
# 824   WARN err DSE accuracy 2.1242e-02.
# 827   WARN err DSE accuracy -4.3692e+01.
# 837   WARN err DSE accuracy 1.5287e+02.
# 849   WARN err DSE accuracy -2.1756e-03.
# 858   WARN err DSE accuracy 1.0686e-01.
# 864   WARN err DSE accuracy 9.9990e-01.
# 870   WARN err DSE accuracy 5.4764e-01.
# 872   WARN err DSE accuracy 2.7294e-04.
# 873   WARN err DSE accuracy 1.0158e-01.
# 875   WARN err DSE accuracy 1.1457e-02.
# 876   WARN err DSE accuracy 9.9990e-01.
# 881   WARN err DSE accuracy 1.9707e-01.
# 886   WARN err DSE accuracy 9.9990e-01.
# 895   WARN err DSE accuracy 2.0667e+00.
# 901   WARN err DSE accuracy 6.8012e-03.
# 907   WARN err DSE accuracy 3.1068e-01.
# 929   WARN err DSE accuracy 3.8579e-03.
# 938   WARN err DSE accuracy -6.7001e-02.
# 944   WARN err pivot size -9.1756e-06.
# 977   WARN err DSE accuracy 9.8471e-02.
# 978   WARN err DSE accuracy -1.7009e+00.
# 980   WARN err pivot size 9.1756e-06.
# 984   WARN err pivot size 9.1756e-06.
# 987   WARN err DSE accuracy 1.2593e-03.
# 989   Obj Primal 5.5568e+05 Dual 5.5568e+05  Con Inf 9.6355e-03 (54)
# [----Begin evaluation----]
# PuLP Eval: con inf=1.6374e-02,var inf=0.0000e+00,obj=5.5568e+05. Status: 1.
# Solver Eval: con inf=7.7580e-03,var inf=1.3100e-07,obj=5.5568e+05. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.099, Solver = 0.682.
# Two solvers match: PuLP = 5.5568e+05, Solver = 5.5568e+05.
#
# Problem name: FINNIS, size: ((497, 614),2310).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 1.
# 7   Obj Primal 0.0000e+00 Dual 0.0000e+00
# phase 1 check   Obj Primal -2.4346e+05 Dual -2.4345e+05  Primal Inf 6.0000e+16 (113)  Con Inf 4.5927e+00 (4)  Bnd err 6
# [----Begin evaluation----]
# PuLP Eval: con inf=3.7067e-04,var inf=1.0100e-04,obj=1.7279e+05. Status: 1.
# Solver Eval: con inf=8.2158e+04,var inf=0.0000e+00,obj=-2.4346e+05. Status: SolveStatus.DUAL_INFEAS.
# Elapsed time: PuLP = 0.057, Solver = 0.011.
# Two solvers mismatch: PuLP = 1.7279e+05, Solver = -2.4346e+05.
# Problem name: FIT1P, size: ((627, 1677),9868).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 2.
# 916   Obj Primal 9.1464e+03 Dual 9.1464e+03
# [----Begin evaluation----]
# PuLP Eval: con inf=1.9123e-04,var inf=0.0000e+00,obj=9.1464e+03. Status: 1.
# Solver Eval: con inf=3.6994e-08,var inf=0.0000e+00,obj=9.1464e+03. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.185, Solver = 0.965.
# Two solvers match: PuLP = 9.1464e+03, Solver = 9.1464e+03.
#
# Problem name: FORPLAN, size: ((161, 422),4564).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 1.
# 36   Obj Primal -1.9852e-11 Dual 0.0000e+00
# Enter phase 2.
# 275   Obj Primal -6.6422e+02 Dual -6.6422e+02
# [----Begin evaluation----]
# PuLP Eval: con inf=6.0633e-03,var inf=0.0000e+00,obj=-6.6422e+02. Status: 1.
# Solver Eval: con inf=4.9643e-06,var inf=2.4401e-09,obj=-6.6422e+02. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.057, Solver = 0.142.
# Two solvers match: PuLP = -6.6422e+02, Solver = -6.6422e+02.
#
# Problem name: GANGES, size: ((1309, 1681),6912).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 2.
# 1000   Obj Primal -1.1449e+05 Dual -1.1449e+05  Primal Inf 1.0786e+04 (297)
# 1178   WARN err DSE accuracy 1.4570e-04.
# 1349   Obj Primal -1.0959e+05 Dual -1.0959e+05
# [----Begin evaluation----]
# PuLP Eval: con inf=2.1363e-02,var inf=2.3675e-12,obj=-1.0959e+05. Status: 1.
# Solver Eval: con inf=7.0365e-10,var inf=1.5872e-15,obj=-1.0959e+05. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.123, Solver = 0.969.
# Two solvers match: PuLP = -1.0959e+05, Solver = -1.0959e+05.
#
# Problem name: GFRD-PNC, size: ((616, 1092),2377).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 2.
# 574   Obj Primal 6.9022e+06 Dual 6.9022e+06
# [----Begin evaluation----]
# PuLP Eval: con inf=2.0308e-04,var inf=0.0000e+00,obj=6.9022e+06. Status: 1.
# Solver Eval: con inf=4.6920e-09,var inf=2.1487e-11,obj=6.9022e+06. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.067, Solver = 0.311.
# Two solvers match: PuLP = 6.9022e+06, Solver = 6.9022e+06.
#
# Problem name: GROW15, size: ((300, 645),5620).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 2.
# 660   WARN err DSE accuracy -1.0335e-03.
# 719   WARN err DSE accuracy -8.9341e-04.
# 804   WARN err DSE accuracy -9.4099e-04.
# 945   WARN err DSE accuracy -4.3808e-04.
# 1000   Obj Primal -1.0688e+08 Dual -1.0688e+08  Primal Inf 7.1953e+03 (16)
# 1080   WARN err DSE accuracy 6.6654e-03.
# 1103   Obj Primal -1.0687e+08 Dual -1.0687e+08
# [----Begin evaluation----]
# PuLP Eval: con inf=4.9750e-01,var inf=5.0707e-10,obj=-1.0687e+08. Status: 1.
# Solver Eval: con inf=2.4028e-05,var inf=0.0000e+00,obj=-1.0687e+08. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.076, Solver = 1.026.
# Two solvers match: PuLP = -1.0687e+08, Solver = -1.0687e+08.
#
# Problem name: GROW22, size: ((440, 946),8252).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 2.
# 665   WARN err DSE accuracy 2.4996e-01.
# 702   WARN err DSE accuracy 1.2087e-03.
# 724   WARN err DSE accuracy 1.8909e-03.
# 765   WARN err DSE accuracy 9.3679e-04.
# 885   WARN err DSE accuracy 1.2149e-03.
# 1000   Obj Primal -1.6275e+08 Dual -1.6275e+08  Primal Inf 2.3576e+08 (281)  Con Inf 7.7941e-05 (2)
# 1126   WARN err DSE accuracy 2.6882e-03.
# 1132   WARN err DSE accuracy 3.8122e-01.
# 1235   WARN err DSE accuracy 2.6830e-03.
# 1292   WARN err DSE accuracy -7.5668e-03.
# 1308   WARN err DSE accuracy -7.4937e-03.
# 1327   WARN err DSE accuracy -1.8524e-04.
# 1328   WARN err DSE accuracy 9.7367e-04.
# 1329   WARN err DSE accuracy 3.9380e-01.
# 1335   WARN err DSE accuracy -3.4024e-04.
# 1350   WARN err DSE accuracy -4.1020e-04.
# 1377   WARN err DSE accuracy -5.1225e-04.
# 1385   WARN err DSE accuracy -5.1727e-03.
# 1394   WARN err DSE accuracy -9.8233e-03.
# 1406   WARN err DSE accuracy 1.7005e-03.
# 1414   WARN err DSE accuracy -4.8249e-04.
# 1416   WARN err DSE accuracy -1.9983e-04.
# 1423   WARN err DSE accuracy -5.4476e-03.
# 1437   WARN err DSE accuracy 2.3660e-04.
# 1444   WARN err DSE accuracy 2.3113e-04.
# 1461   WARN err DSE accuracy -4.6692e-04.
# 1465   WARN err DSE accuracy -3.8367e-03.
# 1470   WARN err DSE accuracy -9.1533e-04.
# 1475   WARN err DSE accuracy -4.6128e-03.
# 1479   WARN err DSE accuracy -1.3922e-04.
# 1480   WARN err DSE accuracy -1.3734e-04.
# 1484   WARN err DSE accuracy -4.5160e-03.
# 1494   WARN err DSE accuracy -1.3803e-04.
# 1499   WARN err DSE accuracy 2.3446e-04.
# 1506   WARN err DSE accuracy 3.5544e-03.
# 1520   WARN err DSE accuracy -1.3082e-02.
# 1526   WARN err DSE accuracy 6.1388e-02.
# 1530   WARN err DSE accuracy -2.2643e-03.
# 1531   WARN err DSE accuracy -4.9777e-02.
# 1534   WARN err DSE accuracy 1.3499e-02.
# 1539   WARN err DSE accuracy -1.6186e-02.
# 1542   WARN err DSE accuracy -4.4885e-03.
# 1545   WARN err DSE accuracy -5.7493e-04.
# 1552   WARN err DSE accuracy -1.7748e-04.
# 1553   WARN err DSE accuracy -8.5176e-04.
# 1555   WARN err DSE accuracy -1.0088e-02.
# 1556   WARN err DSE accuracy -1.0729e-03.
# 1562   WARN err DSE accuracy 8.2951e-01.
# 1563   WARN err DSE accuracy 6.3403e-04.
# 1565   WARN err DSE accuracy 5.9357e-04.
# 1566   WARN err DSE accuracy 3.0825e-04.
# 1574   WARN err DSE accuracy 4.6548e-01.
# 1576   WARN err DSE accuracy -8.6861e-03.
# 1578   WARN err DSE accuracy 9.6723e-03.
# 1586   WARN err DSE accuracy -3.9725e+01.
# 1587   WARN err DSE accuracy -3.2089e-03.
# 1602   WARN err DSE accuracy 2.7909e-02.
# 1607   WARN err DSE accuracy 1.2777e-03.
# 1611   WARN err DSE accuracy -5.1890e-03.
# 1612   WARN err DSE accuracy 3.6469e-01.
# 1634   WARN err DSE accuracy -1.5978e-01.
# 1635   WARN err DSE accuracy 1.5006e-04.
# 1640   WARN err DSE accuracy 1.9733e-04.
# 1650   WARN err DSE accuracy 4.0609e-03.
# 1653   WARN err DSE accuracy -1.2760e-04.
# 1658   WARN err DSE accuracy -5.1498e-03.
# 1677   WARN err DSE accuracy 4.6657e-04.
# 1681   WARN err DSE accuracy -2.2606e-03.
# 1683   WARN err DSE accuracy -2.8550e-04.
# 1716   WARN err DSE accuracy -1.6007e+00.
# 1721   WARN err DSE accuracy -8.8842e-04.
# 1723   WARN err DSE accuracy -1.0869e-02.
# 1728   WARN err DSE accuracy -7.3047e-03.
# 1747   WARN err DSE accuracy -2.2230e-03.
# 1760   WARN err DSE accuracy -5.2230e-03.
# 1769   WARN err DSE accuracy 1.2843e-03.
# 1771   WARN err DSE accuracy -3.9434e+01.
# 1772   WARN err DSE accuracy -4.1419e-02.
# 1775   WARN err DSE accuracy -3.9364e+01.
# 1777   WARN err DSE accuracy 3.9425e-03.
# 1783   WARN err DSE accuracy -1.4979e-04.
# 1811   WARN err DSE accuracy -8.5858e-02.
# 1823   WARN err DSE accuracy -6.7540e-03.
# 1830   WARN err DSE accuracy -5.1891e-03.
# 1853   WARN err DSE accuracy -5.8527e-03.
# 1858   WARN err DSE accuracy 9.6244e-04.
# 1862   WARN err DSE accuracy -1.4983e-04.
# 1863   WARN err DSE accuracy 1.1937e-03.
# 1871   WARN err DSE accuracy -2.1285e-03.
# 1912   WARN err DSE accuracy -8.6662e-02.
# 1913   WARN err DSE accuracy -1.2354e-01.
# 1917   WARN err DSE accuracy -6.6773e-03.
# 1946   WARN err DSE accuracy -1.1592e-03.
# 2000   Obj Primal -1.6084e+08 Dual -1.6084e+08  Primal Inf 3.4214e+06 (66)  Con Inf 1.5338e-03 (18)
# 2003   WARN err DSE accuracy -3.8736e-04.
# 2011   WARN err DSE accuracy -6.7127e-02.
# 2029   WARN err DSE accuracy -1.6105e-04.
# 2051   WARN err pivot size -3.8224e-06.
# 2053   WARN err DSE accuracy 7.8505e-04.
# 2089   WARN err DSE accuracy 6.1283e-03.
# 2090   WARN err DSE accuracy 1.3608e-04.
# 2093   WARN err DSE accuracy -1.4798e-04.
# 2128   WARN err DSE accuracy 2.5043e-04.
# 2148   WARN err DSE accuracy 3.5161e-03.
# 2268   WARN err DSE accuracy -5.6276e+01.
# 2272   WARN err DSE accuracy 1.3484e-04.
# 2290   WARN err DSE accuracy 1.2822e-04.
# 2387   WARN err DSE accuracy 2.5931e-02.
# 2419   WARN err DSE accuracy -1.2609e-03.
# 2420   WARN err DSE accuracy -3.8379e-04.
# 2435   WARN err DSE accuracy 7.0989e-02.
# 2454   WARN err DSE accuracy 3.8180e-04.
# 2463   WARN err DSE accuracy 2.0598e-04.
# 2472   WARN err DSE accuracy 1.1502e+00.
# 2475   WARN err DSE accuracy 1.4302e-03.
# 2476   WARN err DSE accuracy -2.8353e-01.
# 2477   WARN err DSE accuracy 1.5463e+00.
# 2478   WARN err DSE accuracy 5.7563e-04.
# 2479   WARN err DSE accuracy 1.0121e-03.
# 2480   WARN err DSE accuracy 1.4384e-02.
# 2483   WARN err DSE accuracy 9.1947e-04.
# 2488   WARN err DSE accuracy 1.9865e-02.
# 2489   WARN err DSE accuracy 1.4712e-03.
# 2491   WARN err DSE accuracy 1.5739e-02.
# 2492   WARN err DSE accuracy 1.7359e+02.
# 2493   WARN err DSE accuracy 1.7565e-02.
# 2495   WARN err DSE accuracy 9.0998e-04.
# 2498   WARN err DSE accuracy 7.2372e-03.
# 2501   WARN err DSE accuracy 8.8768e-03.
# 2503   WARN err DSE accuracy 1.4365e-02.
# 2505   WARN err DSE accuracy 2.4820e-02.
# 2510   WARN err DSE accuracy 8.9073e-04.
# 2512   WARN err DSE accuracy 9.0286e-04.
# 2513   WARN err DSE accuracy 3.9549e+01.
# 2516   WARN err DSE accuracy 1.6872e-02.
# 2520   WARN err DSE accuracy 2.0695e-04.
# 2524   WARN err DSE accuracy 1.5667e-02.
# 2527   WARN err DSE accuracy 8.9315e-04.
# 2529   WARN err DSE accuracy 8.4337e-03.
# 2543   WARN err DSE accuracy 2.2724e-02.
# 2544   WARN err DSE accuracy 5.2364e-03.
# 2545   WARN err DSE accuracy 4.0047e-04.
# 2548   WARN err DSE accuracy 1.1871e+00.
# 2550   WARN err DSE accuracy 5.6720e-03.
# 2571   WARN err DSE accuracy 5.6577e-03.
# 2585   WARN err DSE accuracy 1.7892e-04.
# 2586   WARN err DSE accuracy 4.7225e-04.
# 2601   Obj Primal -1.6083e+08 Dual -1.6083e+08  Con Inf 1.5488e-03 (18)
# [----Begin evaluation----]
# PuLP Eval: con inf=8.1263e-01,var inf=1.5203e-09,obj=-1.6083e+08. Status: 1.
# Solver Eval: con inf=1.5362e-03,var inf=0.0000e+00,obj=-1.6083e+08. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.116, Solver = 2.770.
# Two solvers match: PuLP = -1.6083e+08, Solver = -1.6083e+08.
# Problem name: GROW7, size: ((140, 301),2612).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 2.
# 313   Obj Primal -4.7788e+07 Dual -4.7788e+07
# [----Begin evaluation----]
# PuLP Eval: con inf=2.1059e-01,var inf=1.4729e-10,obj=-4.7788e+07. Status: 1.
# Solver Eval: con inf=3.8777e-08,var inf=0.0000e+00,obj=-4.7788e+07. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.045, Solver = 0.277.
# Two solvers match: PuLP = -4.7788e+07, Solver = -4.7788e+07.
#
# Problem name: ISRAEL, size: ((174, 142),2269).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 1.
# 139   Obj Primal 2.8874e-09 Dual 0.0000e+00
# Enter phase 2.
# 323   Obj Primal -8.9664e+05 Dual -8.9664e+05
# [----Begin evaluation----]
# PuLP Eval: con inf=9.6412e-03,var inf=0.0000e+00,obj=-8.9664e+05. Status: 1.
# Solver Eval: con inf=1.4621e-05,var inf=0.0000e+00,obj=-8.9664e+05. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.044, Solver = 0.221.
# Two solvers match: PuLP = -8.9664e+05, Solver = -8.9664e+05.
#
# Problem name: KB2, size: ((43, 41),286).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 2.
# 70   Obj Primal -1.7499e+03 Dual -1.7499e+03
# [----Begin evaluation----]
# PuLP Eval: con inf=2.1180e-04,var inf=0.0000e+00,obj=-1.7499e+03. Status: 1.
# Solver Eval: con inf=1.3796e-08,var inf=0.0000e+00,obj=-1.7499e+03. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.015, Solver = 0.039.
# Two solvers match: PuLP = -1.7499e+03, Solver = -1.7499e+03.
#
# Problem name: KEN-07, size: ((2426, 3602),8404).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 2.
# 1000   Obj Primal -8.5961e+08 Dual -8.5961e+08  Primal Inf 3.2829e+04 (1382)
# 2000   Obj Primal -7.4000e+08 Dual -7.4000e+08  Primal Inf 1.5443e+04 (905)
# 3000   Obj Primal -6.7954e+08 Dual -6.7954e+08  Primal Inf 1.2000e+01 (11)
# 3011   Obj Primal -6.7952e+08 Dual -6.7952e+08
# [----Begin evaluation----]
# PuLP Eval: con inf=0.0000e+00,var inf=0.0000e+00,obj=-6.7952e+08. Status: 1.
# Solver Eval: con inf=3.8725e-12,var inf=1.9540e-13,obj=-6.7952e+08. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.208, Solver = 3.388.
# Two solvers match: PuLP = -6.7952e+08, Solver = -6.7952e+08.
#
# Problem name: LOTFI, size: ((153, 308),1078).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 1.
# 100   Obj Primal 1.4211e-14 Dual 0.0000e+00
# phase 1 check   Obj Primal -5.8000e+01 Dual -5.8855e+01  Primal Inf 1.0000e+16 (33)  Con Inf 1.2546e+02 (1)  Bnd err 1
# [----Begin evaluation----]
# PuLP Eval: con inf=8.8211e-03,var inf=1.9351e-11,obj=-2.5265e+01. Status: 1.
# Solver Eval: con inf=1.9456e+05,var inf=4.4099e+04,obj=-5.8000e+01. Status: SolveStatus.DUAL_INFEAS.
# Elapsed time: PuLP = 0.031, Solver = 0.063.
# Two solvers mismatch: PuLP = -2.5265e+01, Solver = -5.8000e+01.
#
# Problem name: MAROS, size: ((846, 1443),9614).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 1.
# 755   WARN err DSE accuracy 1.5562e-03.
# 979   WARN err DSE accuracy 1.1761e-04.
# 983   WARN err DSE accuracy 6.1479e-04.
# 997   Obj Primal 1.2750e-10 Dual 1.2880e-13
# phase 1 check   Obj Primal -2.1130e+05 Dual -2.1130e+05  Primal Inf 4.0000e+16 (165)  Con Inf 1.9532e-03 (1)  Bnd err 4
# [----Begin evaluation----]
# PuLP Eval: con inf=1.0981e-01,var inf=0.0000e+00,obj=-5.8064e+04. Status: 1.
# Solver Eval: con inf=3.1225e+06,var inf=1.6003e+06,obj=-2.1130e+05. Status: SolveStatus.DUAL_INFEAS.
# Elapsed time: PuLP = 0.166, Solver = 0.958.
# Two solvers mismatch: PuLP = -5.8064e+04, Solver = -2.1130e+05.
#
# Problem name: MODSZK1, size: ((687, 1620),3168).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 1.
# 67   Obj Primal 0.0000e+00 Dual 0.0000e+00
# Enter phase 2.
# 1000   Obj Primal 0.0000e+00 Dual 9.2296e-03  Primal Inf 9.9899e+03 (75)
# 1081   Obj Primal 3.2062e+02 Dual 3.2063e+02
# [----Begin evaluation----]
# PuLP Eval: con inf=1.0172e-01,var inf=1.4893e-12,obj=3.2062e+02. Status: 1.
# Solver Eval: con inf=1.1215e-08,var inf=1.6656e-11,obj=3.2062e+02. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.097, Solver = 0.753.
# Two solvers match: PuLP = 3.2062e+02, Solver = 3.2062e+02.
#
# Problem name: PEROLD, size: ((625, 1376),6018).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 1.
# 128   Obj Primal 9.9606e-15 Dual 0.0000e+00
# Enter phase 2.
# 208   WARN err pivot size 8.1462e-07.
# 210   WARN err DSE accuracy 1.1369e-02.
# 211   WARN err DSE accuracy 1.0006e+00.
# 212   WARN err DSE accuracy 1.3016e-02.
# 220   WARN err pivot size 9.4391e-07.
# 227   WARN err DSE accuracy 6.2500e-02.
# 229   WARN err DSE accuracy 9.6395e-02.
# 230   WARN err DSE accuracy 2.1847e+03.
# 231   WARN err DSE accuracy -6.3430e+00.
# 232   WARN err DSE accuracy 2.2093e+03.
# 233   WARN err DSE accuracy 6.5905e+01.
# 234   WARN err DSE accuracy -3.6410e+02.
# 236   WARN err DSE accuracy 4.2259e+00.
# 237   WARN err DSE accuracy 2.8177e+06.
# 238   WARN err DSE accuracy 3.0134e+01.
# 239   WARN err DSE accuracy 1.0236e+00.
# 240   WARN err DSE accuracy 4.9646e+02.
# 241   WARN err DSE accuracy 1.7576e+02.
# 242   WARN err DSE accuracy 3.4382e+01.
# 243   WARN err DSE accuracy 1.2245e+00.
# 247   WARN err DSE accuracy 3.3464e+00.
# 250   WARN err DSE accuracy 3.1189e+01.
# 280   WARN err DSE accuracy 1.2949e+00.
# 286   WARN err DSE accuracy 2.3353e-03.
# 375   WARN err DSE accuracy 1.0022e+00.
# 471   WARN err DSE accuracy 2.6329e+02.
# 472   WARN err DSE accuracy 1.0018e+00.
# 473   WARN err DSE accuracy 1.0007e+00.
# 508   WARN err DSE accuracy -2.7866e-03.
# 509   WARN err DSE accuracy 6.3658e-04.
# 517   WARN err DSE accuracy 1.2909e-02.
# 518   WARN err DSE accuracy -1.2180e-04.
# 520   WARN err DSE accuracy -1.0431e-04.
# 533   WARN err DSE accuracy -3.5441e-04.
# 536   WARN err DSE accuracy -2.9945e-04.
# 537   WARN err DSE accuracy 3.8815e-04.
# 538   WARN err DSE accuracy -9.8801e-04.
# 539   WARN err DSE accuracy 1.6276e-02.
# 540   WARN err DSE accuracy 3.7651e-03.
# 541   WARN err DSE accuracy 2.1289e-01.
# 542   WARN err DSE accuracy 2.6257e-01.
# 543   WARN err DSE accuracy 1.8701e-01.
# 544   WARN err DSE accuracy 1.8701e-01.
# 546   WARN err DSE accuracy -2.1094e-01.
# 548   WARN err DSE accuracy -9.5410e+00.
# 551   WARN err DSE accuracy 4.9133e-03.
# 554   WARN err DSE accuracy -1.9509e-04.
# 556   WARN err DSE accuracy 3.1961e-01.
# 558   WARN err DSE accuracy 7.2479e-04.
# 560   WARN err DSE accuracy 3.9902e-03.
# 561   WARN err DSE accuracy -2.3254e-02.
# 562   WARN err DSE accuracy 6.4636e-02.
# 563   WARN err DSE accuracy -3.2471e-02.
# 564   WARN err DSE accuracy -2.5293e-01.
# 565   WARN err DSE accuracy -1.3599e-01.
# 567   WARN err DSE accuracy 1.2451e-01.
# 568   WARN err DSE accuracy -1.3324e+01.
# 570   WARN err DSE accuracy 5.7031e-01.
# 572   WARN err DSE accuracy -4.4873e+00.
# 574   WARN err DSE accuracy -1.5634e-04.
# 575   WARN err DSE accuracy -2.9243e-02.
# 586   WARN err DSE accuracy 6.5734e-03.
# 601   WARN err DSE accuracy 1.6376e-01.
# 615   WARN err DSE accuracy 9.2070e-04.
# 621   WARN err DSE accuracy -1.7946e-04.
# 639   WARN err DSE accuracy 8.8193e-04.
# 642   WARN err DSE accuracy 1.4571e-02.
# 644   WARN err DSE accuracy -2.4745e-01.
# 654   WARN err DSE accuracy 1.9962e-04.
# 655   WARN err DSE accuracy 1.7222e-04.
# 657   WARN err DSE accuracy 1.7222e-04.
# 661   WARN err DSE accuracy 1.0882e+00.
# 666   WARN err DSE accuracy 5.1711e-03.
# 667   WARN err DSE accuracy 5.1711e-03.
# 671   WARN err DSE accuracy 3.2263e-04.
# 672   WARN err DSE accuracy -1.7674e-03.
# 681   WARN err DSE accuracy -1.9661e+05.
# 682   WARN err DSE accuracy -8.9865e+02.
# 683   WARN err DSE accuracy 2.5940e-04.
# 691   WARN err DSE accuracy 1.1088e+02.
# 694   WARN err DSE accuracy -1.8530e-02.
# 695   WARN err DSE accuracy 1.8582e-03.
# 696   WARN err DSE accuracy 7.5459e-03.
# 698   WARN err DSE accuracy 5.0535e-03.
# 702   WARN err DSE accuracy 1.2229e-01.
# 730   WARN err DSE accuracy -3.0851e-04.
# 731   WARN err DSE accuracy -6.4900e+02.
# 746   WARN err DSE accuracy 1.3115e-04.
# 782   WARN err DSE accuracy 1.2548e-01.
# 787   WARN err DSE accuracy 1.2713e-03.
# 792   WARN err DSE accuracy -5.1378e-04.
# 819   WARN err DSE accuracy 1.4030e-03.
# 826   WARN err DSE accuracy -5.5020e+00.
# 852   WARN err DSE accuracy 1.6750e-03.
# 855   WARN err DSE accuracy 1.0835e-04.
# 861   WARN err DSE accuracy 1.9718e-04.
# 863   WARN err DSE accuracy 1.8543e-04.
# 864   WARN err DSE accuracy 1.7115e-04.
# 866   WARN err DSE accuracy 2.1266e-04.
# 869   WARN err DSE accuracy 1.6568e-04.
# 875   WARN err DSE accuracy -2.8132e-01.
# 877   WARN err DSE accuracy 6.8855e-04.
# 879   WARN err DSE accuracy 1.5168e+01.
# 882   WARN err DSE accuracy 1.4460e+07.
# 883   WARN err DSE accuracy 1.0248e+08.
# 884   WARN err DSE accuracy 8.0955e+06.
# 885   WARN err DSE accuracy 3.7017e+03.
# 886   WARN err DSE accuracy 5.6043e+00.
# 887   WARN err DSE accuracy -3.3695e-04.
# 888   WARN err DSE accuracy 1.1315e+00.
# 889   WARN err DSE accuracy 2.1979e+08.
# 890   WARN err DSE accuracy 1.0189e+01.
# 892   WARN err DSE accuracy 1.4789e+05.
# 893   WARN err DSE accuracy 1.3566e+04.
# 894   WARN err DSE accuracy 2.6488e+01.
# 896   WARN err DSE accuracy -4.6243e-01.
# 897   WARN err DSE accuracy 1.4715e+01.
# 898   WARN err DSE accuracy -5.5183e-02.
# 899   WARN err DSE accuracy -4.3338e-03.
# 906   WARN err DSE accuracy -1.3069e-04.
# 907   WARN err DSE accuracy 5.7327e-02.
# 909   WARN err DSE accuracy 2.2514e-04.
# 910   WARN err DSE accuracy -5.2540e-01.
# 911   WARN err DSE accuracy -5.1383e-04.
# 919   WARN err DSE accuracy 1.2835e+00.
# 936   WARN err DSE accuracy -3.3240e-01.
# 939   WARN err DSE accuracy -1.9099e-03.
# 943   WARN err DSE accuracy -2.1094e-04.
# 948   WARN err DSE accuracy 2.5216e+01.
# 949   WARN err DSE accuracy 1.2908e+02.
# 951   WARN err DSE accuracy 3.7648e-02.
# 961   WARN err DSE accuracy -8.1119e+01.
# 962   WARN err DSE accuracy -9.0493e-02.
# 965   WARN err DSE accuracy -1.9073e-04.
# 970   WARN err DSE accuracy 1.8094e-04.
# 972   WARN err DSE accuracy 2.7849e-01.
# 975   WARN err DSE accuracy 1.0120e-04.
# 983   WARN err DSE accuracy 1.4363e-02.
# 986   WARN err DSE accuracy -2.0222e-01.
# 990   WARN err DSE accuracy -5.0349e-01.
# 997   WARN err DSE accuracy -1.6742e-01.
# 999   WARN err DSE accuracy -5.1226e-01.
# 1000   Obj Primal -9.8970e+03 Dual -9.8970e+03  Primal Inf 7.9663e+05 (167)  Con Inf 7.4416e-03 (22)
# 1001   WARN err DSE accuracy 1.3716e+00.
# 1006   WARN err DSE accuracy -7.0762e-03.
# 1007   WARN err DSE accuracy -2.7004e+00.
# 1008   WARN err DSE accuracy 1.3407e+02.
# 1010   WARN err DSE accuracy -5.6677e-03.
# 1011   WARN err DSE accuracy 8.4971e+01.
# 1012   WARN err DSE accuracy 1.9606e-01.
# 1013   WARN err DSE accuracy 2.1486e-04.
# 1014   WARN err DSE accuracy 2.1400e+00.
# 1018   WARN err DSE accuracy 2.2169e+01.
# 1045   WARN err DSE accuracy -2.5044e-03.
# 1046   WARN err DSE accuracy -1.6398e-02.
# 1048   WARN err DSE accuracy 7.7268e-01.
# 1050   WARN err DSE accuracy -9.9068e+00.
# 1057   WARN err DSE accuracy 5.4474e-03.
# 1061   WARN err DSE accuracy -9.1624e-04.
# 1068   WARN err DSE accuracy -1.8852e+05.
# 1070   WARN err DSE accuracy 5.2246e-03.
# 1075   WARN err DSE accuracy -3.2373e-04.
# 1082   WARN err DSE accuracy -1.2971e-04.
# 1093   WARN err DSE accuracy -1.7772e-03.
# 1101   WARN err DSE accuracy 2.4995e-01.
# 1102   WARN err DSE accuracy -3.0584e-01.
# 1106   WARN err DSE accuracy -2.9097e-03.
# 1124   WARN err DSE accuracy -1.7685e-02.
# 1128   WARN err DSE accuracy -1.7092e-04.
# 1137   WARN err DSE accuracy 4.7990e-04.
# 1139   WARN err DSE accuracy -2.6907e-03.
# 1158   WARN err DSE accuracy 5.2246e-03.
# 1165   WARN err DSE accuracy -1.4188e-02.
# 1167   WARN err FTRAN/BTRAN pivot consistency 7.1540e-07.
# 1167   WARN err pivot size -0.0000e+00.
# 1170   Obj Primal nan Dual -9.7463e+03  Con Inf nan (1)
# [----Begin evaluation----]
# PuLP Eval: con inf=2.5395e-01,var inf=2.9490e-03,obj=-9.3808e+03. Status: 1.
# Solver Eval: con inf=1.8462e-04,var inf=nan,obj=nan. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.263, Solver = 1.231.
# Two solvers mismatch: PuLP = -9.3808e+03, Solver = nan.
#
# Problem name: PILOT-WE, size: ((722, 2789),9126).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 1.
# 286   Obj Primal -1.3147e-07 Dual 0.0000e+00
# Enter phase 2.
# 535   WARN err DSE accuracy -2.9373e-04.
# 537   WARN err DSE accuracy -7.7248e-04.
# 686   WARN err DSE accuracy 2.7907e-04.
# 698   WARN err DSE accuracy 1.0700e-03.
# 699   WARN err DSE accuracy -1.1067e-03.
# 711   WARN err DSE accuracy -4.1574e-04.
# 712   WARN err DSE accuracy 2.2467e-03.
# 718   WARN err DSE accuracy 1.2827e-04.
# 756   WARN err DSE accuracy 3.3411e-01.
# 766   WARN err DSE accuracy 3.3437e-01.
# 768   WARN err DSE accuracy 2.8992e-04.
# 835   WARN err DSE accuracy -3.0041e-04.
# 836   WARN err DSE accuracy 3.9566e-04.
# 838   WARN err DSE accuracy 3.6812e-04.
# 839   WARN err DSE accuracy -6.0234e-03.
# 858   WARN err DSE accuracy -2.0104e-03.
# 859   WARN err DSE accuracy -9.5243e-04.
# 893   WARN err DSE accuracy 1.9702e-04.
# 894   WARN err DSE accuracy 7.2289e-04.
# 895   WARN err pivot size 4.5767e-06.
# 896   WARN err DSE accuracy -3.0520e+03.
# 897   WARN err DSE accuracy 5.5040e+03.
# 908   WARN err DSE accuracy -1.2732e-04.
# 943   WARN err DSE accuracy 1.5402e-04.
# 945   WARN err DSE accuracy 1.3185e-04.
# 946   WARN err DSE accuracy -1.2849e-02.
# 947   WARN err DSE accuracy 9.6321e-04.
# 975   WARN err DSE accuracy 1.5581e-04.
# 976   WARN err DSE accuracy 6.0129e-04.
# 977   WARN err DSE accuracy -4.1962e-04.
# 978   WARN err DSE accuracy -1.4348e-02.
# 980   WARN err DSE accuracy -1.4890e-04.
# 981   WARN err DSE accuracy 3.8825e-04.
# 982   WARN err DSE accuracy -1.3470e-03.
# 1000   Obj Primal -6.9223e+06 Dual -6.9223e+06  Primal Inf 1.8634e+07 (221)  Con Inf 5.3128e-03 (10)
# 1070   WARN err DSE accuracy -4.8061e+04.
# 1071   WARN err DSE accuracy -1.3148e-03.
# 1072   WARN err DSE accuracy -9.0390e-04.
# 1095   WARN err DSE accuracy 1.5759e-04.
# 1096   WARN err DSE accuracy -2.0504e-04.
# 1097   WARN err DSE accuracy 6.9332e-04.
# 1100   WARN err DSE accuracy 1.0312e-04.
# 1109   WARN err DSE accuracy -1.6253e-02.
# 1111   WARN err DSE accuracy -9.1675e-03.
# 1113   WARN err DSE accuracy -4.4553e-04.
# 1114   WARN err DSE accuracy -3.4094e-02.
# 1115   WARN err DSE accuracy -2.7418e-04.
# 1116   WARN err DSE accuracy 1.1320e-03.
# 1117   WARN err DSE accuracy -4.8286e-04.
# 1135   WARN err DSE accuracy 1.7005e-02.
# 1142   WARN err DSE accuracy -1.8613e-04.
# 1145   WARN err DSE accuracy 2.7439e-04.
# 1147   WARN err DSE accuracy 3.4809e-04.
# 1149   WARN err DSE accuracy 1.4615e-04.
# 1151   WARN err DSE accuracy -1.4171e+01.
# 1155   WARN err DSE accuracy -4.9744e-03.
# 1198   WARN err DSE accuracy 3.2806e-04.
# 1203   WARN err DSE accuracy 4.3488e-04.
# 1206   WARN err DSE accuracy -9.9945e-04.
# 1207   WARN err DSE accuracy 7.3242e-04.
# 1208   WARN err DSE accuracy 9.1171e-04.
# 1209   WARN err DSE accuracy 2.1477e-03.
# 1210   WARN err DSE accuracy 5.7983e-04.
# 1211   WARN err DSE accuracy 4.8904e-03.
# 1212   WARN err DSE accuracy -1.2512e-03.
# 1213   WARN err DSE accuracy -3.3691e-02.
# 1230   WARN err DSE accuracy -2.9460e-01.
# 1231   WARN err DSE accuracy -1.3717e-01.
# 1244   WARN err DSE accuracy -3.3844e-02.
# 1245   WARN err DSE accuracy 1.7479e-01.
# 1246   WARN err DSE accuracy 1.3468e-01.
# 1248   WARN err DSE accuracy 2.6298e-04.
# 1250   WARN err DSE accuracy -2.4074e-04.
# 1262   WARN err DSE accuracy -2.6695e-04.
# 1263   WARN err DSE accuracy 2.6503e-03.
# 1265   WARN err DSE accuracy -1.8487e-04.
# 1266   WARN err DSE accuracy -1.7288e-04.
# 1267   WARN err DSE accuracy 8.5135e-03.
# 1268   WARN err DSE accuracy 1.7618e-02.
# 1269   WARN err DSE accuracy -2.0420e-04.
# 1272   WARN err DSE accuracy 1.9123e-04.
# 1273   WARN err DSE accuracy -5.5586e-04.
# 1275   WARN err DSE accuracy -8.6081e-04.
# 1276   WARN err DSE accuracy 3.9009e-01.
# 1278   WARN err DSE accuracy 7.0068e-02.
# 1282   WARN err DSE accuracy -1.1970e-04.
# 1307   WARN err DSE accuracy 1.1323e-03.
# 1354   WARN err DSE accuracy 3.4833e-01.
# 1363   WARN err DSE accuracy 4.9973e-03.
# 1364   WARN err DSE accuracy -3.0289e-03.
# 1365   WARN err DSE accuracy 1.6174e-03.
# 1366   WARN err DSE accuracy -1.5121e-02.
# 1367   WARN err DSE accuracy -3.3875e-03.
# 1368   WARN err DSE accuracy -2.6020e-02.
# 1369   WARN err DSE accuracy -6.4139e-03.
# 1370   WARN err DSE accuracy -8.4962e-02.
# 1371   WARN err DSE accuracy 1.0245e-01.
# 1373   WARN err DSE accuracy -1.5251e-03.
# 1375   WARN err DSE accuracy 7.1742e-04.
# 1378   WARN err DSE accuracy -4.9258e+00.
# 1399   WARN err DSE accuracy 6.5660e-04.
# 1401   WARN err DSE accuracy -2.3395e-04.
# 1414   WARN err DSE accuracy 1.6451e-02.
# 1415   WARN err DSE accuracy -4.5777e-04.
# 1416   WARN err DSE accuracy 1.5435e-02.
# 1417   WARN err DSE accuracy -7.1146e-03.
# 1420   WARN err DSE accuracy 4.4128e-02.
# 1421   WARN err DSE accuracy -2.3389e-01.
# 1422   WARN err DSE accuracy 7.7438e-04.
# 1424   WARN err DSE accuracy -4.6921e-04.
# 1425   WARN err DSE accuracy 1.5686e-02.
# 1426   WARN err DSE accuracy -3.4428e-02.
# 1427   WARN err DSE accuracy -7.5439e-02.
# 1433   WARN err DSE accuracy -1.3233e-02.
# 1439   WARN err DSE accuracy -2.2467e+02.
# 1443   WARN err DSE accuracy -1.4601e-03.
# 1453   WARN err DSE accuracy -1.7269e+02.
# 1464   WARN err DSE accuracy -8.3127e-04.
# 1471   WARN err DSE accuracy 3.4040e-01.
# 1473   WARN err DSE accuracy 5.6740e-04.
# 1477   WARN err DSE accuracy 1.2513e-02.
# 1491   WARN err DSE accuracy -1.3904e+01.
# 1497   WARN err DSE accuracy -6.8294e-01.
# 1522   WARN err DSE accuracy 3.9949e-02.
# 1532   WARN err DSE accuracy -7.2940e-02.
# 1547   WARN err pivot size -4.6445e-06.
# 1549   WARN err DSE accuracy 3.9860e-01.
# 1559   WARN err DSE accuracy -8.2669e+00.
# 1564   WARN err DSE accuracy 3.3836e-02.
# 1578   WARN err DSE accuracy -3.9049e-01.
# 1580   WARN err DSE accuracy -6.0547e-02.
# 1581   WARN err DSE accuracy 3.6085e-04.
# 1582   WARN err DSE accuracy -9.3579e-04.
# 1583   WARN err DSE accuracy -1.0195e-03.
# 1584   WARN err DSE accuracy 1.0729e-03.
# 1585   WARN err DSE accuracy -7.9823e-04.
# 1586   WARN err DSE accuracy 1.4377e-04.
# 1587   WARN err DSE accuracy -1.4629e-03.
# 1592   WARN err DSE accuracy 5.1327e-04.
# 1593   WARN err DSE accuracy -1.8512e-03.
# 1594   WARN err DSE accuracy 4.4568e-03.
# 1596   WARN err DSE accuracy -7.7462e-03.
# 1597   WARN err DSE accuracy -2.6783e-03.
# 1600   WARN err DSE accuracy -3.9210e-04.
# 1603   WARN err DSE accuracy -4.7827e-04.
# 1605   WARN err DSE accuracy 1.6609e-03.
# 1608   WARN err DSE accuracy 6.3019e-02.
# 1617   WARN err DSE accuracy 7.5912e-04.
# 1620   WARN err DSE accuracy -2.2762e-02.
# 1629   WARN err DSE accuracy -5.2491e+00.
# 1632   WARN err DSE accuracy -1.3233e-02.
# 1633   WARN err DSE accuracy 1.6403e-04.
# 1635   WARN err DSE accuracy -3.0461e-04.
# 1636   WARN err DSE accuracy 2.3655e-04.
# 1648   WARN err DSE accuracy 1.2629e-03.
# 1654   WARN err DSE accuracy 9.0075e-04.
# 1657   WARN err DSE accuracy -2.0999e-04.
# 1658   WARN err DSE accuracy -1.3662e-04.
# 1660   WARN err DSE accuracy -6.5662e-02.
# 1673   WARN err DSE accuracy -9.7416e-04.
# 1675   WARN err DSE accuracy -5.2490e-03.
# 1679   WARN err DSE accuracy -9.9366e-04.
# 1692   WARN err DSE accuracy -7.8597e-04.
# 1694   WARN err DSE accuracy -1.3021e-02.
# 1695   WARN err DSE accuracy 1.4294e-01.
# 1698   WARN err DSE accuracy 3.0326e-04.
# 1700   WARN err DSE accuracy -2.0898e-04.
# 1705   WARN err DSE accuracy -3.3494e+04.
# 1718   WARN err DSE accuracy 1.9450e-04.
# 1725   WARN err DSE accuracy -8.3168e-02.
# 1736   WARN err DSE accuracy -3.9328e-02.
# 1737   WARN err DSE accuracy 1.1920e-01.
# 1739   WARN err DSE accuracy -8.6558e-01.
# 1751   WARN err DSE accuracy -5.9942e-02.
# 1753   WARN err DSE accuracy 7.4613e-04.
# 1755   WARN err DSE accuracy 1.4789e-04.
# 1758   WARN err DSE accuracy -2.6638e-04.
# 1766   WARN err DSE accuracy -1.7762e-04.
# 1772   WARN err DSE accuracy -6.7312e-04.
# 1785   WARN err DSE accuracy -2.3684e-03.
# 1786   WARN err DSE accuracy -9.7917e-04.
# 1787   WARN err DSE accuracy -7.0382e-02.
# 1803   WARN err DSE accuracy 3.6621e-04.
# 1824   WARN err DSE accuracy -3.1208e-03.
# 1829   WARN err DSE accuracy -2.7820e-02.
# 1831   WARN err DSE accuracy 7.2272e-04.
# 1853   WARN err DSE accuracy -5.7617e-02.
# 1854   WARN err DSE accuracy -7.1289e-02.
# 1855   WARN err DSE accuracy -1.6835e-01.
# 1856   WARN err DSE accuracy -7.1563e-02.
# 1857   WARN err DSE accuracy 5.1497e-04.
# 1859   WARN err DSE accuracy -9.0452e-02.
# 1860   WARN err DSE accuracy -1.4897e-03.
# 1864   WARN err DSE accuracy -2.3277e-02.
# 1872   WARN err DSE accuracy -1.1805e-02.
# 1880   WARN err DSE accuracy -3.0896e-01.
# 1881   WARN err DSE accuracy 1.0354e-03.
# 1883   WARN err DSE accuracy 1.7500e-04.
# 1884   WARN err DSE accuracy 6.4429e-01.
# 1885   WARN err DSE accuracy 1.7624e-03.
# 1889   WARN err DSE accuracy 8.9539e-02.
# 1890   WARN err DSE accuracy 2.0710e-03.
# 1892   WARN err DSE accuracy -4.0855e-03.
# 1895   WARN err DSE accuracy -4.9896e-03.
# 1896   WARN err DSE accuracy 4.0321e-03.
# 1897   WARN err DSE accuracy -4.9934e-03.
# 1899   WARN err DSE accuracy 1.8692e-03.
# 1906   WARN err DSE accuracy 1.4416e+00.
# 1907   WARN err DSE accuracy -2.6520e-02.
# 1908   WARN err DSE accuracy -3.1738e-03.
# 1909   WARN err DSE accuracy 1.9171e+01.
# 1910   WARN err DSE accuracy 5.0864e-04.
# 1911   WARN err DSE accuracy 1.5150e-04.
# 1914   WARN err DSE accuracy 1.2385e-04.
# 1920   WARN err DSE accuracy -2.5409e+01.
# 1921   WARN err DSE accuracy -6.9046e-04.
# 1922   WARN err DSE accuracy 4.3922e-04.
# 1930   WARN err DSE accuracy -3.2381e-03.
# 1932   WARN err DSE accuracy 2.7139e-04.
# 1933   WARN err DSE accuracy 1.0685e-02.
# 1936   WARN err pivot size -0.0000e+00.
# 1938   Obj Primal nan Dual -2.8422e+06  Primal Inf nan (1)  Con Inf nan (1)
# [----Begin evaluation----]
# PuLP Eval: con inf=4.4547e-01,var inf=1.5447e-03,obj=-2.7201e+06. Status: 1.
# Solver Eval: con inf=1.4647e+01,var inf=nan,obj=nan. Status: SolveStatus.PRIMAL_INFEAS.
# Elapsed time: PuLP = 0.326, Solver = 1.762.
# Two solvers mismatch: PuLP = -2.7201e+06, Solver = nan.
# /Users/hanqiu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:21: RuntimeWarning: invalid value encountered in less
# /Users/hanqiu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in greater
# Problem name: PILOT4, size: ((410, 1000),5141).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 1.
# ...
# Two solvers match: PuLP = -5.2202e+01, Solver = -5.2202e+01.
#
# Problem name: SC50A, size: ((50, 48),130).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 1.
# 31   Obj Primal 2.8422e-14 Dual 0.0000e+00
# Enter phase 2.
# 55   Obj Primal -6.4575e+01 Dual -6.4575e+01
# [----Begin evaluation----]
# PuLP Eval: con inf=3.7800e-05,var inf=0.0000e+00,obj=-6.4575e+01. Status: 1.
# Solver Eval: con inf=9.1926e-13,var inf=9.7700e-15,obj=-6.4575e+01. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.016, Solver = 0.038.
# Two solvers match: PuLP = -6.4575e+01, Solver = -6.4575e+01.
#
# Problem name: SC50B, size: ((50, 48),118).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 1.
# 20   Obj Primal 2.8422e-14 Dual 0.0000e+00
# Enter phase 2.
# 50   Obj Primal -7.0000e+01 Dual -7.0000e+01
# [----Begin evaluation----]
# PuLP Eval: con inf=6.3949e-14,var inf=0.0000e+00,obj=-7.0000e+01. Status: 1.
# Solver Eval: con inf=1.4353e-12,var inf=0.0000e+00,obj=-7.0000e+01. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.014, Solver = 0.032.
# Two solvers match: PuLP = -7.0000e+01, Solver = -7.0000e+01.
#
# Problem name: SCAGR25, size: ((471, 500),1554).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 1.
# 150   Obj Primal 2.2374e-10 Dual 0.0000e+00
# Enter phase 2.
# 493   Obj Primal -1.4753e+07 Dual -1.4753e+07
# [----Begin evaluation----]
# PuLP Eval: con inf=6.4558e-03,var inf=0.0000e+00,obj=-1.4753e+07. Status: 1.
# Solver Eval: con inf=4.1947e-09,var inf=1.2736e-10,obj=-1.4753e+07. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.048, Solver = 0.381.
# Two solvers match: PuLP = -1.4753e+07, Solver = -1.4753e+07.
#
# Problem name: SCAGR7, size: ((129, 140),420).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 1.
# 79   Obj Primal -2.8334e-11 Dual 0.0000e+00
# Enter phase 2.
# 174   Obj Primal -2.3314e+06 Dual -2.3314e+06
# [----Begin evaluation----]
# PuLP Eval: con inf=4.5610e-04,var inf=0.0000e+00,obj=-2.3314e+06. Status: 1.
# Solver Eval: con inf=2.1184e-10,var inf=0.0000e+00,obj=-2.3314e+06. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.026, Solver = 0.127.
# Two solvers match: PuLP = -2.3314e+06, Solver = -2.3314e+06.
#
# Problem name: SCFXM1, size: ((330, 457),2589).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 1.
# 161   Obj Primal -6.3360e-13 Dual 0.0000e+00
# Enter phase 2.
# 514   Obj Primal 1.8417e+04 Dual 1.8417e+04
# [----Begin evaluation----]
# PuLP Eval: con inf=5.7525e-04,var inf=2.2086e-08,obj=1.8417e+04. Status: 1.
# Solver Eval: con inf=5.4130e-09,var inf=5.3489e-10,obj=1.8417e+04. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.058, Solver = 0.334.
# Two solvers match: PuLP = 1.8417e+04, Solver = 1.8417e+04.
#
# Problem name: SCFXM2, size: ((660, 914),5183).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 1.
# 281   Obj Primal -4.3758e-13 Dual 0.0000e+00
# Enter phase 2.
# 993   Obj Primal 3.6660e+04 Dual 3.6660e+04
# [----Begin evaluation----]
# PuLP Eval: con inf=1.5460e-03,var inf=2.4365e-08,obj=3.6660e+04. Status: 1.
# Solver Eval: con inf=2.8298e-08,var inf=1.5048e-10,obj=3.6660e+04. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.105, Solver = 0.836.
# Two solvers match: PuLP = 3.6660e+04, Solver = 3.6660e+04.
#
# Problem name: SCFXM3, size: ((990, 1371),7777).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 1.
# 391   Obj Primal -1.6919e-12 Dual 0.0000e+00
# Enter phase 2.
# 1000   Obj Primal 4.2092e+04 Dual 4.2092e+04  Primal Inf 5.6171e+04 (231)
# 1395   WARN err DSE accuracy 7.3242e-04.
# 1400   WARN err DSE accuracy 1.2422e-03.
# 1404   WARN err DSE accuracy 9.8644e-04.
# 1464   Obj Primal 5.4901e+04 Dual 5.4901e+04
# [----Begin evaluation----]
# PuLP Eval: con inf=1.5061e-03,var inf=2.4806e-08,obj=5.4901e+04. Status: 1.
# Solver Eval: con inf=4.5944e-08,var inf=1.6047e-10,obj=5.4901e+04. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.149, Solver = 1.564.
# Two solvers match: PuLP = 5.4901e+04, Solver = 5.4901e+04.
#
# Problem name: SCORPION, size: ((388, 358),1426).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 2.
# 339   Obj Primal 1.8781e+03 Dual 1.8781e+03
# [----Begin evaluation----]
# PuLP Eval: con inf=4.4465e-07,var inf=0.0000e+00,obj=1.8781e+03. Status: 1.
# Solver Eval: con inf=2.6616e-14,var inf=3.1396e-15,obj=1.8781e+03. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.051, Solver = 0.246.
# Two solvers match: PuLP = 1.8781e+03, Solver = 1.8781e+03.
#
# Problem name: SCRS8, size: ((490, 1169),3182).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 1.
# 45   Obj Primal -7.3081e-13 Dual 0.0000e+00
# Enter phase 2.
# 585   Obj Primal 9.0430e+02 Dual 9.0430e+02
# [----Begin evaluation----]
# PuLP Eval: con inf=1.4005e-05,var inf=0.0000e+00,obj=9.0430e+02. Status: 1.
# Solver Eval: con inf=5.4001e-11,var inf=1.7327e-14,obj=9.0430e+02. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.105, Solver = 0.539.
# Two solvers match: PuLP = 9.0430e+02, Solver = 9.0430e+02.
#
# Problem name: SCSD1, size: ((77, 760),2388).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 2.
# 97   Obj Primal 8.6667e+00 Dual 8.6667e+00
# [----Begin evaluation----]
# PuLP Eval: con inf=1.9562e-08,var inf=0.0000e+00,obj=8.6667e+00. Status: 1.
# Solver Eval: con inf=1.7638e-14,var inf=1.2433e-14,obj=8.6667e+00. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.047, Solver = 0.052.
# Two solvers match: PuLP = 8.6667e+00, Solver = 8.6667e+00.
# Problem name: SCSD6, size: ((147, 1350),4316).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 2.
# 261   Obj Primal 5.0500e+01 Dual 5.0500e+01
# [----Begin evaluation----]
# PuLP Eval: con inf=1.0431e-07,var inf=0.0000e+00,obj=5.0500e+01. Status: 1.
# Solver Eval: con inf=2.8394e-13,var inf=5.0147e-13,obj=5.0500e+01. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.103, Solver = 0.157.
# Two solvers match: PuLP = 5.0500e+01, Solver = 5.0500e+01.
#
# Problem name: SCSD8, size: ((397, 2750),8584).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 2.
# 961   Obj Primal 9.0500e+02 Dual 9.0500e+02
# [----Begin evaluation----]
# PuLP Eval: con inf=5.8315e-06,var inf=0.0000e+00,obj=9.0500e+02. Status: 1.
# Solver Eval: con inf=3.3944e-11,var inf=6.2166e-12,obj=9.0500e+02. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.282, Solver = 0.706.
# Two solvers match: PuLP = 9.0500e+02, Solver = 9.0500e+02.
#
# Problem name: SCTAP1, size: ((300, 480),1692).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 2.
# 327   Obj Primal 1.4122e+03 Dual 1.4123e+03
# [----Begin evaluation----]
# PuLP Eval: con inf=4.7600e-07,var inf=0.0000e+00,obj=1.4122e+03. Status: 1.
# Solver Eval: con inf=2.5864e-12,var inf=6.2612e-14,obj=1.4122e+03. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.059, Solver = 0.239.
# Two solvers match: PuLP = 1.4122e+03, Solver = 1.4122e+03.
#
# Problem name: SCTAP2, size: ((1090, 1880),6714).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 2.
# 769   Obj Primal 1.7248e+03 Dual 1.7248e+03
# [----Begin evaluation----]
# PuLP Eval: con inf=1.9050e-06,var inf=0.0000e+00,obj=1.7248e+03. Status: 1.
# Solver Eval: con inf=4.7437e-12,var inf=9.4527e-14,obj=1.7248e+03. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.131, Solver = 0.593.
# Two solvers match: PuLP = 1.7248e+03, Solver = 1.7248e+03.
#
# Problem name: SCTAP3, size: ((1480, 2480),8874).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 2.
# 1000   Obj Primal 1.4125e+03 Dual 1.4125e+03  Primal Inf 1.0808e+02 (89)
# 1077   Obj Primal 1.4240e+03 Dual 1.4240e+03
# [----Begin evaluation----]
# PuLP Eval: con inf=1.8440e-06,var inf=0.0000e+00,obj=1.4240e+03. Status: 1.
# Solver Eval: con inf=5.9683e-12,var inf=1.4484e-13,obj=1.4240e+03. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.185, Solver = 0.955.
# Two solvers match: PuLP = 1.4240e+03, Solver = 1.4240e+03.
#
# Problem name: SEBA, size: ((515, 1035),4359).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 2.
# 439   Obj Primal 1.5712e+04 Dual 1.5712e+04
# [----Begin evaluation----]
# PuLP Eval: con inf=0.0000e+00,var inf=0.0000e+00,obj=1.5712e+04. Status: 1.
# Solver Eval: con inf=0.0000e+00,var inf=0.0000e+00,obj=1.5712e+04. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.098, Solver = 0.342.
# Two solvers match: PuLP = 1.5712e+04, Solver = 1.5712e+04.
#
# Problem name: SHARE1B, size: ((117, 225),1151).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 1.
# 121   Obj Primal 5.8496e-12 Dual 0.0000e+00
# Enter phase 2.
# 214   Obj Primal -7.6589e+04 Dual -7.6589e+04
# [----Begin evaluation----]
# PuLP Eval: con inf=5.3243e-02,var inf=0.0000e+00,obj=-7.6589e+04. Status: 1.
# Solver Eval: con inf=1.2870e-08,var inf=0.0000e+00,obj=-7.6589e+04. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.038, Solver = 0.192.
# Two solvers match: PuLP = -7.6589e+04, Solver = -7.6589e+04.
#
# Problem name: SHARE2B, size: ((96, 79),694).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 1.
# 110   Obj Primal -6.6152e-13 Dual 0.0000e+00
# Enter phase 2.
# 187   Obj Primal -4.1573e+02 Dual -4.1573e+02
# [----Begin evaluation----]
# PuLP Eval: con inf=2.1444e-04,var inf=0.0000e+00,obj=-4.1573e+02. Status: 1.
# Solver Eval: con inf=2.4731e-11,var inf=5.7965e-13,obj=-4.1573e+02. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.027, Solver = 0.159.
# Two solvers match: PuLP = -4.1573e+02, Solver = -4.1573e+02.
#
# Problem name: SHELL, size: ((536, 1775),3556).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 2.
# 567   Obj Primal 1.2088e+09 Dual 1.2088e+09
# [----Begin evaluation----]
# PuLP Eval: con inf=0.0000e+00,var inf=0.0000e+00,obj=1.2088e+09. Status: 1.
# Solver Eval: con inf=0.0000e+00,var inf=0.0000e+00,obj=1.2088e+09. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.134, Solver = 0.468.
# Two solvers match: PuLP = 1.2088e+09, Solver = 1.2088e+09.
#
# Problem name: SHIP04L, size: ((402, 2118),6332).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 2.
# 409   Obj Primal 1.7933e+06 Dual 1.7933e+06
# [----Begin evaluation----]
# PuLP Eval: con inf=4.9194e-06,var inf=6.0000e-12,obj=1.7933e+06. Status: 1.
# Solver Eval: con inf=1.4285e-13,var inf=6.3838e-16,obj=1.7933e+06. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.167, Solver = 0.331.
# Two solvers match: PuLP = 1.7933e+06, Solver = 1.7933e+06.
#
# Problem name: SHIP04S, size: ((402, 1458),4352).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 2.
# 410   Obj Primal 1.7987e+06 Dual 1.7987e+06
# [----Begin evaluation----]
# PuLP Eval: con inf=3.1332e-06,var inf=0.0000e+00,obj=1.7987e+06. Status: 1.
# Solver Eval: con inf=9.5222e-14,var inf=9.0101e-16,obj=1.7987e+06. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.127, Solver = 0.346.
# Two solvers match: PuLP = 1.7987e+06, Solver = 1.7987e+06.
#
# Problem name: SHIP08S, size: ((778, 2387),7114).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 2.
# 680   Obj Primal 1.9201e+06 Dual 1.9201e+06
# [----Begin evaluation----]
# PuLP Eval: con inf=3.0000e-06,var inf=4.0000e-12,obj=1.9201e+06. Status: 1.
# Solver Eval: con inf=3.8940e-13,var inf=2.1675e-15,obj=1.9201e+06. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.181, Solver = 0.552.
# Two solvers match: PuLP = 1.9201e+06, Solver = 1.9201e+06.
#
# Problem name: SHIP12S, size: ((1151, 2763),8178).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 2.
# 1000   Obj Primal 1.4625e+06 Dual 1.4625e+06  Primal Inf 1.6695e+01 (118)
# 1132   Obj Primal 1.4892e+06 Dual 1.4892e+06
# [----Begin evaluation----]
# PuLP Eval: con inf=4.2039e-06,var inf=9.0000e-12,obj=1.4892e+06. Status: 1.
# Solver Eval: con inf=1.6349e-12,var inf=8.1528e-14,obj=1.4892e+06. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.174, Solver = 0.961.
# Two solvers match: PuLP = 1.4892e+06, Solver = 1.4892e+06.
#
# Problem name: SIERRA, size: ((1227, 2036),7302).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 2.
# 621   WARN err pivot size 1.0000e-05.
# 627   Obj Primal 1.5394e+07 Dual 1.5394e+07
# [----Begin evaluation----]
# PuLP Eval: con inf=2.4576e-12,var inf=1.4211e-14,obj=1.5394e+07. Status: 1.
# Solver Eval: con inf=2.0686e-08,var inf=1.5793e-12,obj=1.5394e+07. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.183, Solver = 0.551.
# Two solvers match: PuLP = 1.5394e+07, Solver = 1.5394e+07.
#
# Problem name: STAIR, size: ((356, 467),3856).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 1.
# 199   Obj Primal 9.5479e-15 Dual 0.0000e+00
# Enter phase 2.
# 419   Obj Primal -2.5127e+02 Dual -2.5127e+02
# [----Begin evaluation----]
# PuLP Eval: con inf=1.9146e-04,var inf=0.0000e+00,obj=-2.5127e+02. Status: 1.
# Solver Eval: con inf=1.6520e-11,var inf=0.0000e+00,obj=-2.5127e+02. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.080, Solver = 0.339.
# Two solvers match: PuLP = -2.5127e+02, Solver = -2.5127e+02.
#
# Problem name: STANDATA, size: ((359, 1075),3031).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 2.
# 71   Obj Primal 1.2577e+03 Dual 1.2577e+03
# [----Begin evaluation----]
# PuLP Eval: con inf=1.7764e-15,var inf=0.0000e+00,obj=1.2577e+03. Status: 1.
# Solver Eval: con inf=9.4147e-14,var inf=1.4211e-14,obj=1.2577e+03. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.067, Solver = 0.058.
# Two solvers match: PuLP = 1.2577e+03, Solver = 1.2577e+03.
#
# Problem name: STANDGUB, size: ((361, 1184),3139).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 2.
# 71   Obj Primal 1.2577e+03 Dual 1.2577e+03
# [----Begin evaluation----]
# PuLP Eval: con inf=1.7764e-15,var inf=0.0000e+00,obj=1.2577e+03. Status: 1.
# Solver Eval: con inf=9.4147e-14,var inf=1.4211e-14,obj=1.2577e+03. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.064, Solver = 0.040.
# Two solvers match: PuLP = 1.2577e+03, Solver = 1.2577e+03.
#
# Problem name: STANDMPS, size: ((467, 1075),3679).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 2.
# 218   Obj Primal 1.4060e+03 Dual 1.4060e+03
# [----Begin evaluation----]
# PuLP Eval: con inf=1.6059e-13,var inf=0.0000e+00,obj=1.4060e+03. Status: 1.
# Solver Eval: con inf=8.6898e-13,var inf=8.3267e-17,obj=1.4060e+03. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.085, Solver = 0.202.
# Two solvers match: PuLP = 1.4060e+03, Solver = 1.4060e+03.
#
# Problem name: STOCFOR1, size: ((117, 111),447).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 1.
# 108   Obj Primal 6.5434e-13 Dual 0.0000e+00
# Enter phase 2.
# 115   Obj Primal -4.1132e+04 Dual -4.1132e+04
# [----Begin evaluation----]
# PuLP Eval: con inf=6.7603e-04,var inf=0.0000e+00,obj=-4.1132e+04. Status: 1.
# Solver Eval: con inf=7.3945e-12,var inf=0.0000e+00,obj=-4.1132e+04. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.025, Solver = 0.115.
# Two solvers match: PuLP = -4.1132e+04, Solver = -4.1132e+04.
# Problem name: STOCFOR2, size: ((2157, 2031),8343).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 1.
# 1000   Obj Primal -1.2241e+05 Dual -1.2241e+05  Primal Inf 1.0535e+05 (676)
# 1901   Obj Primal 7.1942e-10 Dual 0.0000e+00
# Enter phase 2.
# 2000   Obj Primal -4.0672e+04 Dual -4.0672e+04  Primal Inf 1.4978e+03 (151)
# 2119   Obj Primal -3.9024e+04 Dual -3.9024e+04
# [----Begin evaluation----]
# PuLP Eval: con inf=1.0366e-02,var inf=0.0000e+00,obj=-3.9024e+04. Status: 1.
# Solver Eval: con inf=1.6708e-09,var inf=1.0152e-12,obj=-3.9024e+04. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.269, Solver = 3.009.
# Two solvers match: PuLP = -3.9024e+04, Solver = -3.9024e+04.
#
# Problem name: TUFF, size: ((333, 587),4520).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 1.
# 6   Obj Primal 0.0000e+00 Dual 0.0000e+00
# Enter phase 2.
# 275   Obj Primal 2.9215e-01 Dual 2.9215e-01
# [----Begin evaluation----]
# PuLP Eval: con inf=2.9937e-04,var inf=0.0000e+00,obj=2.9215e-01. Status: 1.
# Solver Eval: con inf=1.7498e-10,var inf=1.9161e-12,obj=2.9215e-01. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.064, Solver = 0.146.
# Two solvers match: PuLP = 2.9215e-01, Solver = 2.9215e-01.
#
# Problem name: VTP-BASE, size: ((198, 203),908).
# [----Launch PuLP----]
# [----Launch Solver----]
# Enter phase 1.
# 2   Obj Primal 0.0000e+00 Dual 0.0000e+00
# Enter phase 2.
# 200   Obj Primal 1.2983e+05 Dual 1.2983e+05
# [----Begin evaluation----]
# PuLP Eval: con inf=2.6682e-03,var inf=0.0000e+00,obj=1.2983e+05. Status: 1.
# Solver Eval: con inf=5.3832e-10,var inf=1.4692e-11,obj=1.2983e+05. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.025, Solver = 0.104.
# Two solvers match: PuLP = 1.2983e+05, Solver = 1.2983e+05.

# %% [markdown]
# 上面的测试结果显示，加入robust ratio test后，大部分测试问题可以被正确求解，但仍存在以下问题：
# * 对于一些测试问题（包括PEROLD、PILOT-WE），robust ratio test无法避免选中对应小的pivot size的列；
# * 对于一些测试问题（包括FINNIS、LOTFI、MAROS），在第一和第二阶段的转换中会发生可行性丧失的情况（见phase 1 check输出）。
#
# 在下一小节中，我将进一步引入随机扰动和回滚机制，并对求解主流程的逻辑进行梳理和改进，以解决上述问题。

# %% [markdown]
# ### 随机扰动-回滚机制与求解流程改进

# %% [markdown]
# 首先，我将在DualSimplexSolver中加入随机扰动和shift；后续的回滚机制和求解流程控制都需要使用这两种技术。

# %%
class DualSimplexSolverPlus3a(DualSimplexSolverPlus2):
    '''
    在DualSimplexSolverPlus2的基础上加入shift和perturb技术
    '''
    
    def _get_header(self):
        count = self.global_info.get('count',0)
        phase = self.global_info.get('phase',2)
        header = '{} (P{})'.format(count,phase)
        return header
    
    def _perturb(self,problem):
        '''
        针对DS算法的随机扰动方法，参考A. Koberstein论文中的实现
        '''
        ## 先获取原始目标系数
        c = self.global_info['c_raw'].copy()
    
        ## 获取问题属性
        l,u = problem.l,problem.u
        n,m = problem.A.shape
        m_original = m - n

        ## 生成随机扰动的大小
        psi = 1e-5
        perturb_scale = psi * np.abs(c) + 1e2 * DUAL_TOL
        perturb_scale = 0.5 * (1 + np.random.rand(len(c))) * perturb_scale
        ## 根据上下界情况，基于对偶可行性调整扰动方向
        perturb_scale = (1 * (u >= INF) - 1 * (l <= -INF) + 1 * ((u < INF) & (l > -INF))) * perturb_scale

        ## 将扰动值缩放到范围[perturb_min,perturb_max]中
        perturb_min,perturb_max = min(psi,1e-1 * DUAL_TOL),max(psi*np.mean(c),1e2 * DUAL_TOL)
        idx_below = (np.abs(perturb_scale) < perturb_min) & (perturb_scale != 0)
        while np.any(idx_below):
            perturb_scale[idx_below] *= 10
            idx_below = (np.abs(perturb_scale) < perturb_min) & (perturb_scale != 0)
        idx_above = (np.abs(perturb_scale) > perturb_max)
        while np.any(idx_above):
            perturb_scale[idx_above] /= 10
            idx_above = (np.abs(perturb_scale) > perturb_max)

        ## 施加扰动，并保证逻辑变量不受影响
        c_perturb = c + perturb_scale
        c_perturb[m_original:] = 0

        ## 生成扰动后的问题
        problem_perturb = Problem(problem.A,problem.b,c_perturb,problem.l,problem.u)
        
        ## 打印扰动量级
        header = self._get_header()
        print('{}  INFO max perturb size {:.2e}.'.format(header,np.max(np.abs(c_perturb - c))))
        return problem_perturb
    
    def _shift(self,problem,sol,check_list=None):
        '''
        对目标系数c进行shift调整，使得对偶解sol.s是可行的；
        参数check_list指定了需要考虑shift的列
        '''
        if check_list is not None:
            s_,sign_ = sol.s[check_list],sol.sign[check_list]
        else:
            s_,sign_ = sol.s,sol.sign
            
        ## 计算解的对偶不可行程度
        bool_lower = sign_ == VarStatus.AT_LOWER_BOUND.value
        bool_upper = sign_ == VarStatus.AT_UPPER_BOUND.value
        dual_inf_ = np.zeros((len(s_),))
        dual_inf_[bool_upper] = np.maximum(s_[bool_upper],0)
        dual_inf_[bool_lower] = np.maximum(-s_[bool_lower],0)
            
        bool_shift = dual_inf_ > DUAL_TOL
        if np.any(bool_shift):
            ## 找到对偶不可行的列，计算应该shift的值
            shift_ = s_[bool_shift]
            shift_[bool_lower[bool_shift]] += DUAL_TOL
            shift_[bool_upper[bool_shift]] -= DUAL_TOL
                
            ## 做shift
            if check_list is not None:
                problem.c[check_list[bool_shift]] -= shift_
                sol.s[check_list[bool_shift]] -= shift_
            else:
                problem.c[bool_shift] -= shift_
                sol.s[bool_shift] -= shift_
                
            ## 如有必要，打印shift量级
            if np.max(np.abs(shift_)) > DUAL_TOL * 10:
                header = self._get_header()
                print('{}  INFO max shift size: {:.2e}.'.format(header,np.max(np.abs(shift_))))
        return problem,sol

# %% [markdown]
# 接下来，我将介绍回滚机制的设计。
#
# 根据blog中的思路，在迭代流程无法正常继续下去时应触发回滚操作，回到迭代路径上一个之前的好的基/解，施加随机扰动，然后重新开始求解。为此，我们应在迭代过程中定期保留好的解，以供后续可能的回滚操作使用。在本系列的实现中，我引入了一个堆栈结构对这些回滚option进行维护：一方面，迭代过程定期将满足条件的解压入该堆栈中；另一方面，如果触发了回滚操作，则从堆栈中选取迭代路径上最近的（即迭代次数最大的）一个基/解来重新开始求解。
#
# 在回滚机制的具体实现中，还需要注意到一个小问题：回滚前后的求解阶段可能不一致，因此在堆栈中需要加入对每个基/解所处的求解阶段的记录，并在触发回滚后对求解阶段的一致性进行判断，及时调整求解流程。
#
# 下面的代码块在DualSimplexSolver中加入了回滚机制的基本元素，其中_save_recent函数负责将解加入堆栈中，而_rollback函数负责执行回滚操作（从堆栈中取出解、进行扰动、检查求解阶段）。

# %%
class DualSimplexSolverPlus3b(DualSimplexSolverPlus3a):
    '''
    在DualSimplexSolverPlus3a的基础上加入rollback机制
    '''
    
    def _save_recent(self,problem,sol,basis,count,phase):
        '''
        将当前解加入回滚堆栈中
        '''
        self.global_info['rollback_stack'] += [(count,phase,basis.copy(),sol.copy())]
            
    def _rollback(self,problem,phase):
        '''
        执行回滚操作
        '''
        ## 回滚到堆栈中的最近一个解
        if len(self.global_info['rollback_stack']) > 1:
            last_saved_sol = self.global_info['rollback_stack'].pop()
        else:
            last_saved_sol = self.global_info['rollback_stack'][0]
        last_count,last_phase,basis,sol = last_saved_sol
        header = self._get_header()
        print('{}  INFO rollback to iter {} (P{}).'.format(header,last_count,last_phase))
        basis.lu_factorize() ## 对基进行重分解
        
        ## 重新对问题进行扰动
        problem = self._perturb(problem)
        ## 检查当前解对扰动后的问题的对偶可行性，并适当做shift
        problem,sol = self._shift(problem,sol)

        ## 检查回滚前后求解阶段是否一致
        if phase != last_phase:
            ## 求解阶段不一致，则需要跳出当前DS迭代流程
            if last_phase == 1:
                status = SolveStatus.PHASE1
            elif last_phase == 2:
                status = SolveStatus.PHASE2
        else:
            ## 求解阶段一致，可以继续求解
            status = SolveStatus.ONGOING
        return status,problem,sol,basis

# %% [markdown]
# 最后一步是在DualSimplexSolver中加入上述机制，并对求解流程进行改进。具体来说，我将：
# * 在迭代步_step中增加数值误差检验和shift操作；
# * 在迭代过程_loop中加入对状态REFACTOR和ROLLBACK的处理，以及通过调用_save_recent函数将好的解压入堆栈中；
# * 在求解过程_solve中对第一与第二阶段解的切换步骤进行改进，以提高求解过程的鲁棒性。
#
# 具体的改动点可参见下面代码块中的注释。

# %%
class DualSimplexSolverPlus3(DualSimplexSolverPlus3b):
    '''
    在DualSimplexSolverPlus3b的基础上改进求解流程
    '''
    
    def _ratio_test(self,problem,sol,basis,s_grad,dual_grad):
        return ratio_test(problem,sol,basis,s_grad,dual_grad)
    
    def _step(self,problem,sol,basis):
        '''
        增加shift和数值误差检验
        '''
        count = self.global_info.get('count',0)
        phase = self.global_info.get('phase',2) ## 增加对phase的记录
        header = '{} (P{})'.format(count,phase)

        ## step 1: pricing, 选出离开下标idxBI = idxB[idxI], 并计算相应对偶变量的单位变化量
        status_inner,idxI,idxBI,primal_gap = self._pricing(problem,sol,basis)
        if status_inner != SolveStatus.ONGOING:
            return status_inner,problem,sol,basis
        dual_grad = abs(primal_gap) ## 原始变量的不可行程度正是对偶问题的梯度

        bool_to_lower_bound = sol.x[idxBI] <= problem.l[idxBI]
        direcDualI = 1 if bool_to_lower_bound else -1 ## 原始变量的移动方向
        
        ## 计算对偶变量的单位变化量
        sB_grad0 = basis.get_elem_vec(idxI,if_transpose=True) ## A_B^{-T}e_I
        lam_grad0 = basis.solve(sB_grad0,if_transpose=True) ## A_B^{-T}e_I
        s_grad0 = basis.dot(lam_grad0,if_transpose=True) ## A^TA_B^{-T}e_I
        if direcDualI == -1:
            lam_grad = lam_grad0
            s_grad = -s_grad0
        else:
            lam_grad = -lam_grad0
            s_grad = s_grad0

        ## step 2: ratio test, 选出进入下标idxNJ = idxN[idxJ]
        status_inner,idxJ,idxNJ,alpha_dual,flip_list,check_list = self._ratio_test(problem,sol,basis,s_grad,dual_grad)
        if status_inner != SolveStatus.ONGOING:
            return status_inner,problem,sol,basis

        ## step 3: 更新结果
        aNJ = basis.get_col(idxNJ) ## A_j
        xB_grad0 = basis.solve(aNJ,if_transpose=False) ## A_B^{-1}A_j
        xB_grad = - xB_grad0
        betaI = np.dot(lam_grad0,lam_grad0)
        tau = basis.solve(lam_grad0,if_transpose=False)
        
        ## 校核数值稳定性并进行处理
        if True:
            ## 校核通过\delta s和\delta x_B计算得到的alpha = e_I^T A_B^{-1} a_{NJ}的一致性
            err_pivot = s_grad0[idxNJ] + xB_grad[idxI]
            if abs(err_pivot) > PRIMAL_TOL * (1 + abs(xB_grad[idxI])):
                print('{}  WARN FTRAN/BTRAN pivot consistency err {:.4e}.'.format(header,err_pivot))
                return SolveStatus.REFACTOR,problem,sol,basis
            ## 校核通过\delta s计算得到的e_I^T A_B^T A_B^{-T} e_I = e_I^T e_I = 1的准确性
            err_btran = s_grad0[idxBI] - 1
            if abs(err_btran) > DUAL_TOL:
                print('{}  WARN BTRAN accuracy err {:.4e}.'.format(header,err_btran))
                return SolveStatus.REFACTOR,problem,sol,basis
            ## 校核pivot element的大小
            if abs(xB_grad[idxI]) < PIVOT_TOL:
                print('{}  WARN pivot size {:.4e}.'.format(header,xB_grad[idxI]))
                if abs(xB_grad[idxI]) < ZERO_TOL:
                    return SolveStatus.ROLLBACK,problem,sol,basis
        if False:
            ## 校核DSE权重的准确性
            err_dse = betaI - basis.DSE_weights[idxI]
            if abs(err_dse) > PIVOT_TOL * 10:
                print('{}  WARN DSE accuracy err {:.4e}.'.format(header,err_dse))
        
        ## 更新对偶变量
        sol.lam += alpha_dual * lam_grad
        sol.s += alpha_dual * s_grad

        ## 更新原始变量  
        if len(flip_list) > 0:
            ## 对x_N进行翻转
            idx_flip_to_lower = flip_list[sol.sign[flip_list] == VarStatus.AT_UPPER_BOUND.value]
            idx_flip_to_upper = flip_list[sol.sign[flip_list] == VarStatus.AT_LOWER_BOUND.value]
            sol.x[idx_flip_to_lower] = problem.l[idx_flip_to_lower]
            sol.x[idx_flip_to_upper] = problem.u[idx_flip_to_upper]
            sol.sign[idx_flip_to_lower] = VarStatus.AT_LOWER_BOUND.value
            sol.sign[idx_flip_to_upper] = VarStatus.AT_UPPER_BOUND.value
            ## 根据翻转的x_N，更新x_B
            delta_x_flipped = np.zeros((basis.m,))
            delta_x_flipped[idx_flip_to_lower] = -problem.bounds_gap[idx_flip_to_lower]
            delta_x_flipped[idx_flip_to_upper] = problem.bounds_gap[idx_flip_to_upper]
            delta_b_flipped = basis.dot(delta_x_flipped,if_transpose=False)
            delta_xB = - basis.solve(delta_b_flipped,if_transpose=False)
            sol.x[basis.idxB] += delta_xB
            delta_xBI = delta_xB[idxI]
        else:
            delta_xBI = 0

        ## 然后，计算原始步长，并更新x_j和x_B
        alpha_primal = (-primal_gap - delta_xBI) / xB_grad[idxI]
        sol.x[basis.idxB] += alpha_primal * xB_grad
        sol.x[idxBI] = problem.l[idxBI] if bool_to_lower_bound else problem.u[idxBI]
        sol.sign[idxBI] = VarStatus.AT_LOWER_BOUND.value if bool_to_lower_bound else VarStatus.AT_UPPER_BOUND.value
        sol.x[idxNJ] += alpha_primal
        sol.sign[idxNJ] = VarStatus.OTHER.value ## 进入B
        
        ## 检查解的对偶可行性并及时进行shift操作
        if len(check_list) > 0:
            problem,sol = self._shift(problem,sol,check_list=check_list)

        ## 更新基
        basis.idxB[idxI] = idxNJ
        basis.idxN[idxJ] = idxBI
        basis.boolN[idxBI] = True
        basis.boolN[idxNJ] = False
        ## 更新PFI和DSE信息
        eta_vec = -xB_grad0 / xB_grad0[idxI]
        eta_vec[idxI] += 1 / xB_grad0[idxI]
        eta = (idxI,eta_vec)
        basis.lu_update(eta=eta)
        basis.update_DSE_weights(idxI,xB_grad0,tau,betaI)        
        sol.s[basis.idxB] = 0
        
        return SolveStatus.ONGOING,problem,sol,basis
        
    def _loop(self,problem,sol,basis):
        '''
        增加对REFACTOR、ROLLBACK状态的处理
        '''
        count = self.global_info.get('count',0)
        phase = self.global_info.get('phase',2)
        start_time = self.global_info.get('start_time',time.time())
        
        while True:
            if count % 50000 == 0 and count > 0:
                print('resetting the DSE weights!')
                basis.reset_DSE_weights() ## DSE更新
            if basis.eta_count % 20 == 0 and count > 0:
                basis.lu_factorize() ## LU分解
                
            status,problem,sol,basis = self._step(problem,sol,basis) ## 做一步迭代
            count += 1
            self.global_info['count'] = count
            header = '{} (P{})'.format(count,phase)

            ## 每隔一定迭代步数监控解的状态
            if ((count % 100 == 0 and count > 0) and (status == SolveStatus.ONGOING)) \
              or (status not in (SolveStatus.ONGOING,SolveStatus.REFACTOR,SolveStatus.ROLLBACK)):
                infeas_dict,status_str = problem.check_sol_status(sol)
                if count % 10000 == 0 and count > 0:
                    print('{}  {}'.format(header,status_str))

                if infeas_dict['unbnd']:
                    ## 基对偶不可行（存在原始变量无界），直接回滚
                    print('{}  WARN Bnd err.'.format(header))
                    status = SolveStatus.ROLLBACK
                elif infeas_dict['sign']:
                    ## 基原始不可行（原始变量与基不一致），尝试根据基重新计算解
                    print('{}  WARN Sign err.'.format(header))
                    status = SolveStatus.REFACTOR
                elif infeas_dict['dual']:
                    ## 解对偶不可行，尝试LU重分解
                    print('{}  WARN Dual inf.'.format(header))
                    status = SolveStatus.REFACTOR
                elif infeas_dict['cons']:
                    ## 线性约束不满足，尝试LU重分解
                    print('{}  WARN Con inf.'.format(header))
                    status = SolveStatus.REFACTOR
                else:
                    if status == SolveStatus.ONGOING:
                        ## 解的状态ok，加入回滚堆栈中
                        if count % 500 == 0:
                            self._save_recent(problem,sol,basis,count,phase)
                    else:
                        ## 进入结束状态，打印并退出
                        print('{}  ({}) {}'.format(header,status.name,status_str))
                        return status,problem,sol,basis
                
            ## 如果状态是LU重分解，进行重分解并分析后续方向
            if status == SolveStatus.REFACTOR:
                problem,sol,basis = self._refactorize(problem,sol,basis)
                infeas_dict,status_str = problem.check_sol_status(sol) ## 检查重分解后解的状态
                if infeas_dict['cons']:
                    ## 约束不满足，说明目前基的条件数过大，有必要进入回滚流程
                    print('{}  WARN Con inf after refactor. cond number of curr basis may be too large.'.format(header))
                    status = SolveStatus.ROLLBACK
                elif infeas_dict['dual'] or infeas_dict['sign']:
                    ## 解或基对偶不可行，重新进入第一阶段
                    print('{}  WARN Dual inf after refactor.'.format(header))
                    status = SolveStatus.PHASE1
                    phase = self.global_info['phase']
                else:
                    ## 解状态正常，继续迭代过程
                    status = SolveStatus.ONGOING

            ## 如果状态是回滚，则进入回滚流程
            if status == SolveStatus.ROLLBACK:
                print('{}  INFO rollback to a recent feasible solution.'.format(header))
                status,problem,sol,basis = self._rollback(problem,phase)

            ## 如果状态非继续迭代，abort
            if status != SolveStatus.ONGOING:
                problem.check_sol_status(sol,print_func=print,print_header=header)
                return status,problem,sol,basis

            ## 限制迭代时长和次数
            if time.time() - start_time > 1.8e4 or count > 1e6:
                print('out of time / iterations.')
                problem.check_sol_status(sol,print_func=print,print_header=header)
                return SolveStatus.OTHER,problem,sol,basis
    
    def _solve(self,problem,sol,basis):
        ## 保存迭代过程中的信息，用于进行求解流程控制
        self.global_info['c_raw'] = problem.c.copy()
        self.global_info['rollback_stack'] = [(0,1,basis.copy(),sol.copy())]
        
        ## 检查初始基/解的状态
        infeas_dict,status_str = problem.check_sol_status(sol)
        if infeas_dict['unbnd']:
            ## 基对偶不可行，进入第一阶段
            status = SolveStatus.PHASE1
        elif infeas_dict['cons']:
            ## 解线性约束不可行，意味着初始条件数就很大；目前的求解流程无法处理，直接退出
            ## 注：这需要放在基对偶可行判断的后面，因为如果有原始变量无界，由于数值原因，解的线性约束很容易不可行
            print('Cond num of the initial basis is too large. Abort.')
            status = SolveStatus.ERR
        else:
            ## 可直接进入第二阶段
            status = SolveStatus.PHASE2

        ## 进入循环，在两阶段中跳转
        iter_count = 0
        while ((status in (SolveStatus.PHASE1,SolveStatus.PHASE2)) and (iter_count < 100)):
            iter_count += 1
            if status == SolveStatus.PHASE2:
                ## 进入第二阶段，寻找最优基/解
                self.global_info['phase'] = 2
                status,problem,sol,basis = self._solve_phase_two(problem,sol,basis)
            elif status == SolveStatus.PHASE1:
                ## 进入第一阶段，寻找可行基/解
                self.global_info['phase'] = 1
                statusPhase1,problemPhase1,solPhase1,basis = self._solve_phase_one(problem,sol,basis)
                ## 用第一阶段所得的基更新原始问题的解
                problem.c = problemPhase1.c
                sol.sign = solPhase1.sign.copy()

                ## 对第一阶段求解结果进行分析
                if statusPhase1 == SolveStatus.DUAL_INFEAS:
                    ## 如果返回的状态是对偶不可行，则求解流程有问题，直接退出
                    status = SolveStatus.ERR
                    # status = SolveStatus.PHASE1
                elif statusPhase1 in (SolveStatus.OPT,SolveStatus.PRIMAL_INFEAS):
                    ## 如果返回的状态是最优或原始不可行，再次检查当前基是否满足对偶可行性（不存在原始变量无界）
                    bool_unbnd = problem.eval_unbnd(sol)
                    if not np.any(bool_unbnd):
                        ## 基对偶可行，进入第二阶段
                        status = SolveStatus.PHASE2
                    else:
                        ## 基对偶不可行，说明第一阶段求解结果有瑕疵；尝试直接调整基来恢复对偶可行性，但后续需要检查解的对偶可行性
                        bool_resolve_phase1 = False
                        idxs = np.where(bool_unbnd)[0]
                        for idx in idxs:
                            if problem.bound_type[idx] == BoundType.FREE.value:
                                ## free变量无法通过调整基来恢复对偶可行性；
                                ## 直接重新进入第一阶段
                                bool_resolve_phase1 = True
                                break
                            elif problem.bound_type[idx] == BoundType.UPPER_BOUNDED.value:
                                sol.sign[idx] = VarStatus.AT_UPPER_BOUND.value
                            elif problem.bound_type[idx] == BoundType.LOWER_BOUNDED.value:
                                sol.sign[idx] = VarStatus.AT_LOWER_BOUND.value
                        if bool_resolve_phase1:
                            ## 重新进入第一阶段；尝试进行随机扰动
                            problem = self._perturb(problem)
                            status = SolveStatus.PHASE1
                        else:
                            ## 根据调整后的基计算解，并检查其状态
                            sol = self._compute_sol_from_basis(problem,basis,sign=sol.sign)
                            infeas_dict,status_str = problem.check_sol_status(sol)
                            if infeas_dict['sign'] or infeas_dict['unbnd']:
                                ## 基对偶或原始不可行；
                                ## 调整基后一般不会进入这里；一旦进入了，直接退出求解流程
                                print('ERR Basis Primal/Dual Inf. Abort.')
                                status = SolveStatus.ERR
                            elif infeas_dict['dual']:
                                ## 重新进入第一阶段；尝试进行随机扰动
                                problem = self._perturb(problem)
                                status = SolveStatus.PHASE1
                            elif infeas_dict['primal']:
                                status = SolveStatus.PHASE2
                            else:
                                status = SolveStatus.OPT
                else:
                    ## 返回的状态不是标准结束状态（OPT、PRIMAL_INFEAS、DUAL_INFEAS），则直接复制状态并进行随机扰动
                    problem = self._perturb(problem)
                    status = statusPhase1
        return status,problem,sol,basis

# %% [markdown]
# 下面通过测试来看一下新的DS实现的效果。由于引入了随机扰动，多次执行的结果可能不一样；为了评估的一致性，这里选取了一个固定的随机种子32。

# %%
ds_p = DualSimplexSolverPlus3()
test(ds_p.solve,50000,random_seed=32)
# Out:
# random seed = 32.
#
# Problem name: 25FV47, size: ((821, 1571),10400).
# [----Launch PuLP----]
# [----Launch Solver----]
# 142 (P1)  (OPT) Obj Primal 1.7753e-12 Dual 2.2803e-15
# 615 (P2)  WARN pivot size -4.5910e-06.
# 2676 (P2)  (OPT) Obj Primal 5.5018e+03 Dual 5.5018e+03
# [----Begin evaluation----]
# PuLP Eval: con inf=6.7406e-04,var inf=0.0000e+00,obj=5.5018e+03. Status: 1.
# Solver Eval: con inf=2.5077e-06,var inf=2.0133e-08,obj=5.5018e+03. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.464, Solver = 3.652.
# Two solvers match: PuLP = 5.5018e+03, Solver = 5.5018e+03.
#
# Problem name: 80BAU3B, size: ((2262, 9799),21002).
# [----Launch PuLP----]
# [----Launch Solver----]
# 779 (P1)  (OPT) Obj Primal -1.1340e-11 Dual 0.0000e+00
# 3758 (P2)  (OPT) Obj Primal 9.8722e+05 Dual 9.8722e+05
# [----Begin evaluation----]
# PuLP Eval: con inf=1.0557e-03,var inf=0.0000e+00,obj=9.8722e+05. Status: 1.
# Solver Eval: con inf=6.0566e-08,var inf=2.4372e-10,obj=9.8722e+05. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.880, Solver = 6.514.
# Two solvers match: PuLP = 9.8722e+05, Solver = 9.8722e+05.
#
# Problem name: ADLITTLE, size: ((56, 97),383).
# [----Launch PuLP----]
# [----Launch Solver----]
# 24 (P1)  (OPT) Obj Primal -1.1344e-09 Dual 0.0000e+00
# 110 (P2)  (OPT) Obj Primal 2.2549e+05 Dual 2.2549e+05
# [----Begin evaluation----]
# PuLP Eval: con inf=2.6769e-05,var inf=0.0000e+00,obj=2.2549e+05. Status: 1.
# Solver Eval: con inf=1.5539e-10,var inf=0.0000e+00,obj=2.2549e+05. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.018, Solver = 0.063.
# Two solvers match: PuLP = 2.2549e+05, Solver = 2.2549e+05.
#
# Problem name: AFIRO, size: ((27, 32),83).
# [----Launch PuLP----]
# [----Launch Solver----]
# 11 (P1)  (OPT) Obj Primal -1.1369e-14 Dual 0.0000e+00
# 19 (P2)  (OPT) Obj Primal -4.6475e+02 Dual -4.6475e+02
# [----Begin evaluation----]
# PuLP Eval: con inf=9.5400e-06,var inf=0.0000e+00,obj=-4.6475e+02. Status: 1.
# Solver Eval: con inf=1.3500e-13,var inf=0.0000e+00,obj=-4.6475e+02. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.013, Solver = 0.014.
# Two solvers match: PuLP = -4.6475e+02, Solver = -4.6475e+02.
#
# Problem name: AGG, size: ((488, 163),2410).
# [----Launch PuLP----]
# [----Launch Solver----]
# 19 (P1)  (OPT) Obj Primal -2.7378e-11 Dual 0.0000e+00
# 138 (P2)  (OPT) Obj Primal -3.5992e+07 Dual -3.5992e+07
# [----Begin evaluation----]
# PuLP Eval: con inf=7.0118e-02,var inf=0.0000e+00,obj=-3.5992e+07. Status: 1.
# Solver Eval: con inf=2.2573e-07,var inf=1.1648e-10,obj=-3.5992e+07. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.051, Solver = 0.088.
# Two solvers match: PuLP = -3.5992e+07, Solver = -3.5992e+07.
#
# Problem name: AGG2, size: ((516, 302),4284).
# [----Launch PuLP----]
# [----Launch Solver----]
# 20 (P1)  (OPT) Obj Primal 0.0000e+00 Dual 0.0000e+00
# 169 (P2)  (OPT) Obj Primal -2.0239e+07 Dual -2.0239e+07
# [----Begin evaluation----]
# PuLP Eval: con inf=6.1704e-02,var inf=0.0000e+00,obj=-2.0239e+07. Status: 1.
# Solver Eval: con inf=2.0749e-08,var inf=5.8208e-11,obj=-2.0239e+07. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.067, Solver = 0.110.
# Two solvers match: PuLP = -2.0239e+07, Solver = -2.0239e+07.
#
# Problem name: AGG3, size: ((516, 302),4300).
# [----Launch PuLP----]
# [----Launch Solver----]
# 20 (P1)  (OPT) Obj Primal 0.0000e+00 Dual 0.0000e+00
# 179 (P2)  (OPT) Obj Primal 1.0312e+07 Dual 1.0312e+07
# [----Begin evaluation----]
# PuLP Eval: con inf=4.5744e-02,var inf=0.0000e+00,obj=1.0312e+07. Status: 1.
# Solver Eval: con inf=1.4735e-08,var inf=0.0000e+00,obj=1.0312e+07. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.075, Solver = 0.116.
# Two solvers match: PuLP = 1.0312e+07, Solver = 1.0312e+07.
#
# Problem name: BANDM, size: ((305, 472),2494).
# [----Launch PuLP----]
# [----Launch Solver----]
# 354 (P1)  (OPT) Obj Primal 1.0993e-12 Dual 0.0000e+00
# 637 (P2)  (OPT) Obj Primal -1.5863e+02 Dual -1.5863e+02
# [----Begin evaluation----]
# PuLP Eval: con inf=9.5659e-05,var inf=0.0000e+00,obj=-1.5863e+02. Status: 1.
# Solver Eval: con inf=7.4034e-10,var inf=7.4650e-13,obj=-1.5863e+02. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.056, Solver = 0.581.
# Two solvers match: PuLP = -1.5863e+02, Solver = -1.5863e+02.
#
# Problem name: BEACONFD, size: ((173, 262),3375).
# [----Launch PuLP----]
# [----Launch Solver----]
# 123 (P2)  (OPT) Obj Primal 3.3592e+04 Dual 3.3592e+04
# [----Begin evaluation----]
# PuLP Eval: con inf=4.3903e-11,var inf=0.0000e+00,obj=3.3592e+04. Status: 1.
# Solver Eval: con inf=2.9035e-08,var inf=0.0000e+00,obj=3.3592e+04. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.053, Solver = 0.085.
# Two solvers match: PuLP = 3.3592e+04, Solver = 3.3592e+04.
#
# Problem name: BLEND, size: ((74, 83),491).
# [----Launch PuLP----]
# [----Launch Solver----]
# 54 (P1)  (OPT) Obj Primal 5.6913e-13 Dual 0.0000e+00
# 103 (P2)  (OPT) Obj Primal -3.0812e+01 Dual -3.0812e+01
# [----Begin evaluation----]
# PuLP Eval: con inf=5.1313e-06,var inf=2.4893e-10,obj=-3.0812e+01. Status: 1.
# Solver Eval: con inf=4.8240e-11,var inf=1.6582e-12,obj=-3.0812e+01. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.020, Solver = 0.089.
# Two solvers match: PuLP = -3.0812e+01, Solver = -3.0812e+01.
#
# Problem name: BNL1, size: ((643, 1175),5121).
# [----Launch PuLP----]
# [----Launch Solver----]
# 49 (P1)  (OPT) Obj Primal 4.4465e-13 Dual 0.0000e+00
# 1057 (P2)  (OPT) Obj Primal 1.9776e+03 Dual 1.9776e+03
# [----Begin evaluation----]
# PuLP Eval: con inf=2.6652e-04,var inf=0.0000e+00,obj=1.9776e+03. Status: 1.
# Solver Eval: con inf=3.6513e-08,var inf=7.2897e-10,obj=1.9776e+03. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.153, Solver = 1.010.
# Two solvers match: PuLP = 1.9776e+03, Solver = 1.9776e+03.
#
# Problem name: BNL2, size: ((2324, 3489),13999).
# [----Launch PuLP----]
# [----Launch Solver----]
# 66 (P1)  (OPT) Obj Primal -8.5325e-15 Dual 0.0000e+00
# 2016 (P2)  (OPT) Obj Primal 1.8112e+03 Dual 1.8112e+03
# [----Begin evaluation----]
# PuLP Eval: con inf=5.4147e-04,var inf=0.0000e+00,obj=1.8112e+03. Status: 1.
# Solver Eval: con inf=1.6745e-10,var inf=4.5526e-12,obj=1.8112e+03. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.349, Solver = 2.524.
# Two solvers match: PuLP = 1.8112e+03, Solver = 1.8112e+03.
#
# Problem name: BOEING1, size: ((351, 473),3574).
# [----Launch PuLP----]
# [----Launch Solver----]
# 2 (P1)  (OPT) Obj Primal -4.4791e-13 Dual 0.0000e+00
# 461 (P2)  (OPT) Obj Primal -3.3521e+02 Dual -3.3521e+02
# [----Begin evaluation----]
# PuLP Eval: con inf=1.3845e-04,var inf=0.0000e+00,obj=-3.3521e+02. Status: 1.
# Solver Eval: con inf=3.1929e-09,var inf=1.9228e-11,obj=-3.3521e+02. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.055, Solver = 0.283.
# Two solvers match: PuLP = -3.3521e+02, Solver = -3.3521e+02.
#
# Problem name: BOEING2, size: ((166, 162),1215).
# [----Launch PuLP----]
# [----Launch Solver----]
# 42 (P1)  (OPT) Obj Primal 1.0630e-12 Dual 0.0000e+00
# 170 (P2)  (OPT) Obj Primal -3.1502e+02 Dual -3.1502e+02
# [----Begin evaluation----]
# PuLP Eval: con inf=2.0468e-05,var inf=0.0000e+00,obj=-3.1502e+02. Status: 1.
# Solver Eval: con inf=2.1622e-09,var inf=2.0105e-12,obj=-3.1502e+02. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.026, Solver = 0.091.
# Two solvers match: PuLP = -3.1502e+02, Solver = -3.1502e+02.
#
# Problem name: BORE3D, size: ((233, 315),1429).
# [----Launch PuLP----]
# [----Launch Solver----]
# 188 (P2)  (OPT) Obj Primal 1.3731e+03 Dual 1.3731e+03
# [----Begin evaluation----]
# PuLP Eval: con inf=3.1757e-04,var inf=0.0000e+00,obj=1.3731e+03. Status: 1.
# Solver Eval: con inf=1.2492e-10,var inf=1.0750e-11,obj=1.3731e+03. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.031, Solver = 0.105.
# Two solvers match: PuLP = 1.3731e+03, Solver = 1.3731e+03.
#
# Problem name: BRANDY, size: ((220, 249),2148).
# [----Launch PuLP----]
# [----Launch Solver----]
# 327 (P2)  (OPT) Obj Primal 1.5185e+03 Dual 1.5185e+03
# [----Begin evaluation----]
# PuLP Eval: con inf=1.9453e-04,var inf=0.0000e+00,obj=1.5185e+03. Status: 1.
# Solver Eval: con inf=1.7232e-08,var inf=1.1833e-11,obj=1.5185e+03. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.048, Solver = 0.184.
# Two solvers match: PuLP = 1.5185e+03, Solver = 1.5185e+03.
#
# Problem name: CAPRI, size: ((271, 353),1767).
# [----Launch PuLP----]
# [----Launch Solver----]
# 24 (P1)  (OPT) Obj Primal 2.3959e-14 Dual 0.0000e+00
# 330 (P2)  (OPT) Obj Primal 2.6900e+03 Dual 2.6900e+03
# [----Begin evaluation----]
# PuLP Eval: con inf=4.8150e-04,var inf=0.0000e+00,obj=2.6900e+03. Status: 1.
# Solver Eval: con inf=4.4430e-11,var inf=1.5987e-14,obj=2.6900e+03. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.036, Solver = 0.188.
# Two solvers match: PuLP = 2.6900e+03, Solver = 2.6900e+03.
# Problem name: CRE-A, size: ((3516, 4067),14987).
# [----Launch PuLP----]
# [----Launch Solver----]
# 3543 (P2)  (OPT) Obj Primal 2.3595e+07 Dual 2.3595e+07
# [----Begin evaluation----]
# PuLP Eval: con inf=4.9258e-05,var inf=5.4474e-11,obj=2.3595e+07. Status: 1.
# Solver Eval: con inf=5.8027e-10,var inf=1.1012e-10,obj=2.3595e+07. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.333, Solver = 4.201.
# Two solvers match: PuLP = 2.3595e+07, Solver = 2.3595e+07.
#
# Problem name: CRE-C, size: ((3068, 3678),13244).
# [----Launch PuLP----]
# [----Launch Solver----]
# 3161 (P2)  (OPT) Obj Primal 2.5275e+07 Dual 2.5275e+07
# [----Begin evaluation----]
# PuLP Eval: con inf=7.4379e-05,var inf=0.0000e+00,obj=2.5275e+07. Status: 1.
# Solver Eval: con inf=6.5770e-10,var inf=1.7670e-10,obj=2.5275e+07. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.331, Solver = 3.469.
# Two solvers match: PuLP = 2.5275e+07, Solver = 2.5275e+07.
#
# Problem name: CYCLE, size: ((1903, 2857),20720).
# [----Launch PuLP----]
# [----Launch Solver----]
# 550 (P1)  (OPT) Obj Primal -1.8032e-15 Dual 0.0000e+00
# 3106 (P2)  (PRIMAL_INFEAS) Obj Primal -5.2264e+00 Dual -5.2256e+00  Primal Inf 2.6883e-06 (6)
# [----Begin evaluation----]
# PuLP Eval: con inf=6.9354e-04,var inf=4.9284e-13,obj=-5.2264e+00. Status: 1.
# Solver Eval: con inf=1.8212e-06,var inf=1.3087e-06,obj=-5.2264e+00. Status: SolveStatus.PRIMAL_INFEAS.
# Elapsed time: PuLP = 0.258, Solver = 3.647.
# Two solvers match: PuLP = -5.2264e+00, Solver = -5.2264e+00.
#
# Problem name: CZPROB, size: ((929, 3523),10669).
# [----Launch PuLP----]
# [----Launch Solver----]
# 582 (P1)  (OPT) Obj Primal 1.2413e-12 Dual 0.0000e+00
# 1951 (P2)  (OPT) Obj Primal 2.1852e+06 Dual 2.1852e+06
# [----Begin evaluation----]
# PuLP Eval: con inf=6.8210e-04,var inf=0.0000e+00,obj=2.1852e+06. Status: 1.
# Solver Eval: con inf=1.3038e-09,var inf=4.0862e-11,obj=2.1852e+06. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.181, Solver = 1.399.
# Two solvers match: PuLP = 2.1852e+06, Solver = 2.1852e+06.
#
# Problem name: D2Q06C, size: ((2171, 5167),32417).
# [----Launch PuLP----]
# [----Launch Solver----]
# 716 (P1)  (OPT) Obj Primal -8.7291e-11 Dual 0.0000e+00
# 2269 (P2)  WARN pivot size 4.6892e-06.
# 2300 (P2)  WARN Con inf.
# 2600 (P2)  WARN Con inf.
# 5821 (P2)  (OPT) Obj Primal 1.2278e+05 Dual 1.2278e+05
# [----Begin evaluation----]
# PuLP Eval: con inf=1.2733e-02,var inf=0.0000e+00,obj=1.2278e+05. Status: 1.
# Solver Eval: con inf=1.2362e-05,var inf=5.4093e-09,obj=1.2278e+05. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 2.022, Solver = 9.633.
# Two solvers match: PuLP = 1.2278e+05, Solver = 1.2278e+05.
#
# Problem name: D6CUBE, size: ((415, 6184),37704).
# [----Launch PuLP----]
# [----Launch Solver----]
# 455 (P2)  (OPT) Obj Primal 3.1549e+02 Dual 3.1549e+02
# [----Begin evaluation----]
# PuLP Eval: con inf=1.9556e-04,var inf=0.0000e+00,obj=3.1549e+02. Status: 1.
# Solver Eval: con inf=2.8018e-11,var inf=7.3555e-12,obj=3.1549e+02. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.608, Solver = 0.427.
# Two solvers match: PuLP = 3.1549e+02, Solver = 3.1549e+02.
#
# Problem name: DEGEN2, size: ((444, 534),3978).
# [----Launch PuLP----]
# [----Launch Solver----]
# 116 (P1)  (OPT) Obj Primal 1.6904e-12 Dual 0.0000e+00
# 612 (P2)  (OPT) Obj Primal -1.4352e+03 Dual -1.4352e+03
# [----Begin evaluation----]
# PuLP Eval: con inf=1.1102e-16,var inf=0.0000e+00,obj=-1.4352e+03. Status: 1.
# Solver Eval: con inf=9.3961e-12,var inf=3.2416e-12,obj=-1.4352e+03. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.070, Solver = 0.411.
# Two solvers match: PuLP = -1.4352e+03, Solver = -1.4352e+03.
#
# Problem name: DEGEN3, size: ((1503, 1818),24646).
# [----Launch PuLP----]
# [----Launch Solver----]
# 465 (P1)  (OPT) Obj Primal 7.1759e-13 Dual 0.0000e+00
# 2413 (P2)  (OPT) Obj Primal -9.8729e+02 Dual -9.8729e+02
# [----Begin evaluation----]
# PuLP Eval: con inf=2.4036e-14,var inf=0.0000e+00,obj=-9.8729e+02. Status: 1.
# Solver Eval: con inf=7.4671e-11,var inf=2.4931e-11,obj=-9.8729e+02. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.418, Solver = 2.991.
# Two solvers match: PuLP = -9.8729e+02, Solver = -9.8729e+02.
#
# Problem name: DFL001, size: ((6071, 12230),35632).
# [----Launch PuLP----]
# [----Launch Solver----]
# 10000 (P2)  Obj Primal 1.0660e+07 Dual 1.0660e+07  Primal Inf 2.2205e+06 (1386)
# 20000 (P2)  Obj Primal 1.1266e+07 Dual 1.1266e+07  Primal Inf 7.8812e+02 (616)
# 20360 (P2)  (OPT) Obj Primal 1.1266e+07 Dual 1.1266e+07
# [----Begin evaluation----]
# PuLP Eval: con inf=7.0927e-05,var inf=1.0319e-10,obj=1.1266e+07. Status: 1.
# Solver Eval: con inf=2.1025e-08,var inf=1.8130e-08,obj=1.1266e+07. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 12.232, Solver = 88.663.
# Two solvers match: PuLP = 1.1266e+07, Solver = 1.1266e+07.
#
# Problem name: E226, size: ((223, 282),2578).
# [----Launch PuLP----]
# [----Launch Solver----]
# 168 (P1)  (OPT) Obj Primal -7.0900e-14 Dual 0.0000e+00
# 371 (P2)  (OPT) Obj Primal -1.8752e+01 Dual -1.8752e+01
# [----Begin evaluation----]
# PuLP Eval: con inf=9.3338e-06,var inf=0.0000e+00,obj=-1.8752e+01. Status: 1.
# Solver Eval: con inf=3.0661e-10,var inf=7.0406e-13,obj=-1.8752e+01. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.055, Solver = 0.283.
# Two solvers match: PuLP = -1.8752e+01, Solver = -1.8752e+01.
#
# Problem name: ETAMACRO, size: ((400, 688),2409).
# [----Launch PuLP----]
# [----Launch Solver----]
# 93 (P1)  (OPT) Obj Primal -3.1767e-14 Dual 0.0000e+00
# 722 (P2)  (OPT) Obj Primal -7.5572e+02 Dual -7.5572e+02
# [----Begin evaluation----]
# PuLP Eval: con inf=6.3500e-05,var inf=0.0000e+00,obj=-7.5572e+02. Status: 1.
# Solver Eval: con inf=8.4325e-09,var inf=1.6038e-10,obj=-7.5572e+02. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.055, Solver = 0.572.
# Two solvers match: PuLP = -7.5572e+02, Solver = -7.5572e+02.
#
# Problem name: FFFFF800, size: ((524, 854),6227).
# [----Launch PuLP----]
# [----Launch Solver----]
# 100 (P2)  WARN Con inf.
# 200 (P2)  WARN Con inf.
# 300 (P2)  WARN Con inf.
# 500 (P2)  WARN Con inf.
# 500 (P2)  WARN Con inf after refactor. cond number of curr basis may be too large.
# 500 (P2)  INFO rollback to a recent feasible solution.
# 500 (P2)  INFO rollback to iter 0 (P1).
# 500 (P2)  INFO max perturb size 1.00e-05.
# 500 (P2)  Obj Primal 0.0000e+00 Dual 0.0000e+00  Primal Inf 1.4521e+06 (153)
# 501 (P1)  (OPT) Obj Primal 0.0000e+00 Dual 0.0000e+00
# 600 (P2)  WARN Con inf.
# 600 (P2)  WARN Dual inf after refactor.
# 600 (P2)  Obj Primal 3.0121e+04 Dual 3.0121e+04  Primal Inf 2.6774e+10 (202)  Dual Inf 5.0145e-07 (1)
# 603 (P1)  (OPT) Obj Primal -8.9415e-14 Dual 0.0000e+00
# 700 (P2)  WARN Con inf.
# 700 (P2)  WARN Dual inf after refactor.
# 700 (P2)  Obj Primal 1.7733e+05 Dual 1.7733e+05  Primal Inf 1.3026e+08 (161)  Dual Inf 5.0150e-07 (1)
# 708 (P1)  (OPT) Obj Primal -3.9431e-19 Dual 0.0000e+00
# 800 (P2)  WARN Con inf.
# 900 (P2)  WARN Con inf.
# 1454 (P2)  WARN pivot size -9.1756e-06.
# 1474 (P2)  (OPT) Obj Primal 5.5569e+05 Dual 5.5569e+05
# [----Begin evaluation----]
# PuLP Eval: con inf=1.6374e-02,var inf=0.0000e+00,obj=5.5568e+05. Status: 1.
# Solver Eval: con inf=1.1983e-07,var inf=1.3344e-09,obj=5.5568e+05. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.137, Solver = 1.131.
# Two solvers match: PuLP = 5.5568e+05, Solver = 5.5568e+05.
#
# Problem name: FINNIS, size: ((497, 614),2310).
# [----Launch PuLP----]
# [----Launch Solver----]
# 7 (P1)  (OPT) Obj Primal 0.0000e+00 Dual 0.0000e+00
# 357 (P2)  (OPT) Obj Primal 1.7279e+05 Dual 1.7279e+05
# [----Begin evaluation----]
# PuLP Eval: con inf=3.7067e-04,var inf=1.0100e-04,obj=1.7279e+05. Status: 1.
# Solver Eval: con inf=4.0467e-11,var inf=3.8607e-12,obj=1.7279e+05. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.056, Solver = 0.217.
# Two solvers match: PuLP = 1.7279e+05, Solver = 1.7279e+05.
#
# Problem name: FIT1D, size: ((24, 1026),13404).
# [----Launch PuLP----]
# [----Launch Solver----]
# 68 (P2)  (OPT) Obj Primal -9.1464e+03 Dual -9.1464e+03
# [----Begin evaluation----]
# PuLP Eval: con inf=7.2480e-06,var inf=0.0000e+00,obj=-9.1464e+03. Status: 1.
# Solver Eval: con inf=1.3432e-09,var inf=0.0000e+00,obj=-9.1464e+03. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.137, Solver = 0.082.
# Two solvers match: PuLP = -9.1464e+03, Solver = -9.1464e+03.
#
# Problem name: FIT1P, size: ((627, 1677),9868).
# [----Launch PuLP----]
# [----Launch Solver----]
# 916 (P2)  (OPT) Obj Primal 9.1464e+03 Dual 9.1464e+03
# [----Begin evaluation----]
# PuLP Eval: con inf=1.9123e-04,var inf=0.0000e+00,obj=9.1464e+03. Status: 1.
# Solver Eval: con inf=3.6994e-08,var inf=0.0000e+00,obj=9.1464e+03. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.238, Solver = 0.751.
# Two solvers match: PuLP = 9.1464e+03, Solver = 9.1464e+03.
# Problem name: FORPLAN, size: ((161, 422),4564).
# [----Launch PuLP----]
# [----Launch Solver----]
# 36 (P1)  (OPT) Obj Primal -1.9852e-11 Dual 0.0000e+00
# 275 (P2)  (OPT) Obj Primal -6.6422e+02 Dual -6.6422e+02
# [----Begin evaluation----]
# PuLP Eval: con inf=6.0633e-03,var inf=0.0000e+00,obj=-6.6422e+02. Status: 1.
# Solver Eval: con inf=4.9643e-06,var inf=2.4401e-09,obj=-6.6422e+02. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.057, Solver = 0.170.
# Two solvers match: PuLP = -6.6422e+02, Solver = -6.6422e+02.
#
# Problem name: GANGES, size: ((1309, 1681),6912).
# [----Launch PuLP----]
# [----Launch Solver----]
# 1349 (P2)  (OPT) Obj Primal -1.0959e+05 Dual -1.0959e+05
# [----Begin evaluation----]
# PuLP Eval: con inf=2.1363e-02,var inf=2.3675e-12,obj=-1.0959e+05. Status: 1.
# Solver Eval: con inf=7.0365e-10,var inf=1.5872e-15,obj=-1.0959e+05. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.122, Solver = 0.973.
# Two solvers match: PuLP = -1.0959e+05, Solver = -1.0959e+05.
#
# Problem name: GFRD-PNC, size: ((616, 1092),2377).
# [----Launch PuLP----]
# [----Launch Solver----]
# 574 (P2)  (OPT) Obj Primal 6.9022e+06 Dual 6.9022e+06
# [----Begin evaluation----]
# PuLP Eval: con inf=2.0308e-04,var inf=0.0000e+00,obj=6.9022e+06. Status: 1.
# Solver Eval: con inf=4.6920e-09,var inf=2.1487e-11,obj=6.9022e+06. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.066, Solver = 0.317.
# Two solvers match: PuLP = 6.9022e+06, Solver = 6.9022e+06.
#
# Problem name: GREENBEA, size: ((2392, 5405),30877).
# [----Launch PuLP----]
# [----Launch Solver----]
# 2731 (P1)  (PRIMAL_INFEAS) Obj Primal 1.1114e-09 Dual -9.9880e-11  Primal Inf 6.6874e-07 (4)
# 2800 (P2)  WARN Con inf.
# 3100 (P2)  WARN Con inf.
# 3800 (P2)  WARN Con inf.
# 4000 (P2)  WARN Con inf.
# 4200 (P2)  WARN Con inf.
# 4400 (P2)  WARN Con inf.
# 5139 (P2)  WARN pivot size 1.8993e-07.
# 5169 (P2)  (OPT) Obj Primal -7.2555e+07 Dual -7.2555e+07
# [----Begin evaluation----]
# PuLP Eval: con inf=1.3904e+01,var inf=4.3108e-25,obj=-7.2555e+07. Status: 1.
# Solver Eval: con inf=2.0973e-06,var inf=9.3985e-09,obj=-7.2555e+07. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 1.389, Solver = 11.766.
# Two solvers match: PuLP = -7.2555e+07, Solver = -7.2555e+07.
#
# Problem name: GREENBEB, size: ((2392, 5405),30877).
# [----Launch PuLP----]
# [----Launch Solver----]
# 301 (P1)  (OPT) Obj Primal -1.4736e-11 Dual 0.0000e+00
# 711 (P2)  WARN pivot size -5.9653e-07.
# 2300 (P2)  WARN Con inf.
# 8172 (P2)  (PRIMAL_INFEAS) Obj Primal -4.3023e+06 Dual -4.3023e+06  Primal Inf 1.0285e-06 (2)
# [----Begin evaluation----]
# PuLP Eval: con inf=3.1582e-03,var inf=1.0000e-05,obj=-4.3023e+06. Status: 1.
# Solver Eval: con inf=3.3903e-05,var inf=8.0385e-07,obj=-4.3023e+06. Status: SolveStatus.PRIMAL_INFEAS.
# Elapsed time: PuLP = 1.015, Solver = 15.597.
# Two solvers match: PuLP = -4.3023e+06, Solver = -4.3023e+06.
#
# Problem name: GROW15, size: ((300, 645),5620).
# [----Launch PuLP----]
# [----Launch Solver----]
# 1103 (P2)  (OPT) Obj Primal -1.0687e+08 Dual -1.0687e+08
# [----Begin evaluation----]
# PuLP Eval: con inf=4.9750e-01,var inf=5.0707e-10,obj=-1.0687e+08. Status: 1.
# Solver Eval: con inf=2.4028e-05,var inf=0.0000e+00,obj=-1.0687e+08. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.076, Solver = 1.046.
# Two solvers match: PuLP = -1.0687e+08, Solver = -1.0687e+08.
#
# Problem name: GROW22, size: ((440, 946),8252).
# [----Launch PuLP----]
# [----Launch Solver----]
# 400 (P2)  WARN Con inf.
# 1600 (P2)  WARN Con inf.
# 1600 (P2)  WARN Dual inf after refactor.
# 1600 (P2)  Obj Primal -1.6113e+08 Dual -1.6113e+08  Primal Inf 1.8332e+08 (294)  Dual Inf 1.9251e-06 (6)
# 1608 (P1)  (OPT) Obj Primal 1.8658e-14 Dual 0.0000e+00
# 1755 (P2)  WARN pivot size 4.6455e-06.
# 1900 (P2)  WARN Con inf.
# 2059 (P2)  WARN pivot size -7.5324e-07.
# 2267 (P2)  (OPT) Obj Primal -1.6083e+08 Dual -1.6083e+08
# [----Begin evaluation----]
# PuLP Eval: con inf=8.1263e-01,var inf=1.5203e-09,obj=-1.6083e+08. Status: 1.
# Solver Eval: con inf=1.7131e-05,var inf=0.0000e+00,obj=-1.6083e+08. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.119, Solver = 3.397.
# Two solvers match: PuLP = -1.6083e+08, Solver = -1.6083e+08.
#
# Problem name: GROW7, size: ((140, 301),2612).
# [----Launch PuLP----]
# [----Launch Solver----]
# 313 (P2)  (OPT) Obj Primal -4.7788e+07 Dual -4.7788e+07
# [----Begin evaluation----]
# PuLP Eval: con inf=2.1059e-01,var inf=1.4729e-10,obj=-4.7788e+07. Status: 1.
# Solver Eval: con inf=3.8777e-08,var inf=0.0000e+00,obj=-4.7788e+07. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.057, Solver = 0.439.
# Two solvers match: PuLP = -4.7788e+07, Solver = -4.7788e+07.
#
# Problem name: ISRAEL, size: ((174, 142),2269).
# [----Launch PuLP----]
# [----Launch Solver----]
# 139 (P1)  (OPT) Obj Primal 2.8874e-09 Dual 0.0000e+00
# 323 (P2)  (OPT) Obj Primal -8.9664e+05 Dual -8.9664e+05
# [----Begin evaluation----]
# PuLP Eval: con inf=9.6412e-03,var inf=0.0000e+00,obj=-8.9664e+05. Status: 1.
# Solver Eval: con inf=1.4621e-05,var inf=0.0000e+00,obj=-8.9664e+05. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.068, Solver = 0.207.
# Two solvers match: PuLP = -8.9664e+05, Solver = -8.9664e+05.
#
# Problem name: KB2, size: ((43, 41),286).
# [----Launch PuLP----]
# [----Launch Solver----]
# 70 (P2)  (OPT) Obj Primal -1.7499e+03 Dual -1.7499e+03
# [----Begin evaluation----]
# PuLP Eval: con inf=2.1180e-04,var inf=0.0000e+00,obj=-1.7499e+03. Status: 1.
# Solver Eval: con inf=1.3796e-08,var inf=0.0000e+00,obj=-1.7499e+03. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.016, Solver = 0.037.
# Two solvers match: PuLP = -1.7499e+03, Solver = -1.7499e+03.
#
# Problem name: KEN-07, size: ((2426, 3602),8404).
# [----Launch PuLP----]
# [----Launch Solver----]
# 3011 (P2)  (OPT) Obj Primal -6.7952e+08 Dual -6.7952e+08
# [----Begin evaluation----]
# PuLP Eval: con inf=0.0000e+00,var inf=0.0000e+00,obj=-6.7952e+08. Status: 1.
# Solver Eval: con inf=3.8725e-12,var inf=1.9540e-13,obj=-6.7952e+08. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.249, Solver = 3.634.
# Two solvers match: PuLP = -6.7952e+08, Solver = -6.7952e+08.
#
# Problem name: KEN-11, size: ((14694, 21349),49058).
# [----Launch PuLP----]
# [----Launch Solver----]
# 10000 (P2)  Obj Primal -7.7153e+09 Dual -7.7153e+09  Primal Inf 1.5367e+05 (4799)
# 17552 (P2)  (OPT) Obj Primal -6.9724e+09 Dual -6.9724e+09
# [----Begin evaluation----]
# PuLP Eval: con inf=0.0000e+00,var inf=0.0000e+00,obj=-6.9724e+09. Status: 1.
# Solver Eval: con inf=1.1051e-10,var inf=1.9185e-11,obj=-6.9724e+09. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 2.286, Solver = 132.127.
# Two solvers match: PuLP = -6.9724e+09, Solver = -6.9724e+09.
#
# Problem name: LOTFI, size: ((153, 308),1078).
# [----Launch PuLP----]
# [----Launch Solver----]
# 100 (P1)  (OPT) Obj Primal 1.4211e-14 Dual 0.0000e+00
# 301 (P2)  (OPT) Obj Primal -2.5265e+01 Dual -2.5265e+01
# [----Begin evaluation----]
# PuLP Eval: con inf=8.8211e-03,var inf=1.9351e-11,obj=-2.5265e+01. Status: 1.
# Solver Eval: con inf=5.6280e-08,var inf=4.2473e-12,obj=-2.5265e+01. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.083, Solver = 0.210.
# Two solvers match: PuLP = -2.5265e+01, Solver = -2.5265e+01.
#
# Problem name: MAROS, size: ((846, 1443),9614).
# [----Launch PuLP----]
# [----Launch Solver----]
# 997 (P1)  (OPT) Obj Primal 1.2750e-10 Dual 1.2880e-13
# 1200 (P2)  WARN Con inf.
# 1400 (P2)  WARN Con inf.
# 1849 (P2)  (PRIMAL_INFEAS) Obj Primal -5.8064e+04 Dual -5.8064e+04  Primal Inf 5.7176e-07 (2)
# [----Begin evaluation----]
# PuLP Eval: con inf=1.0981e-01,var inf=0.0000e+00,obj=-5.8064e+04. Status: 1.
# Solver Eval: con inf=1.2920e-06,var inf=1.7371e-08,obj=-5.8064e+04. Status: SolveStatus.PRIMAL_INFEAS.
# Elapsed time: PuLP = 0.205, Solver = 2.648.
# Two solvers match: PuLP = -5.8064e+04, Solver = -5.8064e+04.
#
# Problem name: MODSZK1, size: ((687, 1620),3168).
# [----Launch PuLP----]
# [----Launch Solver----]
# 67 (P1)  (OPT) Obj Primal 0.0000e+00 Dual 0.0000e+00
# 1081 (P2)  (OPT) Obj Primal 3.2062e+02 Dual 3.2063e+02
# [----Begin evaluation----]
# PuLP Eval: con inf=1.0172e-01,var inf=1.4893e-12,obj=3.2062e+02. Status: 1.
# Solver Eval: con inf=1.1215e-08,var inf=1.6656e-11,obj=3.2062e+02. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.154, Solver = 1.270.
# Two solvers match: PuLP = 3.2062e+02, Solver = 3.2062e+02.
#
# Problem name: NESM, size: ((662, 3011),13376).
# [----Launch PuLP----]
# [----Launch Solver----]
# 1205 (P2)  WARN pivot size 5.5093e-06.
# 1620 (P2)  WARN pivot size 8.4187e-06.
# 2336 (P2)  WARN pivot size 2.8059e-06.
# 2670 (P2)  (OPT) Obj Primal 1.4076e+07 Dual 1.4076e+07
# [----Begin evaluation----]
# PuLP Eval: con inf=4.1907e-03,var inf=1.1800e-04,obj=1.4076e+07. Status: 1.
# Solver Eval: con inf=8.9906e-06,var inf=0.0000e+00,obj=1.4076e+07. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.335, Solver = 3.221.
# Two solvers match: PuLP = 1.4076e+07, Solver = 1.4076e+07.
#
# Problem name: PDS-02, size: ((2953, 7535),16390).
# [----Launch PuLP----]
# [----Launch Solver----]
# 2214 (P2)  (OPT) Obj Primal 2.8858e+10 Dual 2.8858e+10
# [----Begin evaluation----]
# PuLP Eval: con inf=0.0000e+00,var inf=0.0000e+00,obj=2.8858e+10. Status: 1.
# Solver Eval: con inf=2.6420e-12,var inf=1.9146e-12,obj=2.8858e+10. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.623, Solver = 3.174.
# Two solvers match: PuLP = 2.8858e+10, Solver = 2.8858e+10.
#
# Problem name: PEROLD, size: ((625, 1376),6018).
# [----Launch PuLP----]
# [----Launch Solver----]
# 128 (P1)  (OPT) Obj Primal 9.9606e-15 Dual 0.0000e+00
# 208 (P2)  WARN pivot size 8.1462e-07.
# 220 (P2)  WARN pivot size 9.4391e-07.
# 300 (P2)  WARN Con inf.
# 300 (P2)  WARN Dual inf after refactor.
# 300 (P2)  Obj Primal -1.0995e+04 Dual -1.0995e+04  Primal Inf 5.7651e+05 (174)  Dual Inf 1.1278e-05 (6)
# 354 (P1)  (OPT) Obj Primal -2.1053e-13 Dual 0.0000e+00
# 358 (P2)  WARN pivot size 1.1879e-07.
# 381 (P2)  WARN pivot size -1.6088e-06.
# 400 (P2)  WARN Dual inf.
# 400 (P2)  WARN Con inf after refactor. cond number of curr basis may be too large.
# 400 (P2)  INFO rollback to a recent feasible solution.
# 400 (P2)  INFO rollback to iter 0 (P1).
# 400 (P2)  INFO max perturb size 1.00e-05.
# 400 (P2)  Obj Primal -7.1366e+16 Dual -7.1366e+16  Primal Inf 3.6140e+20 (405)  Dual Inf 7.1366e+00 (7)  Con Inf 1.2427e+04 (92)  Bnd err 95
# 526 (P1)  (OPT) Obj Primal 9.9577e-15 Dual 0.0000e+00
# 1705 (P2)  (OPT) Obj Primal -9.3686e+03 Dual -9.3686e+03
# [----Begin evaluation----]
# PuLP Eval: con inf=2.5395e-01,var inf=2.9490e-03,obj=-9.3808e+03. Status: 1.
# Solver Eval: con inf=1.1693e-06,var inf=1.7399e-09,obj=-9.3804e+03. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.269, Solver = 2.006.
# Two solvers match: PuLP = -9.3808e+03, Solver = -9.3804e+03.
#
# Problem name: PILOT-JA, size: ((940, 1988),14698).
# [----Launch PuLP----]
# [----Launch Solver----]
# 140 (P1)  (OPT) Obj Primal -1.1628e-14 Dual 0.0000e+00
# 769 (P2)  INFO max shift size: 5.75e-06.
# 800 (P2)  WARN Con inf.
# 1100 (P2)  WARN Con inf.
# 1100 (P2)  WARN Dual inf after refactor.
# 1100 (P2)  Obj Primal -6.5737e+03 Dual -6.5737e+03  Primal Inf 2.5445e+06 (343)  Dual Inf 2.8600e-05 (11)
# 1100 (P1)  INFO max shift size: 1.10e-06.
# 1101 (P1)  INFO max shift size: 1.10e-06.
# 1200 (P1)  WARN Con inf.
# 1200 (P1)  WARN Dual inf after refactor.
# 1200 (P1)  Obj Primal 6.1459e-05 Dual 6.1459e-05  Primal Inf 1.0289e+09 (696)  Dual Inf 2.9115e-06 (1)
# 1200 (P1)  INFO max perturb size 1.00e-05.
# 1216 (P1)  WARN Con inf.
# 1300 (P1)  WARN Con inf.
# 1366 (P1)  WARN pivot size -5.1728e-07.
# 1368 (P1)  WARN pivot size 4.9591e-07.
# 1400 (P1)  WARN Con inf.
# 1500 (P1)  WARN Con inf.
# 1588 (P1)  WARN pivot size 1.0244e-06.
# 1600 (P1)  WARN Con inf.
# 1648 (P1)  WARN pivot size 3.9347e-06.
# 1891 (P1)  WARN pivot size 2.1381e-06.
# 3012 (P1)  (PRIMAL_INFEAS) Obj Primal 2.1553e-10 Dual 0.0000e+00  Primal Inf 1.3844e-04 (86)
# 3021 (P2)  WARN pivot size -8.1430e-06.
# 3021 (P2)  INFO max shift size: 1.53e-03.
# 3049 (P2)  INFO rollback to a recent feasible solution.
# 3049 (P2)  INFO rollback to iter 3000 (P1).
# 3049 (P2)  INFO max perturb size 1.00e-05.
# 3049 (P2)  Obj Primal 6.8540e-06 Dual 1.6369e+09  Primal Inf 2.0000e+16 (272)  Dual Inf 4.2275e-07 (2)  Con Inf 6.5599e+05 (308)  Bnd err 2  Sign err 121
# 3209 (P1)  WARN pivot size 7.3147e-06.
# 3340 (P1)  (PRIMAL_INFEAS) Obj Primal -8.3801e-08 Dual 0.0000e+00  Primal Inf 1.7311e-01 (292)
# 3366 (P2)  INFO max shift size: 1.11e-01.
# 3400 (P2)  WARN Con inf.
# 3400 (P2)  WARN Con inf after refactor. cond number of curr basis may be too large.
# 3400 (P2)  INFO rollback to a recent feasible solution.
# 3400 (P2)  INFO rollback to iter 2500 (P1).
# 3400 (P2)  INFO max perturb size 1.00e-05.
# 3400 (P2)  Obj Primal -2.5173e-06 Dual 1.7905e+09  Primal Inf 1.5000e+17 (278)  Dual Inf 1.3583e-06 (1)  Con Inf 6.5599e+05 (308)  Bnd err 15  Sign err 90
# 3765 (P1)  (PRIMAL_INFEAS) Obj Primal 3.1621e-05 Dual 2.1130e-05  Primal Inf 6.9971e+00 (259)
# 3765 (P1)  INFO max perturb size 1.00e-05.
# 4019 (P1)  INFO rollback to a recent feasible solution.
# 4019 (P1)  INFO rollback to iter 4000 (P1).
# 4019 (P1)  INFO max perturb size 9.99e-06.
# 4038 (P1)  INFO rollback to a recent feasible solution.
# 4038 (P1)  INFO rollback to iter 3500 (P1).
# 4038 (P1)  INFO max perturb size 1.00e-05.
# 4303 (P1)  (PRIMAL_INFEAS) Obj Primal 1.1342e-05 Dual 2.1130e-05  Primal Inf 6.9971e+00 (259)
# 4303 (P1)  INFO max perturb size 9.99e-06.
# 4540 (P1)  WARN pivot size 3.6601e-06.
# 4631 (P1)  (PRIMAL_INFEAS) Obj Primal 2.9717e-09 Dual 0.0000e+00  Primal Inf 1.6636e-01 (239)
# 4635 (P2)  INFO max shift size: 2.03e-05.
# 4648 (P2)  INFO max shift size: 5.51e+01.
# 4649 (P2)  INFO max shift size: 8.88e-02.
# 4650 (P2)  INFO max shift size: 1.76e-05.
# 4651 (P2)  INFO max shift size: 5.42e-05.
# 4653 (P2)  INFO max shift size: 3.58e-05.
# 4668 (P2)  INFO max shift size: 6.89e-05.
# 4673 (P2)  INFO max shift size: 3.90e-02.
# 4700 (P2)  WARN Dual inf.
# 4700 (P2)  WARN Con inf after refactor. cond number of curr basis may be too large.
# 4700 (P2)  INFO rollback to a recent feasible solution.
# 4700 (P2)  INFO rollback to iter 4500 (P1).
# 4700 (P2)  INFO max perturb size 1.00e-05.
# 4700 (P2)  Obj Primal 1.2660e-06 Dual 2.1814e+08  Primal Inf 2.0000e+16 (254)  Con Inf 6.5599e+05 (308)  Bnd err 2  Sign err 91
# 4801 (P1)  WARN pivot size -5.0772e-07.
# 4900 (P1)  WARN Con inf.
# 4900 (P1)  WARN Dual inf after refactor.
# 4900 (P1)  Obj Primal 4.4091e-05 Dual 4.4091e-05  Primal Inf 1.1740e+01 (203)  Dual Inf 8.2350e-07 (1)
# 4900 (P1)  INFO max perturb size 1.00e-05.
# 4986 (P1)  INFO rollback to a recent feasible solution.
# 4986 (P1)  INFO rollback to iter 2000 (P1).
# 4986 (P1)  INFO max perturb size 1.00e-05.
# 5998 (P1)  (PRIMAL_INFEAS) Obj Primal 2.3139e-10 Dual 0.0000e+00  Primal Inf 1.3844e-04 (86)
# 6000 (P2)  WARN Dual inf.
# 6000 (P2)  WARN Con inf after refactor. cond number of curr basis may be too large.
# 6000 (P2)  INFO rollback to a recent feasible solution.
# 6000 (P2)  INFO rollback to iter 5500 (P1).
# 6000 (P2)  INFO max perturb size 1.00e-05.
# 6000 (P2)  Obj Primal 7.1730e-05 Dual 3.2397e+09  Primal Inf 1.5000e+17 (279)  Dual Inf 1.5532e-06 (2)  Con Inf 6.5599e+05 (308)  Bnd err 15  Sign err 91
# 6100 (P1)  WARN Con inf.
# 6362 (P1)  INFO rollback to a recent feasible solution.
# 6362 (P1)  INFO rollback to iter 5000 (P1).
# 6362 (P1)  INFO max perturb size 1.00e-05.
# 7081 (P1)  WARN pivot size 9.0714e-06.
# 7095 (P1)  (PRIMAL_INFEAS) Obj Primal 7.9135e-10 Dual 0.0000e+00  Primal Inf 6.5878e-04 (136)
# 7100 (P2)  WARN Dual inf.
# 7100 (P2)  WARN Con inf after refactor. cond number of curr basis may be too large.
# 7100 (P2)  INFO rollback to a recent feasible solution.
# 7100 (P2)  INFO rollback to iter 7000 (P1).
# 7100 (P2)  INFO max perturb size 1.00e-05.
# 7100 (P2)  Obj Primal -5.1412e-05 Dual 4.6397e+09  Primal Inf 1.0000e+17 (261)  Dual Inf 1.1161e-06 (5)  Con Inf 6.5599e+05 (309)  Bnd err 10  Sign err 115
# 7103 (P1)  WARN pivot size -1.9737e-06.
# 7107 (P1)  WARN Con inf.
# 7107 (P1)  WARN Con inf after refactor. cond number of curr basis may be too large.
# 7107 (P1)  INFO rollback to a recent feasible solution.
# 7107 (P1)  INFO rollback to iter 6500 (P1).
# 7107 (P1)  INFO max perturb size 1.00e-05.
# 7744 (P1)  (PRIMAL_INFEAS) Obj Primal -1.8992e-10 Dual 0.0000e+00  Primal Inf 4.9118e-03 (92)
# 7746 (P2)  INFO max shift size: 2.40e-04.
# 7751 (P2)  INFO max shift size: 1.06e-04.
# 7753 (P2)  INFO rollback to a recent feasible solution.
# 7753 (P2)  INFO rollback to iter 7500 (P1).
# 7753 (P2)  INFO max perturb size 1.00e-05.
# 7753 (P2)  Obj Primal 3.6869e-05 Dual 3.3498e+09  Primal Inf 1.0000e+17 (194)  Dual Inf 1.3276e-06 (3)  Con Inf 6.5599e+05 (308)  Bnd err 10  Sign err 85
# 7868 (P1)  INFO rollback to a recent feasible solution.
# 7868 (P1)  INFO rollback to iter 1000 (P2).
# 7868 (P1)  INFO max perturb size 1.00e-05.
# 7868 (P1)  Obj Primal -2.4464e+03 Dual 0.0000e+00  Primal Inf 6.5193e+08 (768)  Con Inf 6.5599e+05 (308)  Sign err 146
# 7868 (P1)  INFO max perturb size 1.00e-05.
# 7868 (P2)  WARN pivot size 5.0896e-07.
# 7868 (P2)  INFO max shift size: 7.93e+00.
# 7870 (P2)  INFO rollback to a recent feasible solution.
# 7870 (P2)  INFO rollback to iter 500 (P2).
# 7870 (P2)  INFO max perturb size 1.00e-05.
# 8139 (P2)  INFO max shift size: 5.75e-06.
# 8200 (P2)  WARN Con inf.
# 8200 (P2)  WARN Dual inf after refactor.
# 8200 (P2)  Obj Primal -5.1565e+03 Dual -5.1565e+03  Primal Inf 5.4182e+05 (321)  Dual Inf 3.8311e+02 (621)
# 8369 (P1)  WARN pivot size -6.8797e-07.
# 8449 (P1)  WARN pivot size 7.7937e-07.
# 9099 (P1)  (PRIMAL_INFEAS) Obj Primal 2.0983e-05 Dual 2.0845e-05  Primal Inf 3.7863e+00 (210)
# 9099 (P1)  INFO max perturb size 1.00e-05.
# 9235 (P1)  WARN pivot size 3.1280e-07.
# 9545 (P1)  (PRIMAL_INFEAS) Obj Primal -9.7509e-12 Dual 0.0000e+00  Primal Inf 2.0077e-05 (5)
# 9556 (P2)  INFO max shift size: 1.58e-06.
# 9561 (P2)  INFO max shift size: 6.92e-04.
# 9580 (P2)  INFO max shift size: 1.49e-04.
# 9581 (P2)  INFO max shift size: 2.13e-04.
# 9589 (P2)  INFO max shift size: 1.19e-03.
# 9600 (P2)  WARN Dual inf.
# 9600 (P2)  WARN Dual inf after refactor.
# 9600 (P2)  Obj Primal -9.9524e+03 Dual -9.9524e+03  Primal Inf 2.5837e+10 (309)  Dual Inf 6.3149e+00 (370)
# 10000 (P1)  Obj Primal 9.9911e-06 Dual 1.0028e-05  Primal Inf 7.3339e+02 (221)
# 10200 (P1)  (PRIMAL_INFEAS) Obj Primal -5.9354e-10 Dual 0.0000e+00  Primal Inf 2.2625e-04 (90)
# 10300 (P2)  WARN Con inf.
# 10300 (P2)  WARN Con inf after refactor. cond number of curr basis may be too large.
# 10300 (P2)  INFO rollback to a recent feasible solution.
# 10300 (P2)  INFO rollback to iter 10000 (P1).
# 10300 (P2)  INFO max perturb size 1.00e-05.
# 10300 (P2)  Obj Primal 3.6991e-05 Dual 1.0027e+09  Primal Inf 1.1000e+17 (248)  Con Inf 6.5599e+05 (318)  Bnd err 11  Sign err 139
# 10411 (P1)  WARN pivot size -2.7947e-06.
# 10582 (P1)  (PRIMAL_INFEAS) Obj Primal -1.1745e-12 Dual 0.0000e+00  Primal Inf 1.0850e-05 (3)
# 10600 (P2)  WARN Con inf.
# 10600 (P2)  WARN Con inf after refactor. cond number of curr basis may be too large.
# 10600 (P2)  INFO rollback to a recent feasible solution.
# 10600 (P2)  INFO rollback to iter 10500 (P1).
# 10600 (P2)  INFO max perturb size 9.99e-06.
# 10600 (P2)  Obj Primal 7.3886e-06 Dual 6.0545e+08  Primal Inf 1.0000e+16 (282)  Dual Inf 7.5646e-07 (1)  Con Inf 6.5599e+05 (307)  Bnd err 1  Sign err 135
# 10943 (P1)  (PRIMAL_INFEAS) Obj Primal -1.2037e-09 Dual 0.0000e+00  Primal Inf 1.2564e-02 (184)
# 10943 (P2)  INFO max shift size: 1.65e-04.
# 10975 (P2)  INFO rollback to a recent feasible solution.
# 10975 (P2)  INFO rollback to iter 9500 (P1).
# 10975 (P2)  INFO max perturb size 1.00e-05.
# 10975 (P2)  Obj Primal 5.9296e-06 Dual 7.3919e+08  Primal Inf 1.0000e+16 (202)  Dual Inf 4.9762e-07 (1)  Con Inf 6.5599e+05 (307)  Bnd err 1  Sign err 112
# 11100 (P1)  WARN Con inf.
# 11119 (P1)  WARN pivot size 9.7431e-06.
# 11701 (P1)  (PRIMAL_INFEAS) Obj Primal 1.0187e-08 Dual 0.0000e+00  Primal Inf 1.6113e-02 (155)
# 11701 (P2)  INFO max shift size: 8.99e-04.
# 11729 (P2)  INFO rollback to a recent feasible solution.
# 11729 (P2)  INFO rollback to iter 11500 (P1).
# 11729 (P2)  INFO max perturb size 1.00e-05.
# 11729 (P2)  Obj Primal -2.7750e-05 Dual -3.4269e+09  Primal Inf 1.2000e+17 (318)  Dual Inf 1.3823e-06 (2)  Con Inf 6.5599e+05 (309)  Bnd err 12  Sign err 140
# 11873 (P1)  WARN pivot size 6.6289e-07.
# 11987 (P1)  (PRIMAL_INFEAS) Obj Primal 2.4781e-10 Dual 0.0000e+00  Primal Inf 3.9659e-05 (50)
# 12000 (P2)  WARN Con inf.
# 12100 (P2)  WARN Con inf.
# 12100 (P2)  WARN Con inf after refactor. cond number of curr basis may be too large.
# 12100 (P2)  INFO rollback to a recent feasible solution.
# 12100 (P2)  INFO rollback to iter 11000 (P1).
# 12100 (P2)  INFO max perturb size 1.00e-05.
# 12100 (P2)  Obj Primal -4.8292e+02 Dual -4.5929e+16  Primal Inf 1.0200e+18 (433)  Dual Inf 4.5929e+00 (88)  Con Inf 6.5599e+05 (307)  Bnd err 102  Sign err 206
# 12434 (P1)  WARN pivot size 6.2517e-06.
# 12734 (P1)  WARN pivot size 7.9843e-06.
# 12912 (P1)  WARN pivot size -6.3133e-06.
# 12939 (P1)  INFO rollback to a recent feasible solution.
# 12939 (P1)  INFO rollback to iter 12500 (P1).
# 12939 (P1)  INFO max perturb size 1.00e-05.
# 13173 (P1)  WARN pivot size 7.9843e-06.
# 13351 (P1)  WARN pivot size -6.3133e-06.
# 13378 (P1)  INFO rollback to a recent feasible solution.
# 13378 (P1)  INFO rollback to iter 13000 (P1).
# 13378 (P1)  INFO max perturb size 1.00e-05.
# 13809 (P1)  WARN pivot size -2.9794e-07.
# 13833 (P1)  (PRIMAL_INFEAS) Obj Primal -1.4508e-11 Dual 0.0000e+00  Primal Inf 7.0775e-05 (69)
# 13840 (P2)  INFO max shift size: 6.26e-03.
# 13846 (P2)  WARN pivot size -6.8531e-06.
# 13846 (P2)  INFO max shift size: 5.09e-01.
# 13848 (P2)  INFO rollback to a recent feasible solution.
# 13848 (P2)  INFO rollback to iter 13500 (P1).
# 13848 (P2)  INFO max perturb size 1.00e-05.
# 13848 (P2)  Obj Primal 3.3054e-05 Dual 3.4170e+09  Primal Inf 8.0000e+16 (207)  Dual Inf 1.2167e-06 (4)  Con Inf 6.5599e+05 (308)  Bnd err 8  Sign err 138
# 14222 (P1)  (OPT) Obj Primal 3.3902e-12 Dual 0.0000e+00
# 14222 (P2)  INFO max shift size: 8.40e-06.
# 14232 (P2)  INFO max shift size: 7.99e-05.
# 14234 (P2)  INFO max shift size: 3.21e-03.
# 14236 (P2)  INFO max shift size: 9.16e+00.
# 14240 (P2)  INFO max shift size: 1.62e+01.
# 14244 (P2)  INFO max shift size: 5.83e+01.
# 14245 (P2)  INFO max shift size: 1.86e-06.
# 14246 (P2)  INFO max shift size: 3.23e-04.
# 14262 (P2)  INFO rollback to a recent feasible solution.
# 14262 (P2)  INFO rollback to iter 14000 (P1).
# 14262 (P2)  INFO max perturb size 1.00e-05.
# 14262 (P2)  Obj Primal 6.0389e-06 Dual 9.6295e+08  Primal Inf 2.0000e+16 (255)  Dual Inf 2.8672e-07 (1)  Con Inf 6.5599e+05 (308)  Bnd err 2  Sign err 131
# 14316 (P1)  WARN pivot size -8.5453e-07.
# 14400 (P1)  INFO rollback to a recent feasible solution.
# 14400 (P1)  INFO rollback to iter 9000 (P1).
# 14400 (P1)  INFO max perturb size 1.00e-05.
# 14499 (P1)  (PRIMAL_INFEAS) Obj Primal 2.3599e-05 Dual 2.0845e-05  Primal Inf 3.7863e+00 (210)
# 14499 (P1)  INFO max perturb size 1.00e-05.
# 14500 (P1)  WARN Con inf.
# 14500 (P1)  WARN Con inf after refactor. cond number of curr basis may be too large.
# 14500 (P1)  INFO rollback to a recent feasible solution.
# 14500 (P1)  INFO rollback to iter 8500 (P1).
# 14500 (P1)  INFO max perturb size 1.00e-05.
# 15099 (P1)  (PRIMAL_INFEAS) Obj Primal 2.4926e-05 Dual 2.0845e-05  Primal Inf 3.7863e+00 (210)
# 15099 (P1)  INFO max perturb size 1.00e-05.
# 15262 (P1)  WARN pivot size 2.2682e-07.
# 15476 (P1)  INFO rollback to a recent feasible solution.
# 15476 (P1)  INFO rollback to iter 15000 (P1).
# 15476 (P1)  INFO max perturb size 1.00e-05.
# 15575 (P1)  (PRIMAL_INFEAS) Obj Primal 3.0164e-05 Dual 2.0845e-05  Primal Inf 3.7863e+00 (210)
# 15575 (P1)  INFO max perturb size 1.00e-05.
# 15816 (P1)  (OPT) Obj Primal 1.7547e-15 Dual 0.0000e+00
# 15846 (P2)  INFO max shift size: 3.51e-02.
# 15861 (P2)  INFO max shift size: 7.28e-02.
# 15900 (P2)  WARN Dual inf.
# 15900 (P2)  WARN Dual inf after refactor.
# 15900 (P2)  Obj Primal -6.5670e+03 Dual -6.5670e+03  Primal Inf 4.5346e+09 (318)  Dual Inf 3.7714e+02 (544)
# 16000 (P1)  WARN Con inf.
# 16138 (P1)  (PRIMAL_INFEAS) Obj Primal -1.4286e-12 Dual 0.0000e+00  Primal Inf 9.1868e-06 (20)
# 16173 (P2)  INFO max shift size: 3.99e-04.
# 16176 (P2)  INFO rollback to a recent feasible solution.
# 16176 (P2)  INFO rollback to iter 15500 (P1).
# 16176 (P2)  INFO max perturb size 1.00e-05.
# 16176 (P2)  Obj Primal 3.0706e-05 Dual 2.8125e+09  Primal Inf 1.1000e+17 (257)  Dual Inf 1.0951e-06 (1)  Con Inf 6.5599e+05 (308)  Bnd err 11  Sign err 87
# 16200 (P1)  WARN Con inf.
# 16665 (P1)  WARN pivot size -8.6179e-06.
# 16684 (P1)  INFO rollback to a recent feasible solution.
# 16684 (P1)  INFO rollback to iter 16500 (P1).
# 16684 (P1)  INFO max perturb size 1.00e-05.
# 16849 (P1)  WARN pivot size -8.6179e-06.
# 16868 (P1)  INFO rollback to a recent feasible solution.
# 16868 (P1)  INFO rollback to iter 8000 (P2).
# 16868 (P1)  INFO max perturb size 1.00e-05.
# 16868 (P1)  Obj Primal -1.2905e+03 Dual 0.0000e+00  Primal Inf 6.7424e+08 (658)  Con Inf 6.5599e+05 (309)  Sign err 135
# 16868 (P1)  INFO max perturb size 9.99e-06.
# 16868 (P2)  INFO max shift size: 4.55e+00.
# 16880 (P2)  INFO max shift size: 8.99e-03.
# 16885 (P2)  INFO max shift size: 4.60e-01.
# 16900 (P2)  WARN Dual inf.
# 16900 (P2)  WARN Dual inf after refactor.
# 16900 (P2)  Obj Primal -5.0592e+03 Dual -5.0592e+03  Primal Inf 3.9552e+06 (323)  Dual Inf 6.5251e+04 (425)
# 17000 (P1)  WARN Con inf.
# 17058 (P1)  WARN pivot size 2.2206e-07.
# 17125 (P1)  WARN pivot size 1.5525e-06.
# 17556 (P1)  WARN pivot size 8.8628e-06.
# 17596 (P1)  WARN pivot size -3.2272e-06.
# 17636 (P1)  WARN pivot size 9.4230e-06.
# 17665 (P1)  WARN pivot size 1.5073e-07.
# 17723 (P1)  (PRIMAL_INFEAS) Obj Primal -6.7586e-08 Dual 0.0000e+00  Primal Inf 7.6821e-03 (96)
# 17800 (P2)  WARN Dual inf.
# 17800 (P2)  WARN Con inf after refactor. cond number of curr basis may be too large.
# 17800 (P2)  INFO rollback to a recent feasible solution.
# 17800 (P2)  INFO rollback to iter 17500 (P1).
# 17800 (P2)  INFO max perturb size 1.00e-05.
# 17800 (P2)  Obj Primal -2.1072e+00 Dual -3.3643e+14  Primal Inf 3.2000e+17 (324)  Dual Inf 3.3643e-02 (31)  Con Inf 6.5603e+05 (691)  Bnd err 32  Sign err 198
# 17822 (P1)  WARN pivot size -6.3180e-06.
# 17900 (P1)  WARN Con inf.
# 18481 (P1)  WARN pivot size 1.4565e-06.
# 18669 (P1)  WARN pivot size 1.2664e-06.
# 18725 (P1)  WARN pivot size 1.1952e-06.
# 18759 (P1)  WARN pivot size -9.6646e-06.
# 18800 (P1)  WARN Con inf.
# 18898 (P1)  WARN pivot size 7.4701e-06.
# 18938 (P1)  INFO rollback to a recent feasible solution.
# 18938 (P1)  INFO rollback to iter 18500 (P1).
# 18938 (P1)  INFO max perturb size 1.00e-05.
# 19107 (P1)  WARN pivot size 1.2664e-06.
# 19163 (P1)  WARN pivot size 1.1952e-06.
# 19197 (P1)  WARN pivot size -9.6646e-06.
# 19200 (P1)  WARN Con inf.
# 19200 (P1)  WARN Dual inf after refactor.
# 19200 (P1)  Obj Primal -2.4786e+00 Dual -2.4786e+00  Primal Inf 1.5274e+06 (350)  Dual Inf 7.0489e+06 (1433)
# 19200 (P1)  INFO max perturb size 1.00e-05.
# 19300 (P1)  WARN Con inf.
# 19356 (P1)  INFO rollback to a recent feasible solution.
# 19356 (P1)  INFO rollback to iter 19000 (P1).
# 19356 (P1)  INFO max perturb size 1.00e-05.
# 19487 (P1)  WARN pivot size -8.5453e-07.
# 19599 (P1)  WARN pivot size 2.1973e-06.
# 19614 (P1)  WARN pivot size 5.6854e-07.
# 19709 (P1)  WARN pivot size -2.4484e-07.
# 19713 (P1)  INFO rollback to a recent feasible solution.
# 19713 (P1)  INFO rollback to iter 19500 (P1).
# 19713 (P1)  INFO max perturb size 1.00e-05.
# 19812 (P1)  WARN pivot size 2.1973e-06.
# 19881 (P1)  WARN pivot size 3.5479e-07.
# 19924 (P1)  WARN pivot size 3.6112e-07.
# 19962 (P1)  WARN pivot size -8.6497e-06.
# 20000 (P1)  Obj Primal -7.5843e-06 Dual 1.1531e-05  Primal Inf 3.2550e+01 (174)
# 20009 (P1)  INFO rollback to a recent feasible solution.
# 20009 (P1)  INFO rollback to iter 20000 (P1).
# 20009 (P1)  INFO max perturb size 1.00e-05.
# 20018 (P1)  INFO rollback to a recent feasible solution.
# 20018 (P1)  INFO rollback to iter 18000 (P1).
# 20018 (P1)  INFO max perturb size 1.00e-05.
# 20499 (P1)  WARN pivot size 1.4565e-06.
# 20687 (P1)  WARN pivot size 1.2664e-06.
# 20743 (P1)  WARN pivot size 1.1952e-06.
# 20777 (P1)  WARN pivot size -9.6646e-06.
# 20800 (P1)  WARN Con inf.
# 20800 (P1)  WARN Dual inf after refactor.
# 20800 (P1)  Obj Primal 1.5811e+00 Dual 1.5811e+00  Primal Inf 7.1767e+05 (316)  Dual Inf 4.4029e+06 (1410)
# 20800 (P1)  INFO max perturb size 1.00e-05.
# 20900 (P1)  WARN Con inf.
# 21014 (P1)  (PRIMAL_INFEAS) Obj Primal 1.2857e-11 Dual 0.0000e+00  Primal Inf 1.5175e-05 (4)
# 21052 (P2)  INFO max shift size: 3.11e-01.
# 21100 (P2)  WARN Con inf.
# 21100 (P2)  WARN Con inf after refactor. cond number of curr basis may be too large.
# 21100 (P2)  INFO rollback to a recent feasible solution.
# 21100 (P2)  INFO rollback to iter 21000 (P1).
# 21100 (P2)  INFO max perturb size 9.99e-06.
# 21100 (P2)  Obj Primal -1.9449e-11 Dual -1.2440e+05  Primal Inf 9.7087e+02 (29)  Con Inf 6.5599e+05 (309)  Sign err 155
# 21168 (P1)  WARN Con inf.
# 21168 (P1)  WARN Dual inf after refactor.
# 21168 (P1)  Obj Primal -4.8389e-01 Dual -4.8389e-01  Primal Inf 1.7299e+06 (308)  Dual Inf 2.6356e-05 (6)
# 21168 (P1)  INFO max perturb size 1.00e-05.
# 21221 (P1)  WARN pivot size -8.5453e-07.
# 21498 (P1)  INFO rollback to a recent feasible solution.
# 21498 (P1)  INFO rollback to iter 20500 (P1).
# 21498 (P1)  INFO max perturb size 1.00e-05.
# 21577 (P1)  WARN pivot size 3.0602e-07.
# 21600 (P1)  WARN Con inf.
# 21600 (P1)  WARN Dual inf after refactor.
# 21600 (P1)  Obj Primal -1.2907e+01 Dual -1.2907e+01  Primal Inf 3.4642e+06 (415)  Dual Inf 1.5848e-01 (88)
# 21600 (P1)  INFO max perturb size 1.00e-05.
# 21756 (P1)  WARN pivot size -9.2765e-07.
# 21871 (P1)  INFO rollback to a recent feasible solution.
# 21871 (P1)  INFO rollback to iter 21500 (P1).
# 21871 (P1)  INFO max perturb size 1.00e-05.
# 22001 (P1)  WARN pivot size 1.0950e-07.
# 22068 (P1)  WARN pivot size 7.9327e-06.
# 22100 (P1)  WARN Con inf.
# 22100 (P1)  WARN Dual inf after refactor.
# 22100 (P1)  Obj Primal -4.0857e-02 Dual -4.0857e-02  Primal Inf 3.2598e+04 (285)  Dual Inf 1.6234e-01 (66)
# 22100 (P1)  INFO max perturb size 1.00e-05.
# 22172 (P1)  WARN pivot size 1.4848e-07.
# 22253 (P1)  WARN pivot size -2.6105e-06.
# 22302 (P1)  INFO rollback to a recent feasible solution.
# 22302 (P1)  INFO rollback to iter 22000 (P1).
# 22302 (P1)  INFO max perturb size 1.00e-05.
# 22303 (P1)  WARN pivot size 1.0950e-07.
# 22342 (P1)  WARN pivot size 6.0571e-06.
# 22718 (P1)  (PRIMAL_INFEAS) Obj Primal -1.0310e-02 Dual -1.1081e-02  Primal Inf 1.0876e+04 (244)
# 22718 (P1)  INFO max perturb size 1.00e-05.
# 22793 (P1)  WARN pivot size 4.0096e-07.
# 22963 (P1)  (PRIMAL_INFEAS) Obj Primal 1.2968e-08 Dual 0.0000e+00  Primal Inf 1.3157e-03 (76)
# 23000 (P2)  WARN Dual inf.
# 23000 (P2)  WARN Con inf after refactor. cond number of curr basis may be too large.
# 23000 (P2)  INFO rollback to a recent feasible solution.
# 23000 (P2)  INFO rollback to iter 22500 (P1).
# 23000 (P2)  INFO max perturb size 1.00e-05.
# 23000 (P2)  Obj Primal -5.0892e-02 Dual -6.3719e+12  Primal Inf 8.0000e+16 (289)  Dual Inf 6.3720e-04 (8)  Con Inf 6.5599e+05 (308)  Bnd err 8  Sign err 184
# 23150 (P1)  WARN pivot size 2.9378e-07.
# 23167 (P1)  WARN pivot size 6.2648e-07.
# 23213 (P1)  (PRIMAL_INFEAS) Obj Primal 1.8227e-07 Dual 0.0000e+00  Primal Inf 1.0571e-02 (98)
# 23300 (P2)  WARN Con inf.
# 23300 (P2)  WARN Con inf after refactor. cond number of curr basis may be too large.
# 23300 (P2)  INFO rollback to a recent feasible solution.
# 23300 (P2)  INFO rollback to iter 0 (P1).
# 23300 (P2)  INFO max perturb size 1.00e-05.
# 23300 (P2)  Obj Primal -4.1301e+16 Dual -4.1301e+16  Primal Inf 3.5475e+20 (457)  Dual Inf 4.1301e+00 (7)  Con Inf 1.0872e+04 (157)  Bnd err 95
# 23430 (P1)  (OPT) Obj Primal -9.6824e-15 Dual 0.0000e+00
# ...
# [----Launch Solver----]
# 150 (P1)  (OPT) Obj Primal 2.2374e-10 Dual 0.0000e+00
# 493 (P2)  (OPT) Obj Primal -1.4753e+07 Dual -1.4753e+07
# [----Begin evaluation----]
# PuLP Eval: con inf=6.4558e-03,var inf=0.0000e+00,obj=-1.4753e+07. Status: 1.
# Solver Eval: con inf=4.1947e-09,var inf=1.2736e-10,obj=-1.4753e+07. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.044, Solver = 0.288.
# Two solvers match: PuLP = -1.4753e+07, Solver = -1.4753e+07.
#
# Problem name: SCAGR7, size: ((129, 140),420).
# [----Launch PuLP----]
# [----Launch Solver----]
# 79 (P1)  (OPT) Obj Primal -2.8334e-11 Dual 0.0000e+00
# 174 (P2)  (OPT) Obj Primal -2.3314e+06 Dual -2.3314e+06
# [----Begin evaluation----]
# PuLP Eval: con inf=4.5610e-04,var inf=0.0000e+00,obj=-2.3314e+06. Status: 1.
# Solver Eval: con inf=2.1184e-10,var inf=0.0000e+00,obj=-2.3314e+06. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.036, Solver = 0.095.
# Two solvers match: PuLP = -2.3314e+06, Solver = -2.3314e+06.
#
# Problem name: SCFXM1, size: ((330, 457),2589).
# [----Launch PuLP----]
# [----Launch Solver----]
# 161 (P1)  (OPT) Obj Primal -6.3360e-13 Dual 0.0000e+00
# 514 (P2)  (OPT) Obj Primal 1.8417e+04 Dual 1.8417e+04
# [----Begin evaluation----]
# PuLP Eval: con inf=5.7525e-04,var inf=2.2086e-08,obj=1.8417e+04. Status: 1.
# Solver Eval: con inf=5.4130e-09,var inf=5.3489e-10,obj=1.8417e+04. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.068, Solver = 0.292.
# Two solvers match: PuLP = 1.8417e+04, Solver = 1.8417e+04.
#
# Problem name: SCFXM2, size: ((660, 914),5183).
# [----Launch PuLP----]
# [----Launch Solver----]
# 281 (P1)  (OPT) Obj Primal -4.3758e-13 Dual 0.0000e+00
# 993 (P2)  (OPT) Obj Primal 3.6660e+04 Dual 3.6660e+04
# [----Begin evaluation----]
# PuLP Eval: con inf=1.5460e-03,var inf=2.4365e-08,obj=3.6660e+04. Status: 1.
# Solver Eval: con inf=2.8298e-08,var inf=1.5048e-10,obj=3.6660e+04. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.091, Solver = 0.674.
# Two solvers match: PuLP = 3.6660e+04, Solver = 3.6660e+04.
#
# Problem name: SCFXM3, size: ((990, 1371),7777).
# [----Launch PuLP----]
# [----Launch Solver----]
# 391 (P1)  (OPT) Obj Primal -1.6919e-12 Dual 0.0000e+00
# 1464 (P2)  (OPT) Obj Primal 5.4901e+04 Dual 5.4901e+04
# [----Begin evaluation----]
# PuLP Eval: con inf=1.5061e-03,var inf=2.4806e-08,obj=5.4901e+04. Status: 1.
# Solver Eval: con inf=4.5944e-08,var inf=1.6047e-10,obj=5.4901e+04. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.153, Solver = 1.135.
# Two solvers match: PuLP = 5.4901e+04, Solver = 5.4901e+04.
#
# Problem name: SCORPION, size: ((388, 358),1426).
# [----Launch PuLP----]
# [----Launch Solver----]
# 339 (P2)  (OPT) Obj Primal 1.8781e+03 Dual 1.8781e+03
# [----Begin evaluation----]
# PuLP Eval: con inf=4.4465e-07,var inf=0.0000e+00,obj=1.8781e+03. Status: 1.
# Solver Eval: con inf=2.6616e-14,var inf=3.1396e-15,obj=1.8781e+03. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.036, Solver = 0.175.
# Two solvers match: PuLP = 1.8781e+03, Solver = 1.8781e+03.
#
# Problem name: SCRS8, size: ((490, 1169),3182).
# [----Launch PuLP----]
# [----Launch Solver----]
# 45 (P1)  (OPT) Obj Primal -7.3081e-13 Dual 0.0000e+00
# 585 (P2)  (OPT) Obj Primal 9.0430e+02 Dual 9.0430e+02
# [----Begin evaluation----]
# PuLP Eval: con inf=1.4005e-05,var inf=0.0000e+00,obj=9.0430e+02. Status: 1.
# Solver Eval: con inf=5.4001e-11,var inf=1.7327e-14,obj=9.0430e+02. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.085, Solver = 0.322.
# Two solvers match: PuLP = 9.0430e+02, Solver = 9.0430e+02.
#
# Problem name: SCSD1, size: ((77, 760),2388).
# [----Launch PuLP----]
# [----Launch Solver----]
# 97 (P2)  (OPT) Obj Primal 8.6667e+00 Dual 8.6667e+00
# [----Begin evaluation----]
# PuLP Eval: con inf=1.9562e-08,var inf=0.0000e+00,obj=8.6667e+00. Status: 1.
# Solver Eval: con inf=1.7638e-14,var inf=1.2433e-14,obj=8.6667e+00. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.063, Solver = 0.048.
# Two solvers match: PuLP = 8.6667e+00, Solver = 8.6667e+00.
#
# Problem name: SCSD6, size: ((147, 1350),4316).
# [----Launch PuLP----]
# [----Launch Solver----]
# 261 (P2)  (OPT) Obj Primal 5.0500e+01 Dual 5.0500e+01
# [----Begin evaluation----]
# PuLP Eval: con inf=1.0431e-07,var inf=0.0000e+00,obj=5.0500e+01. Status: 1.
# Solver Eval: con inf=2.8394e-13,var inf=5.0147e-13,obj=5.0500e+01. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.074, Solver = 0.136.
# Two solvers match: PuLP = 5.0500e+01, Solver = 5.0500e+01.
#
# Problem name: SCSD8, size: ((397, 2750),8584).
# [----Launch PuLP----]
# [----Launch Solver----]
# 961 (P2)  (OPT) Obj Primal 9.0500e+02 Dual 9.0500e+02
# [----Begin evaluation----]
# PuLP Eval: con inf=5.8315e-06,var inf=0.0000e+00,obj=9.0500e+02. Status: 1.
# Solver Eval: con inf=3.3944e-11,var inf=6.2166e-12,obj=9.0500e+02. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.182, Solver = 0.594.
# Two solvers match: PuLP = 9.0500e+02, Solver = 9.0500e+02.
#
# Problem name: SCTAP1, size: ((300, 480),1692).
# [----Launch PuLP----]
# [----Launch Solver----]
# 327 (P2)  (OPT) Obj Primal 1.4122e+03 Dual 1.4123e+03
# [----Begin evaluation----]
# PuLP Eval: con inf=4.7600e-07,var inf=0.0000e+00,obj=1.4122e+03. Status: 1.
# Solver Eval: con inf=2.5864e-12,var inf=6.2612e-14,obj=1.4122e+03. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.038, Solver = 0.162.
# Two solvers match: PuLP = 1.4122e+03, Solver = 1.4122e+03.
#
# Problem name: SCTAP2, size: ((1090, 1880),6714).
# [----Launch PuLP----]
# [----Launch Solver----]
# 769 (P2)  (OPT) Obj Primal 1.7248e+03 Dual 1.7248e+03
# [----Begin evaluation----]
# PuLP Eval: con inf=1.9050e-06,var inf=0.0000e+00,obj=1.7248e+03. Status: 1.
# Solver Eval: con inf=4.7437e-12,var inf=9.4527e-14,obj=1.7248e+03. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.135, Solver = 0.480.
# Two solvers match: PuLP = 1.7248e+03, Solver = 1.7248e+03.
#
# Problem name: SCTAP3, size: ((1480, 2480),8874).
# [----Launch PuLP----]
# [----Launch Solver----]
# 1077 (P2)  (OPT) Obj Primal 1.4240e+03 Dual 1.4240e+03
# [----Begin evaluation----]
# PuLP Eval: con inf=1.8440e-06,var inf=0.0000e+00,obj=1.4240e+03. Status: 1.
# Solver Eval: con inf=5.9683e-12,var inf=1.4484e-13,obj=1.4240e+03. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.149, Solver = 0.738.
# Two solvers match: PuLP = 1.4240e+03, Solver = 1.4240e+03.
#
# Problem name: SEBA, size: ((515, 1035),4359).
# [----Launch PuLP----]
# [----Launch Solver----]
# 439 (P2)  (OPT) Obj Primal 1.5712e+04 Dual 1.5712e+04
# [----Begin evaluation----]
# PuLP Eval: con inf=0.0000e+00,var inf=0.0000e+00,obj=1.5712e+04. Status: 1.
# Solver Eval: con inf=0.0000e+00,var inf=0.0000e+00,obj=1.5712e+04. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.096, Solver = 0.238.
# Two solvers match: PuLP = 1.5712e+04, Solver = 1.5712e+04.
#
# Problem name: SHARE1B, size: ((117, 225),1151).
# [----Launch PuLP----]
# [----Launch Solver----]
# 121 (P1)  (OPT) Obj Primal 5.8496e-12 Dual 0.0000e+00
# 214 (P2)  (OPT) Obj Primal -7.6589e+04 Dual -7.6589e+04
# [----Begin evaluation----]
# PuLP Eval: con inf=5.3243e-02,var inf=0.0000e+00,obj=-7.6589e+04. Status: 1.
# Solver Eval: con inf=1.2870e-08,var inf=0.0000e+00,obj=-7.6589e+04. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.026, Solver = 0.119.
# Two solvers match: PuLP = -7.6589e+04, Solver = -7.6589e+04.
#
# Problem name: SHARE2B, size: ((96, 79),694).
# [----Launch PuLP----]
# [----Launch Solver----]
# 110 (P1)  (OPT) Obj Primal -6.6152e-13 Dual 0.0000e+00
# 187 (P2)  (OPT) Obj Primal -4.1573e+02 Dual -4.1573e+02
# [----Begin evaluation----]
# PuLP Eval: con inf=2.1444e-04,var inf=0.0000e+00,obj=-4.1573e+02. Status: 1.
# Solver Eval: con inf=2.4731e-11,var inf=5.7965e-13,obj=-4.1573e+02. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.021, Solver = 0.109.
# Two solvers match: PuLP = -4.1573e+02, Solver = -4.1573e+02.
#
# Problem name: SHELL, size: ((536, 1775),3556).
# [----Launch PuLP----]
# [----Launch Solver----]
# 567 (P2)  (OPT) Obj Primal 1.2088e+09 Dual 1.2088e+09
# [----Begin evaluation----]
# PuLP Eval: con inf=0.0000e+00,var inf=0.0000e+00,obj=1.2088e+09. Status: 1.
# Solver Eval: con inf=0.0000e+00,var inf=0.0000e+00,obj=1.2088e+09. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.080, Solver = 0.313.
# Two solvers match: PuLP = 1.2088e+09, Solver = 1.2088e+09.
#
# Problem name: SHIP04L, size: ((402, 2118),6332).
# [----Launch PuLP----]
# [----Launch Solver----]
# 409 (P2)  (OPT) Obj Primal 1.7933e+06 Dual 1.7933e+06
# [----Begin evaluation----]
# PuLP Eval: con inf=4.9194e-06,var inf=6.0000e-12,obj=1.7933e+06. Status: 1.
# Solver Eval: con inf=1.4285e-13,var inf=6.3838e-16,obj=1.7933e+06. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.101, Solver = 0.213.
# Two solvers match: PuLP = 1.7933e+06, Solver = 1.7933e+06.
#
# Problem name: SHIP04S, size: ((402, 1458),4352).
# [----Launch PuLP----]
# [----Launch Solver----]
# 410 (P2)  (OPT) Obj Primal 1.7987e+06 Dual 1.7987e+06
# [----Begin evaluation----]
# PuLP Eval: con inf=3.1332e-06,var inf=0.0000e+00,obj=1.7987e+06. Status: 1.
# Solver Eval: con inf=9.5222e-14,var inf=9.0101e-16,obj=1.7987e+06. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.078, Solver = 0.208.
# Two solvers match: PuLP = 1.7987e+06, Solver = 1.7987e+06.
#
# Problem name: SHIP08L, size: ((778, 4283),12802).
# [----Launch PuLP----]
# [----Launch Solver----]
# 727 (P2)  (OPT) Obj Primal 1.9091e+06 Dual 1.9091e+06
# [----Begin evaluation----]
# PuLP Eval: con inf=1.9000e-06,var inf=8.0000e-12,obj=1.9091e+06. Status: 1.
# Solver Eval: con inf=6.9371e-13,var inf=1.0343e-15,obj=1.9091e+06. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.243, Solver = 0.437.
# Two solvers match: PuLP = 1.9091e+06, Solver = 1.9091e+06.
#
# Problem name: SHIP08S, size: ((778, 2387),7114).
# [----Launch PuLP----]
# [----Launch Solver----]
# 680 (P2)  (OPT) Obj Primal 1.9201e+06 Dual 1.9201e+06
# [----Begin evaluation----]
# PuLP Eval: con inf=3.0000e-06,var inf=4.0000e-12,obj=1.9201e+06. Status: 1.
# Solver Eval: con inf=3.8940e-13,var inf=2.1675e-15,obj=1.9201e+06. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.120, Solver = 0.390.
# Two solvers match: PuLP = 1.9201e+06, Solver = 1.9201e+06.
# Problem name: SHIP12L, size: ((1151, 5427),16170).
# [----Launch PuLP----]
# [----Launch Solver----]
# 1203 (P2)  (OPT) Obj Primal 1.4702e+06 Dual 1.4702e+06
# [----Begin evaluation----]
# PuLP Eval: con inf=4.0179e-06,var inf=1.4003e-11,obj=1.4702e+06. Status: 1.
# Solver Eval: con inf=1.4548e-12,var inf=7.6624e-14,obj=1.4702e+06. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.283, Solver = 0.819.
# Two solvers match: PuLP = 1.4702e+06, Solver = 1.4702e+06.
#
# Problem name: SHIP12S, size: ((1151, 2763),8178).
# [----Launch PuLP----]
# [----Launch Solver----]
# 1132 (P2)  (OPT) Obj Primal 1.4892e+06 Dual 1.4892e+06
# [----Begin evaluation----]
# PuLP Eval: con inf=4.2039e-06,var inf=9.0000e-12,obj=1.4892e+06. Status: 1.
# Solver Eval: con inf=1.6349e-12,var inf=8.1528e-14,obj=1.4892e+06. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.163, Solver = 0.721.
# Two solvers match: PuLP = 1.4892e+06, Solver = 1.4892e+06.
#
# Problem name: SIERRA, size: ((1227, 2036),7302).
# [----Launch PuLP----]
# [----Launch Solver----]
# 621 (P2)  WARN pivot size 1.0000e-05.
# 627 (P2)  (OPT) Obj Primal 1.5394e+07 Dual 1.5394e+07
# [----Begin evaluation----]
# PuLP Eval: con inf=2.4576e-12,var inf=1.4211e-14,obj=1.5394e+07. Status: 1.
# Solver Eval: con inf=2.0686e-08,var inf=1.5793e-12,obj=1.5394e+07. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.158, Solver = 0.479.
# Two solvers match: PuLP = 1.5394e+07, Solver = 1.5394e+07.
#
# Problem name: STAIR, size: ((356, 467),3856).
# [----Launch PuLP----]
# [----Launch Solver----]
# 199 (P1)  (OPT) Obj Primal 9.5479e-15 Dual 0.0000e+00
# 419 (P2)  (OPT) Obj Primal -2.5127e+02 Dual -2.5127e+02
# [----Begin evaluation----]
# PuLP Eval: con inf=1.9146e-04,var inf=0.0000e+00,obj=-2.5127e+02. Status: 1.
# Solver Eval: con inf=1.6520e-11,var inf=0.0000e+00,obj=-2.5127e+02. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.065, Solver = 0.309.
# Two solvers match: PuLP = -2.5127e+02, Solver = -2.5127e+02.
#
# Problem name: STANDATA, size: ((359, 1075),3031).
# [----Launch PuLP----]
# [----Launch Solver----]
# 71 (P2)  (OPT) Obj Primal 1.2577e+03 Dual 1.2577e+03
# [----Begin evaluation----]
# PuLP Eval: con inf=1.7764e-15,var inf=0.0000e+00,obj=1.2577e+03. Status: 1.
# Solver Eval: con inf=9.4147e-14,var inf=1.4211e-14,obj=1.2577e+03. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.055, Solver = 0.038.
# Two solvers match: PuLP = 1.2577e+03, Solver = 1.2577e+03.
#
# Problem name: STANDGUB, size: ((361, 1184),3139).
# [----Launch PuLP----]
# [----Launch Solver----]
# 71 (P2)  (OPT) Obj Primal 1.2577e+03 Dual 1.2577e+03
# [----Begin evaluation----]
# PuLP Eval: con inf=1.7764e-15,var inf=0.0000e+00,obj=1.2577e+03. Status: 1.
# Solver Eval: con inf=9.4147e-14,var inf=1.4211e-14,obj=1.2577e+03. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.056, Solver = 0.040.
# Two solvers match: PuLP = 1.2577e+03, Solver = 1.2577e+03.
#
# Problem name: STANDMPS, size: ((467, 1075),3679).
# [----Launch PuLP----]
# [----Launch Solver----]
# 218 (P2)  (OPT) Obj Primal 1.4060e+03 Dual 1.4060e+03
# [----Begin evaluation----]
# PuLP Eval: con inf=1.6059e-13,var inf=0.0000e+00,obj=1.4060e+03. Status: 1.
# Solver Eval: con inf=8.6898e-13,var inf=8.3267e-17,obj=1.4060e+03. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.061, Solver = 0.117.
# Two solvers match: PuLP = 1.4060e+03, Solver = 1.4060e+03.
#
# Problem name: STOCFOR1, size: ((117, 111),447).
# [----Launch PuLP----]
# [----Launch Solver----]
# 108 (P1)  (OPT) Obj Primal 6.5434e-13 Dual 0.0000e+00
# 115 (P2)  (OPT) Obj Primal -4.1132e+04 Dual -4.1132e+04
# [----Begin evaluation----]
# PuLP Eval: con inf=6.7603e-04,var inf=0.0000e+00,obj=-4.1132e+04. Status: 1.
# Solver Eval: con inf=7.3945e-12,var inf=0.0000e+00,obj=-4.1132e+04. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.020, Solver = 0.071.
# Two solvers match: PuLP = -4.1132e+04, Solver = -4.1132e+04.
#
# Problem name: STOCFOR2, size: ((2157, 2031),8343).
# [----Launch PuLP----]
# [----Launch Solver----]
# 1901 (P1)  (OPT) Obj Primal 7.1942e-10 Dual 0.0000e+00
# 2119 (P2)  (OPT) Obj Primal -3.9024e+04 Dual -3.9024e+04
# [----Begin evaluation----]
# PuLP Eval: con inf=1.0366e-02,var inf=0.0000e+00,obj=-3.9024e+04. Status: 1.
# Solver Eval: con inf=1.6708e-09,var inf=1.0152e-12,obj=-3.9024e+04. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.213, Solver = 2.157.
# Two solvers match: PuLP = -3.9024e+04, Solver = -3.9024e+04.
#
# Problem name: TRUSS, size: ((1000, 8806),27836).
# [----Launch PuLP----]
# [----Launch Solver----]
# 10000 (P2)  Obj Primal 2.8589e+05 Dual 2.8589e+05  Primal Inf 4.9520e+05 (289)
# 18829 (P2)  (OPT) Obj Primal 4.5882e+05 Dual 4.5882e+05
# [----Begin evaluation----]
# PuLP Eval: con inf=2.8473e-04,var inf=0.0000e+00,obj=4.5882e+05. Status: 1.
# Solver Eval: con inf=1.8146e-07,var inf=5.7115e-08,obj=4.5882e+05. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 3.682, Solver = 20.661.
# Two solvers match: PuLP = 4.5882e+05, Solver = 4.5882e+05.
#
# Problem name: TUFF, size: ((333, 587),4520).
# [----Launch PuLP----]
# [----Launch Solver----]
# 6 (P1)  (OPT) Obj Primal 0.0000e+00 Dual 0.0000e+00
# 275 (P2)  (OPT) Obj Primal 2.9215e-01 Dual 2.9215e-01
# [----Begin evaluation----]
# PuLP Eval: con inf=2.9937e-04,var inf=0.0000e+00,obj=2.9215e-01. Status: 1.
# Solver Eval: con inf=1.7498e-10,var inf=1.9161e-12,obj=2.9215e-01. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.060, Solver = 0.151.
# Two solvers match: PuLP = 2.9215e-01, Solver = 2.9215e-01.
#
# Problem name: VTP-BASE, size: ((198, 203),908).
# [----Launch PuLP----]
# [----Launch Solver----]
# 2 (P1)  (OPT) Obj Primal 0.0000e+00 Dual 0.0000e+00
# 200 (P2)  (OPT) Obj Primal 1.2983e+05 Dual 1.2983e+05
# [----Begin evaluation----]
# PuLP Eval: con inf=2.6682e-03,var inf=0.0000e+00,obj=1.2983e+05. Status: 1.
# Solver Eval: con inf=5.3832e-10,var inf=1.4692e-11,obj=1.2983e+05. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.024, Solver = 0.105.
# Two solvers match: PuLP = 1.2983e+05, Solver = 1.2983e+05.
#
# Problem name: WOODW, size: ((1098, 8405),37474).
# [----Launch PuLP----]
# [----Launch Solver----]
# 2838 (P2)  (OPT) Obj Primal 1.3045e+00 Dual 1.3045e+00
# [----Begin evaluation----]
# PuLP Eval: con inf=2.0915e-05,var inf=0.0000e+00,obj=1.3045e+00. Status: 1.
# Solver Eval: con inf=4.6381e-08,var inf=1.5585e-11,obj=1.3045e+00. Status: SolveStatus.OPT.
# Elapsed time: PuLP = 0.470, Solver = 3.208.
# Two solvers match: PuLP = 1.3045e+00, Solver = 1.3045e+00.

# %% [markdown]
# 上面的测试结果显示，新的DS实现基本可以正确求解所有测试问题；但是，求解效率相比PuLP还是有很大差距。在下一篇blog/notebook中，我将进一步引入一些预处理手段来提高求解效率。

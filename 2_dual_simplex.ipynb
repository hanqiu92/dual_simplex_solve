# %% [markdown]
# ## 2. 对偶单纯形法
#
# 本notebook对应[这一篇blog post](https://hanqiu92.github.io/blogs/2020/LP_dual_simplex_solver_2_202003/)中的内容，主要包括对对偶单纯形法（DS）的基本实现。
#
# 首先是一些准备工作：导入相关的计算工具包、从文件util_lec_2.py中读取上一个notebook中完成的类：问题类和解类。

# %%
import numpy as np
import scipy.sparse as sp
import scipy.sparse.linalg as splinalg
from scipy.sparse import csc_matrix,csr_matrix,coo_matrix
from util_lec_2 import *

# %% [markdown]
# ### DS单步迭代的实现

# %% [markdown]
# 在这一小节中，我们根据blog post中介绍的算法流程来实现DS的单步迭代。
#
# 下面的代码块中包含了以下模块：
# * SolveStatus类: Enum类，对迭代步的求解状态进行管理
# * Basis: 对基$(B,L,U)$的下标元素进行封装管理，提高代码可读性
# * step: DS单步迭代流程
# * ratio_test: 迭代步中的ratio test部分，由于代码量较多，单独形成一个函数
#
# 具体的实现逻辑可以参考下面代码中的注释。需要特别注意的是，在下面的代码中，一些变量的命名与blog post中存在区别。具体来说，为了方便索引，我们用idxI,idxJ,idxBI,idxNJ来指代$i_B$,$j_N$,$i$,$j$；这也可以理解为我们考虑基于基$(B,L,U)$中顺序的下标$i$,$j$,$B_i$,$N_j$。为了符合Py的命名规范，变量lam_grad,s_grad,xB_grad分别对应$\delta \lambda$,$\delta s$,$\delta x_B$，即单位变动值；而包含delta的相关变量则对应$\Delta$，即实际变动值。

# %%
@unique
class SolveStatus(Enum):
    '''
    求解状态，每步DS迭代后返回，用于判断后续动作
    '''
    ONGOING = 0 ## 继续迭代
    OPT = 1 ## 最优
    PRIMAL_INFEAS = 2 ## 原始不可行
    DUAL_INFEAS = 3 ## 对偶不可行
    OTHER = -2
    ERR = -1
    
class Basis(object):
    '''
    对B和N=L \cup U的元素进行管理
    '''
    def __init__(self,idxB,m):
        self.idxB = idxB.copy()
        self.boolN = np.ones((m,),dtype=bool)
        self.boolN[self.idxB] = False
        self.idxN = np.where(self.boolN)[0]

def step(problem,sol,basis):
    '''
    进行一次对偶单纯形法的迭代
    '''
    ## step 0: 做一些计算准备
    n,m = problem.A.shape
    B = problem.A[:,basis.idxB] ## A_B
    
    ## step 1: pricing, 选出离开下标idxBI = idxB[idxI], 并计算相应对偶变量的单位变化量
    idxB = basis.idxB
    xB = sol.x[idxB]
    primal_inf = np.minimum(xB - problem.l[idxB],0) + np.maximum(xB - problem.u[idxB],0)
    bool_primal_inf = (primal_inf > problem.primal_upper_bound_tol[idxB]) | \
                      (primal_inf < problem.primal_lower_bound_tol[idxB])
    if not np.any(bool_primal_inf):
        ## 原始解可行，因此达到最优
        return SolveStatus.OPT,problem,sol,basis

    ## 否则，根据DSE规则选取离开下标idxBI，并保存相应信息
    ## DSE weight_i = |A_B^{-T}e_i|_2^2        
    DSE_weights = np.zeros((n,))
    for idx in range(n):
        e = np.zeros((n,))
        e[idx] = 1
        DSE_weights[idx] = np.sum(np.square(splinalg.spsolve(B.T,e)))
    idxI = np.argmax(np.square(primal_inf)/DSE_weights)
    idxBI = idxB[idxI]
    primal_gap = primal_inf[idxI]
    dual_grad = abs(primal_gap) ## 原始变量的不可行程度正是对偶问题的梯度

    bool_to_lower_bound = sol.x[idxBI] <= problem.l[idxBI]
    direcDualI = 1 if bool_to_lower_bound else -1 ## 原始变量的移动方向
    
    ## 计算对偶变量的单位变化量
    sB_grad0 = np.zeros((n,))
    sB_grad0[idxI] = 1
    lam_grad0 = splinalg.spsolve(B.T,sB_grad0) ## A_B^{-T}e_i
    s_grad0 = problem.A.T.dot(lam_grad0) ## A^TA_B^{-T}e_i
    if direcDualI == -1:
        lam_grad = lam_grad0
        s_grad = -s_grad0
    else:
        lam_grad = -lam_grad0
        s_grad = s_grad0

    ## step 2: ratio test, 选出进入下标idxNJ = idxN[idxJ]
    status_inner,idxJ,idxNJ,alpha_dual,flip_list = ratio_test(problem,sol,basis,s_grad,dual_grad)
    if status_inner == SolveStatus.PRIMAL_INFEAS:
        return SolveStatus.PRIMAL_INFEAS,problem,sol,basis

    ## step 3: 更新结果
    ## 更新对偶变量
    sol.lam += alpha_dual * lam_grad
    sol.s += alpha_dual * s_grad
    
    ## 更新原始变量
    aNJ = problem.A[:,idxNJ] ## A_j
    xB_grad0 = splinalg.spsolve(B,aNJ) ## A_B^{-1}A_j
    xB_grad = -xB_grad0
    if len(flip_list) > 0:
        ## 对x_N进行翻转
        idx_flip_to_lower = flip_list[sol.sign[flip_list] == VarStatus.AT_UPPER_BOUND.value]
        idx_flip_to_upper = flip_list[sol.sign[flip_list] == VarStatus.AT_LOWER_BOUND.value]
        sol.x[idx_flip_to_lower] = problem.l[idx_flip_to_lower]
        sol.x[idx_flip_to_upper] = problem.u[idx_flip_to_upper]
        sol.sign[idx_flip_to_lower] = VarStatus.AT_LOWER_BOUND.value
        sol.sign[idx_flip_to_upper] = VarStatus.AT_UPPER_BOUND.value
        ## 根据翻转的x_N，更新x_B
        delta_x_flipped = np.zeros((m,))
        delta_x_flipped[idx_flip_to_lower] = -problem.bounds_gap[idx_flip_to_lower]
        delta_x_flipped[idx_flip_to_upper] = problem.bounds_gap[idx_flip_to_upper]
        delta_b_flipped = problem.A.dot(delta_x_flipped)
        delta_xB = - splinalg.spsolve(B,delta_b_flipped)
        sol.x[basis.idxB] += delta_xB
        delta_xBI = delta_xB[idxI]
    else:
        delta_xBI = 0

    ## 然后，计算原始步长，并更新x_j和x_B
    alpha_primal = (-primal_gap - delta_xBI) / xB_grad[idxI]
    sol.x[basis.idxB] += alpha_primal * xB_grad
    sol.x[idxBI] = problem.l[idxBI] if bool_to_lower_bound else problem.u[idxBI]
    sol.sign[idxBI] = VarStatus.AT_LOWER_BOUND.value if bool_to_lower_bound else VarStatus.AT_UPPER_BOUND.value
    sol.x[idxNJ] += alpha_primal
    sol.sign[idxNJ] = VarStatus.OTHER.value ## 进入B

    ## 更新基
    basis.idxB[idxI] = idxNJ
    basis.idxN[idxJ] = idxBI
    basis.boolN[idxBI] = True
    basis.boolN[idxNJ] = False
    sol.s[basis.idxB] = 0

    return SolveStatus.ONGOING,problem,sol,basis

def ratio_test(problem,sol,basis,s_grad,dual_grad):
    idxN,boolN = basis.idxN,basis.boolN 
    
    ## 统计可能会约束对偶步长的对偶变量的下标
    idxL_bounded = np.where((sol.sign == VarStatus.AT_LOWER_BOUND.value) & (s_grad < 0))[0] ## 处于下界，要求s>=0
    idxU_bounded = np.where((sol.sign == VarStatus.AT_UPPER_BOUND.value) & (s_grad > 0))[0] ## 处于上界，要求s<=0
    idxF = np.where((sol.sign == VarStatus.OTHER.value) & boolN)[0] ## free变量，要求s==0
    idxF_bounded = idxF[(np.abs(s_grad[idxF]) > 0)]
    elems_bounded = np.concatenate([idxL_bounded,idxU_bounded,idxF_bounded])

    if len(elems_bounded) == 0:
        ## 没有变量可以约束对偶步长，因此对偶步长可以无限大，从而对偶目标无界/原始解不可行
        status,idxJ,idxNJ,alpha_dual,flip_list = SolveStatus.PRIMAL_INFEAS,-1,-1,0,[]
        return status,idxJ,idxNJ,alpha_dual,flip_list

    ## 针对可能约束对偶步长的变量，进一步判断其是否可以做bound flip；如果可行，则进行相关计算
    bool_not_both_bounded = problem.bool_not_both_bounded[elems_bounded]
    s_grad_bounded = s_grad[elems_bounded]
    ## 计算bound filp对对偶梯度的影响
    s_grad_abs_bounded = np.abs(s_grad_bounded)
    dual_grad_delta_flipped = problem.bounds_gap[elems_bounded] * s_grad_abs_bounded
    if (np.sum(dual_grad_delta_flipped) <= dual_grad) and (not np.any(bool_not_both_bounded)):
        ## 如果所有约束变量都可以做bound flip，而且flip完对偶的梯度仍是正数，则对偶目标无界/原始解不可行
        status,idxJ,idxNJ,delta_dual,flip_list = SolveStatus.PRIMAL_INFEAS,-1,-1,0,[]
        return status,idxJ,idxNJ,delta_dual,flip_list

    ## 计算每个约束变量对应bound flip的临界对偶步长
    alpha_dual_allowed = - sol.s[elems_bounded] / s_grad_bounded
    
    ## 通过不可flip的变量进一步筛选
    if np.any(bool_not_both_bounded):
        alpha_dual_ub = np.min(alpha_dual_allowed[bool_not_both_bounded])
        ## 找到对应最小步长的不可flip变量之前的所有变量
        idxs_remain = np.where(alpha_dual_allowed <= alpha_dual_ub)[0] 
    else:
        ## 考虑全部变量
        idxs_remain = np.arange(len(elems_bounded),dtype=int)

    ## 通过alpha_dual_allowed对各变量进行排序
    idxs_remain = idxs_remain[np.argsort(alpha_dual_allowed[idxs_remain])]
    ## 做线搜索，寻找临界的变量
    dual_grad_remain = dual_grad
    for idx_pivot in idxs_remain:
        dual_grad_remain -= dual_grad_delta_flipped[idx_pivot]
        if dual_grad_remain < 0:
            break
    
    ## 整理结果
    idxNJ = elems_bounded[idx_pivot]
    alpha_dual = alpha_dual_allowed[idx_pivot]
    bool_flip = (alpha_dual_allowed < alpha_dual)
    flip_list = elems_bounded[bool_flip]
    idxJ = np.where(idxN == idxNJ)[0]
    return SolveStatus.ONGOING,idxJ,idxNJ,alpha_dual,flip_list

# %% [markdown]
# 下面，我们实现一个简单的求解流程，来对上述代码进行测试。

# %%
from util import *
import time
import traceback
import glob
np.set_printoptions(suppress=False,precision=4)

def test_w_bound(problem_size,solve_func):    
    evaluator = Evaluator()
    
    fnames = sorted(glob.glob('netlib/*.SIF'))
    for fname in fnames:
        model_name = fname.split('/')[-1].split('.')[0]

        A_dict,b_dict,sense_dict,c_dict,l_dict,u_dict,m,n,row_key,col_key = read_mps(fname)
        A,b,sense,c,l,u = dicts_to_computable(A_dict,b_dict,sense_dict,c_dict,l_dict,u_dict,m,n)

        ## 为了保证对偶可行，将无界改为比较大的上下界
        bound = 1e4
        if np.all(l <= -INF):
            l_new = np.full((m,),-bound)
        else:
            l_new = np.maximum(l,np.min(l[l>-INF])-bound)
        if np.all(u >= INF):
            u_new = np.full((m,),bound)
        else:
            u_new = np.minimum(u,np.max(u[u<INF])+bound)
        bool_all_eq = np.all(sense == 0)

        ## 筛选比较小的问题来进行测试
        if A.nnz < problem_size and bool_all_eq and np.all(l_new <= u_new):
            evaluator.reset(A,b,sense,c,l,u)
            print('Problem name: {}, size:({},{}).'.format(model_name,A.shape,A.nnz))

            l_dict_new = dict([(i,l_new[i]) for i in range(m)])
            u_dict_new = dict([(i,u_new[i]) for i in range(m)])
            try:
                tt = time.time()
                x_pulp,lam_pulp,status_pulp = solve_pulp(A_dict,b_dict,sense_dict,c_dict,l_dict_new,u_dict_new,
                                                         m,n,msg=1)
                time_pulp = time.time() - tt
                print(f"Eval: {evaluator.eval_str(x_pulp)} Status: {status_pulp}. Elapsed time: {time_pulp:.3f}.\n")

                tt = time.time()
                status_ds,sol_ds,basis_ds = solve_func(A,b,sense,c,l_new,u_new)
                x_ds = sol_ds.x
                time_ds = time.time() - tt
                print(f"Eval: {evaluator.eval_str(x_ds)} Status: {status_ds}. Elapsed time: {time_ds:.3f}.\n")

            except Exception as e:
                print(repr(e))
                print(traceback.print_exc())

# %%
def loop(A_raw,b_raw,sense_raw,c_raw,l_raw,u_raw):
    '''
    基于step迭代步的DS求解流程
    '''
    ## 读取数据
    A,b,sense,c,l,u = A_raw.copy(),b_raw.copy(),sense_raw.copy(),c_raw.copy(),l_raw.copy(),u_raw.copy()
    n,m = A.shape
    ## 加上逻辑变量，保证A是满秩的；否则会出现数值问题
    c = np.concatenate([c,np.zeros((n,))])
    l = np.concatenate([l,np.zeros((n,))])
    u = np.concatenate([u,np.zeros((n,))])
    for colidx in range(n):
        ## 对非等式对应的逻辑变量加上上下界
        if sense[colidx] == 1: ## G
            l[m+colidx] = -INF
        elif sense[colidx] == -1: ## L
            u[m+colidx] = INF
    A = sp.hstack([A,sp.eye(n)],format='csc')
    n,m = A.shape

    ## 初始化
    problem = Problem(A,b,c,l,u)
    idxB = np.arange(m-n,m,1,dtype=int)
    basis = Basis(idxB,m)
    
    B = problem.A[:,idxB]
    lam = splinalg.spsolve(B.T,problem.c[idxB])
    s = problem.c - problem.A.T.dot(lam)
    s[idxB] = 0

    boolN = basis.boolN
    sign = np.full((m,),VarStatus.OTHER.value,dtype=int)
    sign[boolN & (s < 0)] = VarStatus.AT_UPPER_BOUND.value
    sign[boolN & (s >= 0)] = VarStatus.AT_LOWER_BOUND.value

    x = np.zeros((m,))
    x[sign == VarStatus.AT_LOWER_BOUND.value] = problem.l[sign == VarStatus.AT_LOWER_BOUND.value]
    x[sign == VarStatus.AT_UPPER_BOUND.value] = problem.u[sign == VarStatus.AT_UPPER_BOUND.value]
    x[idxB] = splinalg.spsolve(B,problem.b - problem.A.dot(x))
    sol = Solution(x,lam,s,sign)

    ## 开始DS迭代流程
    start_time = time.time()
    count = 0
    while True:
        status,problem,sol,basis = step(problem,sol,basis) ## 做一步迭代
        count += 1
        header = '{} '.format(count)
        
        ## 每隔一定迭代步数观察效果
        if ((count % 100 == 0 and count > 0) and (status == SolveStatus.ONGOING)):
            problem.check_sol_status(sol,print_func=print,print_header=header)

        ## 如果最优或者无解，abort
        if status != SolveStatus.ONGOING:
            problem.check_sol_status(sol,print_func=print,print_header=header)
            ## 对原始变量的后处理，去除增加的逻辑变量
            sol.x = sol.x[:(m-n)]
            return status,sol,basis

        ## 限制迭代时长和次数
        if time.time() - start_time > 9.0e2 or count > 1e4:
            print('out of time / iterations.')
            problem.check_sol_status(sol,print_func=print,print_header=header)
            ## 对原始变量的后处理，去除增加的逻辑变量
            sol.x = sol.x[:(m-n)]
            return SolveStatus.OTHER,sol,basis

# %%
test_w_bound(5000,loop)
# Out:
# Problem name: BANDM, size:((305, 472),2494).
# Eval: con inf=9.5659e-05,var inf=0.0000e+00,obj=-1.5863e+02. Status: 1. Elapsed time: 0.049.
#
# 100   Obj Primal -1.2234e+06 Dual -1.2234e+06  Primal Inf 2.4241e+06 (230)
# 162   Obj Primal -5.7584e+05 Dual -5.7584e+05  Primal Inf 2.7332e+06 (222)
# Eval: con inf=2.2583e+06,var inf=1.6345e+05,obj=-5.7584e+05. Status: SolveStatus.PRIMAL_INFEAS. Elapsed time: 20.264.
#
# Problem name: GROW7, size:((140, 301),2612).
# Eval: con inf=2.0063e-01,var inf=2.9632e-10,obj=-4.7788e+07. Status: 1. Elapsed time: 0.056.
#
# 100   Obj Primal -5.3512e+07 Dual -5.3512e+07  Primal Inf 1.1641e+07 (99)
# 200   Obj Primal -4.9523e+07 Dual -4.9523e+07  Primal Inf 2.2535e+06 (76)
# 300   Obj Primal -4.8176e+07 Dual -4.8176e+07  Primal Inf 4.1330e+06 (70)
# 400   Obj Primal -4.7905e+07 Dual -4.7905e+07  Primal Inf 1.3303e+07 (67)
# 471   Obj Primal -4.7788e+07 Dual -4.7788e+07
# Eval: con inf=9.3237e-08,var inf=0.0000e+00,obj=-4.7788e+07. Status: SolveStatus.OPT. Elapsed time: 41.404.
#
# Problem name: MODSZK1, size:((687, 1620),3168).
# Eval: con inf=4.1902e-03,var inf=3.4025e+05,obj=5.9454e+05. Status: -1. Elapsed time: 0.317.
#
# 1   Obj Primal 0.0000e+00 Dual 0.0000e+00  Primal Inf 1.0464e+06 (16)
# Eval: con inf=1.0464e+06,var inf=0.0000e+00,obj=0.0000e+00. Status: SolveStatus.PRIMAL_INFEAS. Elapsed time: 0.243.
#
# Problem name: SCSD1, size:((77, 760),2388).
# Eval: con inf=1.9562e-08,var inf=0.0000e+00,obj=8.6667e+00. Status: 1. Elapsed time: 0.087.
#
# 98   Obj Primal 8.6667e+00 Dual 8.6667e+00
# Eval: con inf=2.9584e-11,var inf=3.1015e-11,obj=8.6667e+00. Status: SolveStatus.OPT. Elapsed time: 2.729.
#
# Problem name: SCSD6, size:((147, 1350),4316).
# Eval: con inf=1.0431e-07,var inf=0.0000e+00,obj=5.0500e+01. Status: 1. Elapsed time: 0.075.
#
# 100   Obj Primal 2.7417e+01 Dual 2.7417e+01  Primal Inf 1.7399e+01 (24)
# 200   Obj Primal 4.7819e+01 Dual 4.7819e+01  Primal Inf 3.1595e+05 (41)
# 269   Obj Primal 5.0500e+01 Dual 5.0500e+01
# Eval: con inf=2.3058e-11,var inf=2.0618e-11,obj=5.0500e+01. Status: SolveStatus.OPT. Elapsed time: 15.098.

# %% [markdown]
# 通过上述测试我们可以看出，虽然本小节中的DS实现能够执行，但存在两个比较严重的问题：
# 1. 结果可能不正确（对于问题BANDM）；
# 2. 计算速度慢。
#
# 在下一小节中，我们先尝试解决第二个问题。

# %% [markdown]
# ### 线性方程求解效率优化

# %% [markdown]
# 通过应用%prun、%lprun等profile工具可以发现，在前一小节的实现中，每步DS迭代中计算时间开销最大的部分是线性方程$Ax=y$的求解。因此，在这一小节中，我们将介绍如何利用DS算法的性质来优化这部分计算的效率，并通过测试来说明这一效率优化的重要性。

# %% [markdown]
# 对于线性方程$Ax=y$，一种常用的做法是先对矩阵$A$做LU分解（其中，$L$是一个下三角矩阵，而$U$是一个上三角矩阵），然后计算$x=U^{-1}L^{-1}y$。（前面用到的scipy.sparse.linalg.spsolve函数就采用了这种做法。）这种做法的好处在于，$L$和$U$都是三角阵，因此$L^{-1}y$和$U^{-1}z$可以高效求解；而且，如果矩阵$A$保持不变的话，LU分解的结果可以复用用于多组线性方程的求解中。然而，LU分解的计算开销是比较大的。注意到DS算法过程具有以下两个性质：
# 1. 每步迭代中我们需要对同一个矩阵$A_B$求解多个线性方程$A_Bx=y$和$A_B^Tx=y$；
# 2. 每步迭代后$A_B$的变化很小。
#
# 因此，如果在线性方程求解中能利用已有的LU分解结果和每步迭代中$A_B$变化的信息，而不是简单地重新做LU分解，则应能提高计算效率。具体来说，在每步迭代后，$A_B$的第$i_B$列（也是$A$的第$i$列）被$A$的第$j$列替代；用矩阵计算的方法表示，则有
# $$
# \begin{aligned}
# A_B & \gets A_B - A_Be_{i_B}e_i^T + A_{j}e_i^T \\
# & = A_B(I + (\delta x_B-e_i)e_i^T),
# \end{aligned}\tag{1}
# $$ 其中$e_i$是$e_{i_B}$的简写（与blog post中保持一致）。换句话说，矩阵$A_B$的更新可以看成是乘上一个只有第$i_B$列非$e_i$的矩阵。这一形式的好处是，$A_B$的逆的更新也可以很方便的表示：
# $$
# \begin{aligned}
# A_B^{-1} & \gets (I + (\delta x_B-e_i)e_i^T)^{-1} A_B^{-1} \\
# & = (I + \eta e_i^T) A_B^{-1},
# \end{aligned}\tag{2}
# $$ 其中$\eta_{i_B}=1/(\delta x_B)_{i_B}-1; \eta_l = -(\delta x_B)_l/(\delta x_B)_{i_B}, \ \forall l\neq i_B$。基于这种表示，在迭代步$k$进行线性方程$A_B^{(k)}x=y$的求解时，相比于直接解$x=(A_B^{(k)})^{-1}y$，我们可以解$x=\prod_{k'=k-1}^{1}E_{k'}(A_B^{(1)})^{-1}y$，其中$E_{k'} = (I + \eta^{(k')}(e_i^{(k')})^T)$。同理，对于问题$(A_B^{(k)})^Tx=y$，我们可以解$x=(A_B^{(1)})^{-T}\prod_{k'=1}^{k-1}E_{k'}^Ty$。这种方法虽然在每次求解中增加了矩阵$E_{k}$乘积的计算量，但省下了LU分解的计算开销，从整体上看是更高效的。

# %% [markdown]
# 上述思路在文献中称为product form of inverse（PFI），是一种经典做法；但目前主流求解器已经不采用这个思路了，而是使用一种称为LU update的思路：在迭代过程中直接对LU分解进行更新。LU update的优点在于能够更好地利用矩阵的稀疏性降低计算成本，而且每次求解的计算量是一定的；相比之下，PFI每次求解的计算量随着迭代步$k$的增长而增长，而且在矩阵$E_{k}$的乘积计算中无法利用$A$的稀疏性。另外，在PFI中，如果在一个迭代步中$(\delta x_B)_{i_B}$很小，那么数值误差会导致$\eta$很不稳定；而LU update可以更好地识别并解决这个问题。不过，LU update是一种局限于单纯形法的技术，因此目前通用的线性方程求解工具包中普遍没有支持这种技术；而直接用脚本语言进行实现无法有效利用其高效率，因此在本系列中暂不做尝试。A. Koberstein在其[博士论文](https://www.researchgate.net/profile/Achim_Koberstein/publication/35632487_The_dual_simplex_method_techniques_for_a_fast_and_stable_implementation_Elektronische_Ressource/links/0a85e52ef5144e9031000000/The-dual-simplex-method-techniques-for-a-fast-and-stable-implementation-Elektronische-Ressource.pdf)的第5章中对LU update进行了简单介绍，有兴趣的读者可以进行参考。一些其他的参考资料包括：
# * LUSOL: Sparse LU for Ax = b. [[link1]](https://stanford.edu/group/SOL/software/lusol/) [[link2]](https://github.com/nwh/lusol)
# * Hyper-sparsity: Hall, J. A., & McKinnon, K. I. (2005). Hyper-sparsity in the revised simplex method and how to exploit it. Computational Optimization and Applications, 32(3), 259-283. [[link]](http://www.optimization-online.org/DB_FILE/2000/11/234.pdf)

# %% [markdown]
# 对于DSE，我们同样可以基于迭代公式(1-2)进行计算上的优化。在DSE的过程中，我们需要对$\forall l\in\{1,\cdots,n\}$计算$\beta_l = |\rho_l|_2^2=\rho_l^{T}\rho_l$，其中$\rho_l$表示$A_B^{-T}e_l$；注意到$\delta\lambda_0=A_B^{-T}e_i=\rho_{i_B}$。根据公式(1-2)，
# $$
# \rho_l \gets A_B^{-T} (I + e_i\eta^T) e_l  = \rho_l + \eta_l \rho_{i_B} = \rho_l + \eta_l \delta\lambda_0
# $$
#
# 因此我们可以推得以下更新方式
# $$
# \begin{aligned}
# \beta_{i_B} & \gets \frac{1}{(\delta x_B)_{i_B}^2}\beta_{i_B}; \\
# \beta_l & \gets \beta_l + \frac{(\delta x_B)_l^2}{(\delta x_B)_{i_B}^2} \beta_i - 2\frac{(\delta x_B)_l}{(\delta x_B)_{i_B}}\rho_l^T \delta\lambda_0  \\
# & = \beta_l + \frac{(\delta x_B)_l^2}{(\delta x_B)_{i_B}^2} \beta_i - 2\frac{(\delta x_B)_l}{(\delta x_B)_{i_B}}\tau_l, \ \forall l \neq i_B, \\
# \end{aligned}\tag{3}
# $$
#
# 其中$\tau=A_B^{-1}\delta \lambda_0$可以通过线性方程求解来计算。

# %% [markdown]
# 下面，我们对上述思路给出代码实现。具体来说，我们考虑以下实现方案：
# 1. Basis类在管理基$(B,L,U)$的下标元素的基础上，进一步负责所有的线性代数相关的计算（相乘/方程求解/LU分解更新）。
# 2. 我们引入DualSimplex类对上面DS算法的各部分（step、ratio_test、solve）进行封装，从而实现更好的对迭代步的管理（目前，仅考虑重新进行LU分解的触发）。

# %%
import numpy as np
import scipy.sparse as sp
import scipy.sparse.linalg as splinalg
from scipy.sparse import csc_matrix,csr_matrix,coo_matrix
from scikits import umfpack
from scikits.umfpack import UMFPACK_A,UMFPACK_At,UMFPACK_Aat

@unique
class LinearSolver(Enum):
    '''
    用于对线性方程求解/LU分解工具的选用，默认是UMFPACK；
    计算实验表明UMFPACK比SUPERLU快20%以上
    '''
    UMFPACK = 0
    SUPERLU = 1

LINEAR_SOLVER_TYPE = LinearSolver.UMFPACK

class BasisPlus(object):
    '''
    在上面Basis类的基础上，进一步引入线性代数相关的计算（相乘/方程求解/LU分解更新）
    '''
    def __init__(self,A,AT=None):
        self.A = A
        if AT is None:
            self.AT = self.A.T
        else:
            self.AT = AT
        self.n,self.m = self.A.shape

        self.idxB,self.idxN,self.boolN = None,None,None
        self.DSE_weights = None ## DSE权重
        self.invB = None ## LU 分解结果
        self.etas = [] ## PFI的连乘部分
        self.eta_count = 0

    def copy(self):
        basis_new = Basis(self.A,self.AT)
        basis_new.invB = self.invB
        basis_new.eta_count = self.eta_count
        basis_new.idxB = self.idxB.copy()
        basis_new.idxN = self.idxN.copy()
        basis_new.boolN = self.boolN.copy()
        basis_new.DSE_weights = self.DSE_weights.copy()
        basis_new.etas = self.etas.copy()
        return basis_new
    
    def reset_basis_idx(self,idxB):
        self.idxB = idxB.copy()
        self.boolN = np.ones((self.m,),dtype=bool)
        self.boolN[self.idxB] = False
        self.idxN = np.where(self.boolN)[0]
        self.lu_factorize()

    def lu_update(self,eta):
        ## 在PFI中，只需要增加\eta向量和对应的位置i_B即可
        self.etas += [eta]
        self.eta_count += 1

    def lu_factorize(self):
        ## 重新做LU分解
        self.B = self.A[:,self.idxB]
        self.etas = []
        self.eta_count = 0

        if LINEAR_SOLVER_TYPE == LinearSolver.SUPERLU:
            self.invB = splinalg.splu(self.B)
        else:
            self.invB = umfpack.splu(self.B)

    def get_col(self,idx):
        ## 对从矩阵A中获取列idx的封装
        ## 需要A是CSC格式的
        idx_start,idx_end = self.A.indptr[idx],self.A.indptr[idx+1]
        data_,row_ = self.A.data[idx_start:idx_end],self.A.indices[idx_start:idx_end]
        col = np.zeros((self.n,))
        col[row_] = data_
        return col

    def get_elem_vec(self,idx,if_transpose=False):
        ## 对获取单位向量e的封装
        if if_transpose:
            e = np.zeros((self.n,))
        else:
            e = np.zeros((self.m,))
        e[idx] = 1
        return e

    def solve(self,y,if_transpose=False):
        ## 基于PFI的线性方程求解
        if if_transpose:
            ## A_B^T x = y
            y_ = y.copy()
            for eta in self.etas[::-1]:
                y_[eta[0]] += np.dot(eta[1],y_)
            if LINEAR_SOLVER_TYPE == LinearSolver.SUPERLU:
                x = self.invB.solve(y_,trans='T')
            else:
                x = self.invB.umf.solve(UMFPACK_Aat, self.invB._A, y_, autoTranspose=True)
        else:
            ## A_B x = y
            if LINEAR_SOLVER_TYPE == LinearSolver.SUPERLU:
                x = self.invB.solve(y)
            else:
                x = self.invB.umf.solve(UMFPACK_A, self.invB._A, y, autoTranspose=True)
            for eta in self.etas:
                x += x[eta[0]] * eta[1]
        return x

    def dot(self,x,if_transpose=False):
        ## 矩阵与向量的相乘
        if if_transpose:
            ## y = A^T x
            return self.AT._mul_vector(x)
        else:
            ## y = A x
            return self.A._mul_vector(x)

    def get_DSE_weight(self,idx):
        ## 计算idx行的DSE权重|A_B^{-T} e_{idx}|_2^2
        e = self.get_elem_vec(idx,if_transpose=True)
        return np.sum(np.square(self.solve(e,if_transpose=True)))

    def init_DSE_weights(self):
        self.DSE_weights = np.ones((self.n,))

    def reset_DSE_weights(self):
        ## 重新计算DSE权重
        self.DSE_weights = np.array([self.get_DSE_weight(i) for i in range(self.n)])

    def update_DSE_weights(self,idxI,xB_grad0,tau,betaI0):
        ## 通过迭代的方式更新DSE权重，参考公式(3)
        alpha_j = xB_grad0[idxI]
        betaI = betaI0 / alpha_j / alpha_j
        self.DSE_weights += xB_grad0 * (xB_grad0 * betaI - 2 / alpha_j * tau)
        self.DSE_weights[idxI] = betaI
        self.DSE_weights = np.maximum(self.DSE_weights,1e-4)

    def get_DSE_weights(self):
        return self.DSE_weights

# %%
class DualSimplexSolver(object):
    def __init__(self):
        ## 保存迭代过程中的信息，用于进行控制流处理
        self.global_info = {'count':0,'start_time':time.time()}

    def _pricing(self,problem,sol,basis):
        idxB = basis.idxB
        xB = sol.x[idxB]
        primal_inf = np.minimum(xB - problem.l[idxB],0) + np.maximum(xB - problem.u[idxB],0)
        bool_primal_inf = (primal_inf > problem.primal_upper_bound_tol[idxB]) | \
                          (primal_inf < problem.primal_lower_bound_tol[idxB])

        if not np.any(bool_primal_inf):
            ## 原始解可行，因此达到最优
            return SolveStatus.OPT,-1,-1,0

        ## 否则，根据DSE规则选取离开下标idxBI，并保存相应信息
        ## DSE weight已经保存在basis中
        idxI = np.argmax(np.square(primal_inf)/basis.DSE_weights)
        idxBI = idxB[idxI]
        primal_gap = primal_inf[idxI]
        return SolveStatus.ONGOING,idxI,idxBI,primal_gap

    def _ratio_test(self,problem,sol,basis,s_grad,dual_grad):
        return ratio_test(problem,sol,basis,s_grad,dual_grad)
    
    def _step(self,problem,sol,basis):
        count = self.global_info.get('count',0)
        header = '{} '.format(count)

        ## step 1: pricing, 选出离开下标idxBI = idxB[idxI], 并计算相应对偶变量的单位变化量
        status_inner,idxI,idxBI,primal_gap = self._pricing(problem,sol,basis)
        if status_inner == SolveStatus.OPT:
            return SolveStatus.OPT,problem,sol,basis
        dual_grad = abs(primal_gap) ## 原始变量的不可行程度正是对偶问题的梯度

        bool_to_lower_bound = sol.x[idxBI] <= problem.l[idxBI]
        direcDualI = 1 if bool_to_lower_bound else -1 ## 原始变量的移动方向
        
        ## 计算对偶变量的单位变化量
        sB_grad0 = basis.get_elem_vec(idxI,if_transpose=True) ## A_B^{-T}e_I
        lam_grad0 = basis.solve(sB_grad0,if_transpose=True) ## A_B^{-T}e_I
        s_grad0 = basis.dot(lam_grad0,if_transpose=True) ## A^TA_B^{-T}e_I
        if direcDualI == -1:
            lam_grad = lam_grad0
            s_grad = -s_grad0
        else:
            lam_grad = -lam_grad0
            s_grad = s_grad0

        ## step 2: ratio test, 选出进入下标idxNJ = idxN[idxJ]
        status_inner,idxJ,idxNJ,alpha_dual,flip_list = self._ratio_test(problem,sol,basis,s_grad,dual_grad)
        if status_inner == SolveStatus.PRIMAL_INFEAS:
            return SolveStatus.PRIMAL_INFEAS,problem,sol,basis

        ## step 3: 更新结果
        
        aNJ = basis.get_col(idxNJ) ## A_j
        xB_grad0 = basis.solve(aNJ,if_transpose=False) ## A_B^{-1}A_j
        xB_grad = - xB_grad0
        betaI = np.dot(lam_grad0,lam_grad0)
        tau = basis.solve(lam_grad0,if_transpose=False)
        
        ## 校核数值稳定性，在这一个notebook中只做评估而不进行处理
        if True:
            ## 校核通过\delta s和\delta x_B计算得到的alpha = e_I^T A_B^{-1} a_{NJ}的一致性
            err_pivot = s_grad0[idxNJ] + xB_grad[idxI]
            if abs(err_pivot) > PRIMAL_TOL * (1 + abs(xB_grad[idxI])):
                print('{}  WARN err FTRAN/BTRAN pivot consistency {:.4e}.'.format(header,err_pivot))
            ## 校核DSE权重的准确性
            err_dse = betaI - basis.DSE_weights[idxI]
            if abs(err_dse) > PIVOT_TOL * 10:
                print('{}  WARN err DSE accuracy {:.4e}.'.format(header,err_dse))
        
        ## 更新对偶变量
        sol.lam += alpha_dual * lam_grad
        sol.s += alpha_dual * s_grad

        ## 更新原始变量  
        if len(flip_list) > 0:
            ## 对x_N进行翻转
            idx_flip_to_lower = flip_list[sol.sign[flip_list] == VarStatus.AT_UPPER_BOUND.value]
            idx_flip_to_upper = flip_list[sol.sign[flip_list] == VarStatus.AT_LOWER_BOUND.value]
            sol.x[idx_flip_to_lower] = problem.l[idx_flip_to_lower]
            sol.x[idx_flip_to_upper] = problem.u[idx_flip_to_upper]
            sol.sign[idx_flip_to_lower] = VarStatus.AT_LOWER_BOUND.value
            sol.sign[idx_flip_to_upper] = VarStatus.AT_UPPER_BOUND.value
            ## 根据翻转的x_N，更新x_B
            delta_x_flipped = np.zeros((basis.m,))
            delta_x_flipped[idx_flip_to_lower] = -problem.bounds_gap[idx_flip_to_lower]
            delta_x_flipped[idx_flip_to_upper] = problem.bounds_gap[idx_flip_to_upper]
            delta_b_flipped = basis.dot(delta_x_flipped,if_transpose=False)
            delta_xB = - basis.solve(delta_b_flipped,if_transpose=False)
            sol.x[basis.idxB] += delta_xB
            delta_xBI = delta_xB[idxI]
        else:
            delta_xBI = 0

        ## 然后，计算原始步长，并更新x_j和x_B
        alpha_primal = (-primal_gap - delta_xBI) / xB_grad[idxI]
        sol.x[basis.idxB] += alpha_primal * xB_grad
        sol.x[idxBI] = problem.l[idxBI] if bool_to_lower_bound else problem.u[idxBI]
        sol.sign[idxBI] = VarStatus.AT_LOWER_BOUND.value if bool_to_lower_bound else VarStatus.AT_UPPER_BOUND.value
        sol.x[idxNJ] += alpha_primal
        sol.sign[idxNJ] = VarStatus.OTHER.value ## 进入B

        ## 更新基
        basis.idxB[idxI] = idxNJ
        basis.idxN[idxJ] = idxBI
        basis.boolN[idxBI] = True
        basis.boolN[idxNJ] = False
        ## 更新PFI和DSE信息
        eta_vec = -xB_grad0 / xB_grad0[idxI]
        eta_vec[idxI] += 1 / xB_grad0[idxI]
        eta = (idxI,eta_vec)
        basis.lu_update(eta=eta)
        basis.update_DSE_weights(idxI,xB_grad0,tau,betaI)        
        sol.s[basis.idxB] = 0

        return SolveStatus.ONGOING,problem,sol,basis


    def compute_sol_from_basis(self,problem,basis,sign=None):
        '''
        给定一组基，计算对应的解。如果sign没有给出，则这组基是狭义基，不在B中的元素的L/U属性将按照对偶变量s的符号给出
        '''
        idxB,boolN,m = basis.idxB,basis.boolN,basis.m
        
        ## A^T \lambda + s = c, s_B = 0
        lam = basis.solve(problem.c[idxB],if_transpose=True)
        s = problem.c - basis.dot(lam,if_transpose=True)
        s[idxB] = 0
        if sign is None:
            sign = VarStatus.OTHER.value * np.ones((m,),dtype=int)
            sign[boolN & (s < 0)] = VarStatus.AT_UPPER_BOUND.value
            sign[boolN & (s >= 0)] = VarStatus.AT_LOWER_BOUND.value

        ## A_B x_B + A_L x_L + A_U x_U = b, x_L = l_L, x_U = u_U
        x = np.zeros((m,))
        x[sign == VarStatus.AT_LOWER_BOUND.value] = problem.l[sign == VarStatus.AT_LOWER_BOUND.value]
        x[sign == VarStatus.AT_UPPER_BOUND.value] = problem.u[sign == VarStatus.AT_UPPER_BOUND.value]
        x[idxB] = basis.solve(problem.b - basis.dot(x,if_transpose=False),if_transpose=False)

        sol = Solution(x,lam,s,sign)
        return sol

    def refactorize(self,problem,sol,basis):
        '''
        重新做LU分解并计算解，降低数值误差
        '''
        try:
            basis.lu_factorize()
        except Exception as e:
            print(e)
            return problem,sol,basis
        if sol is not None:
            sol = self.compute_sol_from_basis(problem,basis,sign=sol.sign)
        else:
            sol = self.compute_sol_from_basis(problem,basis)
        return problem,sol,basis
    
    def _loop(self,problem,sol,basis):
        '''
        对迭代步之间进行管理
        '''
        count = self.global_info.get('count',0)
        start_time = self.global_info.get('start_time',time.time())
        while True:
            if count % 5000 == 0 and count > 0:
                print('resetting the DSE weights!')
                basis.reset_DSE_weights() ## DSE更新
            if basis.eta_count % 20 == 0 and count > 0:
                basis.lu_factorize() ## LU分解
                
            status,problem,sol,basis = self._step(problem,sol,basis) ## 做一步迭代
            count += 1
            self.global_info['count'] = count
            header = '{} '.format(count)

            ## 每隔一定迭代步数观察效果
            if ((count % 1000 == 0 and count > 0) and (status == SolveStatus.ONGOING)):
                problem.check_sol_status(sol,print_func=print,print_header=header)

            ## 如果最优或者无解，abort
            if status != SolveStatus.ONGOING:
                problem.check_sol_status(sol,print_func=print,print_header=header)
                return status,problem,sol,basis

            ## 限制迭代时长和次数
            if time.time() - start_time > 9.0e2 or count > 1e5:
                print('out of time / iterations.')
                problem.check_sol_status(sol,print_func=print,print_header=header)
                return SolveStatus.OTHER,problem,sol,basis
            
    def _solve(self,problem,sol,basis):
        ## 直接进入DS迭代
        return self._loop(problem,sol,basis)
            
    def solve(self,A_raw,b_raw,sense_raw,c_raw,l_raw,u_raw):
        '''
        主求解入口
        '''
        self.global_info = {'count':0,'start_time':time.time()}

        ## 读取数据
        A,b,sense,c,l,u = A_raw.copy(),b_raw.copy(),sense_raw.copy(),c_raw.copy(),l_raw.copy(),u_raw.copy()
        n,m = A.shape
        ## 加上逻辑变量，保证A是满秩的；否则会出现数值问题
        c = np.concatenate([c,np.zeros((n,))])
        l = np.concatenate([l,np.zeros((n,))])
        u = np.concatenate([u,np.zeros((n,))])
        for colidx in range(n):
            ## 对非等式对应的逻辑变量加上上下界
            if sense[colidx] == 1: ## G
                l[m+colidx] = -INF
            elif sense[colidx] == -1: ## L
                u[m+colidx] = INF
        A = sp.hstack([A,sp.eye(n)],format='csc')

        ## 初始化
        problem = Problem(A,b,c,l,u)
        n,m = A.shape
        idxB = np.arange(m-n,m,1,dtype=int)
        basis = BasisPlus(A)
        basis.init_DSE_weights()
        basis.reset_basis_idx(idxB)
        problem,sol,basis = self.refactorize(problem,sol=None,basis=basis)

        ## 开始求解流程
        status,problem,sol,basis = self._solve(problem,sol,basis)
        
        ## 对原始变量的后处理，去除增加的逻辑变量
        sol.x = sol.x[:(m-n)]

        return status,sol,basis

# %% [markdown]
# 下面，对新的代码实现进行校核。

# %%
ds = DualSimplexSolver()
# test_w_bound(5000,ds.solve)
# test_w_bound(10000,ds.solve)
test_w_bound(50000,ds.solve)
# Out:
# Problem name: BANDM, size:((305, 472),2494).
# Eval: con inf=9.5659e-05,var inf=0.0000e+00,obj=-1.5863e+02. Status: 1. Elapsed time: 0.097.
#
# 162   Obj Primal -7.2056e+05 Dual -7.2056e+05  Primal Inf 2.1287e+06 (213)
# Eval: con inf=1.7871e+06,var inf=2.6871e+05,obj=-7.2056e+05. Status: SolveStatus.PRIMAL_INFEAS. Elapsed time: 0.080.
#
# Problem name: D6CUBE, size:((415, 6184),37704).
# Eval: con inf=1.9556e-04,var inf=3.3172e-10,obj=3.1549e+02. Status: 1. Elapsed time: 0.477.
#
# 413   Obj Primal 3.1549e+02 Dual 3.1549e+02
# Eval: con inf=1.2877e-08,var inf=6.9962e-09,obj=3.1549e+02. Status: SolveStatus.OPT. Elapsed time: 0.387.
#
# Problem name: DFL001, size:((6071, 12230),35632).
# Eval: con inf=7.1516e-05,var inf=1.2856e-13,obj=1.1266e+07. Status: 1. Elapsed time: 10.911.
#
# 1000   Obj Primal 0.0000e+00 Dual 0.0000e+00  Primal Inf 4.8640e+03 (1514)
# 2000   Obj Primal 2.5807e+06 Dual 2.5807e+06  Primal Inf 3.1404e+03 (1431)
# 3000   Obj Primal 3.6822e+06 Dual 3.6822e+06  Primal Inf 1.0754e+04 (1460)
# 4000   Obj Primal 4.8993e+06 Dual 4.8993e+06  Primal Inf 7.3880e+04 (1466)
# 5000   Obj Primal 5.8692e+06 Dual 5.8692e+06  Primal Inf 2.7682e+04 (1318)
# resetting the DSE weights!
# 6000   Obj Primal 6.8822e+06 Dual 6.8822e+06  Primal Inf 7.4088e+04 (1403)
# 7000   Obj Primal 7.6311e+06 Dual 7.6311e+06  Primal Inf 1.3197e+05 (1526)
# 8000   Obj Primal 9.5832e+06 Dual 9.5832e+06  Primal Inf 1.0311e+05 (1333)
# 9000   Obj Primal 9.9735e+06 Dual 9.9735e+06  Primal Inf 2.8776e+05 (1435)
# 10000   Obj Primal 1.0330e+07 Dual 1.0330e+07  Primal Inf 4.4785e+04 (1297)
# resetting the DSE weights!
# 11000   Obj Primal 1.0620e+07 Dual 1.0620e+07  Primal Inf 3.9040e+04 (1387)
# 11695   WARN err DSE accuracy 1.6030e-04.
# 11717   WARN err DSE accuracy 1.7803e-04.
# 11794   WARN err DSE accuracy 1.2730e-04.
# 11808   WARN err DSE accuracy 1.4931e-04.
# 11823   WARN err DSE accuracy 1.5907e-04.
# 11878   WARN err DSE accuracy 2.0977e-04.
# 11918   WARN err DSE accuracy 1.5181e-04.
# 12000   Obj Primal 1.0753e+07 Dual 1.0753e+07  Primal Inf 5.3883e+04 (1499)
# 12026   WARN err DSE accuracy 1.0345e-04.
# 12094   WARN err DSE accuracy 3.3774e-04.
# 12130   WARN err DSE accuracy 1.4833e-04.
# 12132   WARN err DSE accuracy 2.3768e-04.
# 12141   WARN err DSE accuracy 1.4932e-04.
# 12173   WARN err DSE accuracy 1.8035e-04.
# 12252   WARN err DSE accuracy 1.4999e-04.
# 12259   WARN err DSE accuracy 1.2948e-04.
# 12290   WARN err DSE accuracy 2.5292e-04.
# 12326   WARN err DSE accuracy 1.8116e-04.
# 12342   WARN err DSE accuracy 1.5009e-04.
# 12344   WARN err DSE accuracy 1.4997e-04.
# 12371   WARN err DSE accuracy 2.5186e-04.
# 12471   WARN err DSE accuracy 2.6606e-04.
# 12530   WARN err DSE accuracy 2.8378e-04.
# 12619   WARN err DSE accuracy 1.7905e-04.
# 12650   WARN err DSE accuracy 1.3343e-04.
# 12703   WARN err DSE accuracy 2.5798e-04.
# 12704   WARN err DSE accuracy 1.7805e-04.
# 12710   WARN err DSE accuracy 1.7892e-04.
# 12831   WARN err DSE accuracy 1.5906e-04.
# 12852   WARN err DSE accuracy 1.8901e-04.
# 12865   WARN err DSE accuracy 1.5004e-04.
# 12896   WARN err DSE accuracy 1.8031e-04.
# 12902   WARN err DSE accuracy 1.6829e-04.
# 12918   WARN err DSE accuracy 1.7234e-04.
# 12921   WARN err DSE accuracy 2.0565e-04.
# 12950   WARN err DSE accuracy 3.3239e-04.
# 12953   WARN err DSE accuracy 1.6074e-04.
# 12960   WARN err DSE accuracy 2.2223e-04.
# 12969   WARN err DSE accuracy 1.6460e-04.
# 12986   WARN err DSE accuracy 1.1124e-04.
# 12992   WARN err DSE accuracy 1.7723e-04.
# 13000   Obj Primal 1.0957e+07 Dual 1.0957e+07  Primal Inf 1.0714e+05 (1417)
# 13047   WARN err DSE accuracy 2.6384e-04.
# 13052   WARN err DSE accuracy 2.6352e-04.
# 13054   WARN err DSE accuracy 2.6334e-04.
# 13060   WARN err DSE accuracy 1.8024e-04.
# 13071   WARN err DSE accuracy 5.1093e-04.
# 13109   WARN err DSE accuracy 2.6250e-04.
# 13199   WARN err DSE accuracy 1.0275e-04.
# 13211   WARN err DSE accuracy 1.9225e-04.
# 13224   WARN err DSE accuracy 1.0582e-04.
# 13227   WARN err DSE accuracy 2.0101e-04.
# 13228   WARN err DSE accuracy 2.6367e-04.
# 13243   WARN err DSE accuracy 5.1479e-04.
# 13274   WARN err DSE accuracy 2.6899e-04.
# 13276   WARN err DSE accuracy 5.6940e-04.
# 13285   WARN err DSE accuracy 3.6301e-04.
# 13289   WARN err DSE accuracy 5.7167e-04.
# 13299   WARN err DSE accuracy 3.5952e-04.
# 13340   WARN err DSE accuracy 2.2111e-04.
# 13344   WARN err DSE accuracy 1.9780e-04.
# 13378   WARN err DSE accuracy 2.4217e-04.
# 13386   WARN err DSE accuracy 1.8666e-04.
# 13394   WARN err DSE accuracy 2.0070e-04.
# 13406   WARN err DSE accuracy 1.8667e-04.
# 13427   WARN err DSE accuracy 3.8490e-04.
# 13428   WARN err DSE accuracy 1.2555e-04.
# 13447   WARN err DSE accuracy 2.8109e-04.
# 13467   WARN err DSE accuracy 1.9347e-04.
# 13481   WARN err DSE accuracy 2.0125e-04.
# 13494   WARN err DSE accuracy 1.0718e-04.
# 13508   WARN err DSE accuracy 2.1009e-04.
# 13511   WARN err DSE accuracy 1.4467e-04.
# 13520   WARN err DSE accuracy 1.8664e-04.
# 13549   WARN err DSE accuracy 2.6053e-04.
# 13556   WARN err DSE accuracy 2.8711e-04.
# 13557   WARN err DSE accuracy 1.1234e-04.
# 13558   WARN err DSE accuracy 1.8380e-04.
# 13560   WARN err DSE accuracy 1.3872e-04.
# 13605   WARN err DSE accuracy 5.7065e-04.
# 13607   WARN err DSE accuracy 1.1119e-04.
# 13608   WARN err DSE accuracy 1.8891e-04.
# 13618   WARN err DSE accuracy 1.8699e-04.
# 13622   WARN err DSE accuracy 1.2984e-04.
# 13629   WARN err DSE accuracy 1.1980e-04.
# 13635   WARN err DSE accuracy 1.1094e-04.
# 13637   WARN err DSE accuracy 2.0112e-04.
# 13641   WARN err DSE accuracy 6.5725e-04.
# 13658   WARN err DSE accuracy 1.4369e-04.
# 13670   WARN err DSE accuracy 2.6461e-04.
# 13672   WARN err DSE accuracy 3.8124e-04.
# 13683   WARN err DSE accuracy 2.0243e-04.
# 13701   WARN err DSE accuracy 1.2022e-04.
# 13711   WARN err DSE accuracy 4.7674e-04.
# 13719   WARN err DSE accuracy 1.8297e-04.
# 13741   WARN err DSE accuracy 1.1045e-04.
# 13746   WARN err DSE accuracy 1.2686e-04.
# 13764   WARN err DSE accuracy 1.8430e-04.
# 13780   WARN err DSE accuracy 3.8124e-04.
# 13904   WARN err DSE accuracy 2.4032e-04.
# 13938   WARN err DSE accuracy 2.0619e-04.
# 14000   Obj Primal 1.1105e+07 Dual 1.1105e+07  Primal Inf 2.4106e+04 (1374)
# 14017   WARN err DSE accuracy 3.2401e-04.
# 14047   WARN err DSE accuracy 2.9782e-04.
# 14051   WARN err DSE accuracy 2.2798e-04.
# 14133   WARN err DSE accuracy 1.1012e-04.
# 14156   WARN err DSE accuracy 1.0666e-04.
# 14159   WARN err DSE accuracy 1.5228e-04.
# 14205   WARN err DSE accuracy 1.4884e-04.
# 14215   WARN err DSE accuracy 2.0278e-04.
# 14216   WARN err DSE accuracy 2.0230e-04.
# 14220   WARN err DSE accuracy 1.3920e-04.
# 14224   WARN err DSE accuracy 1.2763e-04.
# 14226   WARN err DSE accuracy 3.7703e-04.
# 14230   WARN err DSE accuracy 1.1100e-04.
# 14243   WARN err DSE accuracy 5.8877e-04.
# 14256   WARN err DSE accuracy 1.1006e-04.
# 14261   WARN err DSE accuracy 1.6566e-04.
# 14262   WARN err DSE accuracy 3.9734e-04.
# 14273   WARN err DSE accuracy 3.3234e-04.
# 14274   WARN err DSE accuracy 1.1922e-04.
# 14280   WARN err DSE accuracy 2.2031e-04.
# 14281   WARN err DSE accuracy 1.3068e-04.
# 14288   WARN err DSE accuracy 1.1459e-04.
# 14299   WARN err DSE accuracy 1.1365e-04.
# 14302   WARN err DSE accuracy 1.1593e-04.
# 14322   WARN err DSE accuracy 2.9774e-04.
# 14329   WARN err DSE accuracy 5.0310e-04.
# 14337   WARN err DSE accuracy 7.3815e-04.
# 14342   WARN err DSE accuracy 1.1363e-04.
# 14343   WARN err DSE accuracy 3.2232e-04.
# 14381   WARN err DSE accuracy 1.1233e-04.
# 14390   WARN err DSE accuracy 1.0835e-04.
# 14398   WARN err DSE accuracy 1.4314e-04.
# 14410   WARN err DSE accuracy 4.2194e-04.
# 14412   WARN err DSE accuracy 3.7456e-04.
# 14415   WARN err DSE accuracy 2.0723e-04.
# 14417   WARN err DSE accuracy 3.8506e-04.
# 14418   WARN err DSE accuracy 1.1067e-04.
# 14424   WARN err DSE accuracy 4.4382e-04.
# 14425   WARN err DSE accuracy 1.5166e-04.
# 14426   WARN err DSE accuracy 7.4087e-04.
# 14438   WARN err DSE accuracy 1.1190e-04.
# 14453   WARN err DSE accuracy 1.9356e-04.
# 14472   WARN err DSE accuracy 1.5794e-04.
# 14475   WARN err DSE accuracy 2.2183e-03.
# 14476   WARN err DSE accuracy 1.1251e-04.
# 14477   WARN err DSE accuracy 2.8385e-04.
# 14479   WARN err DSE accuracy 3.3174e-04.
# 14489   WARN err DSE accuracy 1.4976e-04.
# 14493   WARN err DSE accuracy 2.4978e-04.
# 14505   WARN err DSE accuracy 1.7205e-04.
# 14513   WARN err DSE accuracy 1.9739e-04.
# 14515   WARN err DSE accuracy 9.1566e-04.
# 14518   WARN err DSE accuracy 1.2072e-04.
# 14519   WARN err DSE accuracy 2.6328e-04.
# 14520   WARN err DSE accuracy 5.3485e-04.
# 14523   WARN err DSE accuracy 1.0409e-04.
# 14527   WARN err DSE accuracy 2.2324e-04.
# 14528   WARN err DSE accuracy 6.9554e-04.
# 14531   WARN err DSE accuracy 2.0707e-04.
# 14556   WARN err DSE accuracy 1.0527e-04.
# 14563   WARN err DSE accuracy 1.0260e-04.
# 14581   WARN err DSE accuracy 1.8315e-04.
# 14583   WARN err DSE accuracy 3.4769e-04.
# 14586   WARN err DSE accuracy 1.1881e-04.
# 14591   WARN err DSE accuracy 2.2283e-04.
# 14605   WARN err DSE accuracy 3.0263e-04.
# 14607   WARN err DSE accuracy 1.1997e-04.
# 14611   WARN err DSE accuracy 1.4971e-04.
# 14628   WARN err DSE accuracy 1.7958e-04.
# 14638   WARN err DSE accuracy 1.7083e-04.
# 14642   WARN err DSE accuracy 9.0920e-04.
# 14646   WARN err DSE accuracy 9.3706e-04.
# 14647   WARN err DSE accuracy 1.8669e-04.
# 14655   WARN err DSE accuracy 1.5178e-04.
# 14657   WARN err DSE accuracy 3.3646e-04.
# 14660   WARN err DSE accuracy 2.0282e-04.
# 14662   WARN err DSE accuracy 1.1669e-04.
# 14688   WARN err DSE accuracy 4.8322e-04.
# 14692   WARN err DSE accuracy 1.1644e-04.
# 14709   WARN err DSE accuracy 1.2057e-04.
# 14714   WARN err DSE accuracy 1.8621e-04.
# 14720   WARN err DSE accuracy 3.4782e-04.
# 14721   WARN err DSE accuracy 2.8180e-04.
# 14728   WARN err DSE accuracy 1.6874e-04.
# 14734   WARN err DSE accuracy 1.0571e-04.
# 14736   WARN err DSE accuracy 4.1058e-04.
# 14739   WARN err DSE accuracy 8.5896e-04.
# 14740   WARN err DSE accuracy 1.6955e-04.
# 14748   WARN err DSE accuracy 5.1930e-04.
# 14759   WARN err DSE accuracy 1.4863e-04.
# 14764   WARN err DSE accuracy 1.7171e-04.
# 14766   WARN err DSE accuracy 1.1994e-04.
# 14769   WARN err DSE accuracy 5.4172e-04.
# 14771   WARN err DSE accuracy 4.7329e-04.
# 14773   WARN err DSE accuracy 1.1417e-04.
# 14784   WARN err DSE accuracy 4.5859e-03.
# 14820   WARN err DSE accuracy 5.0320e-04.
# 14822   WARN err DSE accuracy 1.5302e-04.
# 14828   WARN err DSE accuracy 1.3071e-04.
# 14829   WARN err DSE accuracy 4.7293e-04.
# 14846   WARN err DSE accuracy 1.4868e-04.
# 14848   WARN err DSE accuracy 1.7031e-04.
# 14851   WARN err DSE accuracy 4.7718e-04.
# 14867   WARN err DSE accuracy 1.1513e-04.
# 14869   WARN err DSE accuracy 5.4062e-04.
# 14870   WARN err DSE accuracy 7.1361e-04.
# 14873   WARN err DSE accuracy 1.9612e-04.
# 14886   WARN err DSE accuracy 1.2289e-04.
# 14890   WARN err DSE accuracy 1.7683e-04.
# 14901   WARN err DSE accuracy 1.1506e-04.
# 14902   WARN err DSE accuracy 9.7308e-04.
# 14905   WARN err DSE accuracy 4.1769e-04.
# 14907   WARN err DSE accuracy 5.7068e-04.
# 14920   WARN err DSE accuracy 7.8019e-04.
# 14928   WARN err DSE accuracy 2.7116e-04.
# 14940   WARN err DSE accuracy 1.5301e-04.
# 14942   WARN err DSE accuracy 2.9946e-04.
# 14947   WARN err DSE accuracy 1.4228e-04.
# 14959   WARN err DSE accuracy 4.3134e-04.
# 14997   WARN err DSE accuracy 1.7614e-04.
# 15000   Obj Primal 1.1154e+07 Dual 1.1154e+07  Primal Inf 3.1690e+04 (1370)
# resetting the DSE weights!
# 15677   WARN err DSE accuracy 1.6488e-04.
# 16000   Obj Primal 1.1184e+07 Dual 1.1184e+07  Primal Inf 8.5316e+04 (1322)
# 16802   WARN err DSE accuracy 2.0311e-04.
# 16904   WARN err DSE accuracy 2.2600e-04.
# 16905   WARN err DSE accuracy 1.5921e-04.
# 16916   WARN err DSE accuracy 1.1275e-04.
# 16931   WARN err DSE accuracy 1.8313e-04.
# 16932   WARN err DSE accuracy 2.2181e-04.
# 16939   WARN err DSE accuracy 2.5837e-04.
# 16963   WARN err DSE accuracy 1.3796e-04.
# 16965   WARN err DSE accuracy 2.7176e-04.
# 16969   WARN err DSE accuracy 2.6561e-04.
# 17000   Obj Primal 1.1216e+07 Dual 1.1216e+07  Primal Inf 5.1232e+04 (1265)
# 17031   WARN err DSE accuracy 1.2958e-04.
# 17049   WARN err DSE accuracy 1.4093e-04.
# 17052   WARN err DSE accuracy 1.4115e-04.
# 17053   WARN err DSE accuracy 1.3921e-04.
# 17060   WARN err DSE accuracy 2.5968e-04.
# 17065   WARN err DSE accuracy 1.3303e-04.
# 17103   WARN err DSE accuracy 1.5623e-04.
# 17107   WARN err DSE accuracy 1.1766e-04.
# 17125   WARN err DSE accuracy 2.4317e-04.
# 17140   WARN err DSE accuracy 6.7755e-04.
# 17163   WARN err DSE accuracy 1.0433e-03.
# 17167   WARN err DSE accuracy 3.5329e-04.
# 17171   WARN err DSE accuracy 5.8313e-04.
# 17172   WARN err DSE accuracy 1.0858e-04.
# 17176   WARN err DSE accuracy 5.8810e-04.
# 17179   WARN err DSE accuracy 3.8171e-04.
# 17180   WARN err DSE accuracy 8.1286e-04.
# 17183   WARN err DSE accuracy 1.1668e-04.
# 17184   WARN err DSE accuracy 1.1581e-04.
# 17191   WARN err DSE accuracy 1.0901e-04.
# 17192   WARN err DSE accuracy 1.1822e-04.
# 17193   WARN err DSE accuracy 8.9715e-04.
# 17194   WARN err DSE accuracy 1.2204e-04.
# 17198   WARN err DSE accuracy 1.1205e-03.
# 17210   WARN err DSE accuracy 1.0183e-04.
# 17214   WARN err DSE accuracy 1.1630e-03.
# 17217   WARN err DSE accuracy 2.4192e-04.
# 17218   WARN err DSE accuracy 4.2303e-03.
# 17222   WARN err DSE accuracy 4.4418e-03.
# 17223   WARN err DSE accuracy 5.2583e-04.
# 17224   WARN err DSE accuracy 1.0224e-04.
# 17225   WARN err DSE accuracy 4.2240e-04.
# 17226   WARN err DSE accuracy 4.0849e-03.
# 17228   WARN err DSE accuracy 2.4780e-03.
# 17229   WARN err DSE accuracy 1.0107e-04.
# 17231   WARN err DSE accuracy 5.2242e-04.
# 17234   WARN err DSE accuracy 1.7314e-04.
# 17238   WARN err DSE accuracy 3.0782e-04.
# 17239   WARN err DSE accuracy 9.9825e-04.
# 17240   WARN err DSE accuracy 3.1360e-04.
# 17241   WARN err DSE accuracy 1.0349e-04.
# 17245   WARN err DSE accuracy 9.5135e-04.
# 17250   WARN err DSE accuracy 5.1558e-03.
# 17251   WARN err DSE accuracy 5.1560e-03.
# 17252   WARN err DSE accuracy 4.2141e-04.
# 17254   WARN err DSE accuracy 6.6937e-04.
# 17256   WARN err DSE accuracy 7.1992e-04.
# 17264   WARN err DSE accuracy 3.8051e-03.
# 17267   WARN err DSE accuracy 9.1249e-04.
# 17271   WARN err DSE accuracy 2.1343e-04.
# 17272   WARN err DSE accuracy 5.2657e-04.
# 17274   WARN err DSE accuracy 9.3906e-04.
# 17276   WARN err DSE accuracy 1.0842e-02.
# 17277   WARN err DSE accuracy 2.0749e-04.
# 17301   WARN err DSE accuracy 2.5089e-03.
# 17302   WARN err DSE accuracy 3.4606e-04.
# 17303   WARN err DSE accuracy 5.5876e-04.
# 17307   WARN err DSE accuracy 5.2776e-04.
# 17309   WARN err DSE accuracy 4.5011e-04.
# 17310   WARN err DSE accuracy 4.9615e-02.
# 17311   WARN err DSE accuracy 1.0087e-04.
# 17312   WARN err DSE accuracy 7.2632e-04.
# 17314   WARN err DSE accuracy 5.4675e-03.
# 17315   WARN err DSE accuracy 2.5488e-03.
# 17320   WARN err DSE accuracy 2.0018e-04.
# 17326   WARN err DSE accuracy 1.6733e-04.
# 17329   WARN err DSE accuracy 2.9653e-03.
# 17330   WARN err DSE accuracy 1.3392e-03.
# 17331   WARN err DSE accuracy 2.3580e-03.
# 17338   WARN err DSE accuracy 1.4411e-02.
# 17339   WARN err DSE accuracy 5.2049e-04.
# 17340   WARN err DSE accuracy 1.2887e-02.
# 17341   WARN err DSE accuracy 1.3560e-03.
# 17345   WARN err DSE accuracy 1.9788e-04.
# 17347   WARN err DSE accuracy 5.8107e-04.
# 17349   WARN err DSE accuracy 5.5207e-04.
# 17353   WARN err DSE accuracy 3.8045e-03.
# 17355   WARN err DSE accuracy 5.4925e-03.
# 17356   WARN err DSE accuracy 4.1971e-04.
# 17361   WARN err DSE accuracy 1.1661e-04.
# 17362   WARN err DSE accuracy 2.0904e-03.
# 17365   WARN err DSE accuracy 2.5711e-03.
# 17366   WARN err DSE accuracy 8.2739e-03.
# 17369   WARN err DSE accuracy 6.0125e-04.
# 17370   WARN err DSE accuracy 1.8554e-03.
# 17375   WARN err DSE accuracy 3.9536e-04.
# 17376   WARN err DSE accuracy 5.1987e-04.
# 17377   WARN err DSE accuracy 4.2081e-04.
# 17379   WARN err DSE accuracy 9.1186e-03.
# 17380   WARN err DSE accuracy 2.0608e-03.
# 17383   WARN err DSE accuracy 1.3320e-04.
# 17384   WARN err DSE accuracy 2.9501e-04.
# 17386   WARN err DSE accuracy 6.8859e-02.
# 17392   WARN err DSE accuracy 3.7910e-03.
# 17393   WARN err DSE accuracy 3.7894e-03.
# 17396   WARN err DSE accuracy 3.7895e-03.
# 17397   WARN err DSE accuracy 7.2945e-04.
# 17401   WARN err DSE accuracy 5.5874e-04.
# 17402   WARN err DSE accuracy 3.6616e-04.
# 17404   WARN err DSE accuracy 3.9979e-04.
# 17407   WARN err DSE accuracy 5.7924e-04.
# 17413   WARN err DSE accuracy 1.3011e-03.
# 17414   WARN err DSE accuracy 6.8691e-03.
# 17415   WARN err DSE accuracy 5.8109e-04.
# 17417   WARN err DSE accuracy 1.7014e-04.
# 17420   WARN err DSE accuracy 3.3240e-02.
# 17422   WARN err DSE accuracy 1.0894e-02.
# 17426   WARN err DSE accuracy 8.7945e-04.
# 17427   WARN err DSE accuracy 1.0393e-04.
# 17437   WARN err DSE accuracy 3.8457e-03.
# 17439   WARN err DSE accuracy 4.4169e-04.
# 17441   WARN err DSE accuracy 1.6145e-04.
# 17442   WARN err DSE accuracy 2.5095e-03.
# 17443   WARN err DSE accuracy 1.6409e-03.
# 17448   WARN err DSE accuracy 1.3659e-03.
# 17449   WARN err DSE accuracy 7.0170e-04.
# 17450   WARN err DSE accuracy 2.9535e-03.
# 17463   WARN err DSE accuracy 2.6398e-03.
# 17464   WARN err DSE accuracy 1.3295e-03.
# 17466   WARN err DSE accuracy 3.9679e-04.
# 17467   WARN err DSE accuracy 5.2285e-04.
# 17469   WARN err DSE accuracy 4.2081e-04.
# 17470   WARN err DSE accuracy 2.2541e-03.
# 17472   WARN err DSE accuracy 2.9611e-03.
# 17473   WARN err DSE accuracy 7.6531e-04.
# 17475   WARN err DSE accuracy 3.9875e-04.
# 17477   WARN err DSE accuracy 7.7760e-04.
# 17478   WARN err DSE accuracy 1.0191e-04.
# 17480   WARN err DSE accuracy 5.8620e-04.
# 17490   WARN err DSE accuracy 1.6585e-04.
# 17492   WARN err DSE accuracy 9.2610e-04.
# 17493   WARN err DSE accuracy 2.4853e-04.
# 17494   WARN err DSE accuracy 2.2296e-03.
# 17500   WARN err DSE accuracy 5.8852e-03.
# 17502   WARN err DSE accuracy 2.8333e-03.
# 17504   WARN err DSE accuracy 7.3365e-04.
# 17505   WARN err DSE accuracy 9.8924e-04.
# 17507   WARN err DSE accuracy 2.6530e-03.
# 17509   WARN err DSE accuracy 1.5543e-02.
# 17510   WARN err DSE accuracy 3.0639e-03.
# 17514   WARN err DSE accuracy 5.1562e-03.
# 17517   WARN err DSE accuracy 1.3930e-03.
# 17519   WARN err DSE accuracy 1.2450e-03.
# 17524   WARN err DSE accuracy 1.5484e-03.
# 17532   WARN err DSE accuracy 4.9633e-02.
# 17533   WARN err DSE accuracy 2.2302e-03.
# 17535   WARN err DSE accuracy 3.9674e-04.
# 17538   WARN err DSE accuracy 1.9961e-04.
# 17539   WARN err DSE accuracy 2.6477e-03.
# 17542   WARN err DSE accuracy 4.7079e-04.
# 17544   WARN err DSE accuracy 1.6873e-02.
# 17547   WARN err DSE accuracy 4.2989e-04.
# 17551   WARN err DSE accuracy 2.5184e-03.
# 17555   WARN err DSE accuracy 7.1716e-04.
# 17556   WARN err DSE accuracy 5.0511e-03.
# 17557   WARN err DSE accuracy 7.2638e-04.
# 17568   WARN err DSE accuracy 6.6640e-04.
# 17575   WARN err DSE accuracy 4.4584e-03.
# 17576   WARN err DSE accuracy 4.4685e-03.
# 17577   WARN err DSE accuracy 9.1298e-04.
# 17578   WARN err DSE accuracy 1.2237e-03.
# 17579   WARN err DSE accuracy 1.3311e-04.
# 17581   WARN err DSE accuracy 5.5986e-03.
# 17582   WARN err DSE accuracy 2.9572e-03.
# 17583   WARN err DSE accuracy 9.9864e-04.
# 17584   WARN err DSE accuracy 5.0138e-04.
# 17585   WARN err DSE accuracy 2.9187e-04.
# 17590   WARN err DSE accuracy 4.3536e-04.
# 17591   WARN err DSE accuracy 4.8362e-03.
# 17593   WARN err DSE accuracy 4.8042e-02.
# 17594   WARN err DSE accuracy 4.8044e-02.
# 17596   WARN err DSE accuracy 2.4193e-01.
# 17597   WARN err DSE accuracy 1.6144e-04.
# 17600   WARN err DSE accuracy 2.2092e-03.
# 17601   WARN err DSE accuracy 3.0597e-04.
# 17602   WARN err DSE accuracy 5.2027e-03.
# 17603   WARN err DSE accuracy 5.0107e-02.
# 17604   WARN err DSE accuracy 9.1301e-04.
# 17606   WARN err DSE accuracy 1.3709e-03.
# 17609   WARN err DSE accuracy 2.7361e-03.
# 17611   WARN err DSE accuracy 4.2668e-04.
# 17615   WARN err DSE accuracy 3.8119e-03.
# 17616   WARN err DSE accuracy 7.6493e-04.
# 17617   WARN err DSE accuracy 2.4574e-04.
# 17619   WARN err DSE accuracy 1.8549e-02.
# 17621   WARN err DSE accuracy 1.2872e-03.
# 17623   WARN err DSE accuracy 3.6727e-03.
# 17624   WARN err DSE accuracy 5.7542e-02.
# 17628   WARN err DSE accuracy 1.3709e-03.
# 17629   WARN err DSE accuracy 3.6609e-03.
# 17630   WARN err DSE accuracy 2.5089e-03.
# 17632   WARN err DSE accuracy 5.4915e-03.
# 17634   WARN err DSE accuracy 2.1882e-04.
# 17635   WARN err DSE accuracy 9.1145e-04.
# 17636   WARN err DSE accuracy 1.0357e-04.
# 17637   WARN err DSE accuracy 1.2809e-04.
# 17642   WARN err DSE accuracy 6.5004e-03.
# 17646   WARN err DSE accuracy 1.2383e-03.
# 17647   WARN err DSE accuracy 5.1292e-04.
# 17649   WARN err DSE accuracy 3.7917e-02.
# 17650   WARN err DSE accuracy 5.2523e-03.
# 17651   WARN err DSE accuracy 1.8553e-03.
# 17653   WARN err DSE accuracy 3.7646e-03.
# 17656   WARN err DSE accuracy 8.1638e-03.
# 17663   WARN err DSE accuracy 1.2040e-02.
# 17664   WARN err DSE accuracy 1.4968e-03.
# 17665   WARN err DSE accuracy 1.4207e-01.
# 17666   WARN err DSE accuracy 1.8595e-03.
# 17667   WARN err DSE accuracy 8.5183e-03.
# 17669   WARN err DSE accuracy 4.1144e-02.
# 17670   WARN err DSE accuracy 2.1407e-03.
# 17673   WARN err DSE accuracy 6.5784e-04.
# 17677   WARN err DSE accuracy 1.3866e-02.
# 17679   WARN err DSE accuracy 7.4261e-03.
# 17682   WARN err DSE accuracy 1.5539e-02.
# 17683   WARN err DSE accuracy 5.0870e-02.
# 17684   WARN err DSE accuracy 3.5745e-02.
# 17688   WARN err DSE accuracy 1.1633e-03.
# 17689   WARN err DSE accuracy 3.7915e-03.
# 17691   WARN err DSE accuracy 4.1133e-02.
# 17693   WARN err DSE accuracy 5.4536e-04.
# 17694   WARN err DSE accuracy 4.2638e-04.
# 17696   WARN err DSE accuracy 5.2529e-03.
# 17697   WARN err DSE accuracy 1.0648e-02.
# 17699   WARN err DSE accuracy 1.2718e-03.
# 17701   WARN err DSE accuracy 8.3844e-03.
# 17708   WARN err DSE accuracy 1.2651e-04.
# 17709   WARN err DSE accuracy 6.7220e-03.
# 17714   WARN err DSE accuracy 7.3395e-04.
# 17717   WARN err DSE accuracy 4.1261e-04.
# 17718   WARN err DSE accuracy 4.4440e-03.
# 17720   WARN err DSE accuracy 1.3922e-02.
# 17724   WARN err DSE accuracy 8.1708e-03.
# 17725   WARN err DSE accuracy 2.1570e-04.
# 17730   WARN err DSE accuracy 1.5125e-04.
# 17734   WARN err DSE accuracy 5.5182e-03.
# 17735   WARN err DSE accuracy 5.2046e-04.
# 17736   WARN err DSE accuracy 9.0394e-04.
# 17738   WARN err DSE accuracy 3.0725e-02.
# 17740   WARN err DSE accuracy 1.0373e-02.
# 17743   WARN err DSE accuracy 7.3496e-04.
# 17756   WARN err DSE accuracy 2.6860e-02.
# 17757   WARN err DSE accuracy 1.3869e-02.
# 17758   WARN err DSE accuracy 2.6597e-04.
# 17759   WARN err DSE accuracy 5.8850e-03.
# 17762   WARN err DSE accuracy 2.4797e-04.
# 17769   WARN err DSE accuracy 2.8862e-02.
# 17777   WARN err DSE accuracy 3.2578e-03.
# 17780   WARN err DSE accuracy 3.0729e-02.
# 17781   WARN err DSE accuracy 3.0082e-03.
# 17782   WARN err DSE accuracy 7.4095e-02.
# 17784   WARN err DSE accuracy 4.4543e-02.
# 17790   WARN err DSE accuracy 2.7487e-02.
# 17793   WARN err DSE accuracy 3.7725e-03.
# 17796   WARN err DSE accuracy 8.1630e-04.
# 17799   WARN err DSE accuracy 4.2482e-03.
# 17800   WARN err DSE accuracy 1.0147e-03.
# 17803   WARN err DSE accuracy 7.3362e-04.
# 17804   WARN err DSE accuracy 4.7990e-02.
# 17805   WARN err DSE accuracy 5.0356e-04.
# 17811   WARN err DSE accuracy 1.6785e-04.
# 17814   WARN err DSE accuracy 1.2299e-03.
# 17815   WARN err DSE accuracy 7.3481e-04.
# 17818   WARN err DSE accuracy 6.3953e-04.
# 17820   WARN err DSE accuracy 5.2524e-03.
# 17821   WARN err DSE accuracy 5.2526e-03.
# 17826   WARN err DSE accuracy 9.1592e-04.
# 17828   WARN err DSE accuracy 2.1223e-04.
# 17829   WARN err DSE accuracy 3.0068e-02.
# 17832   WARN err DSE accuracy 2.9959e-02.
# 17833   WARN err DSE accuracy 3.7498e-03.
# 17835   WARN err DSE accuracy 5.0037e-03.
# 17839   WARN err DSE accuracy 5.8492e-04.
# 17841   WARN err DSE accuracy 1.9472e-04.
# 17845   WARN err DSE accuracy 1.6859e-03.
# 17846   WARN err DSE accuracy 1.0139e-03.
# 17848   WARN err DSE accuracy 1.7437e-03.
# 17849   WARN err DSE accuracy 1.7458e-03.
# 17850   WARN err DSE accuracy 4.2242e-04.
# 17851   WARN err DSE accuracy 5.0801e-02.
# 17852   WARN err DSE accuracy 1.9981e-02.
# 17855   WARN err DSE accuracy 2.9964e-02.
# 17857   WARN err DSE accuracy 4.9373e-02.
# 17858   WARN err DSE accuracy 1.2299e-03.
# 17863   WARN err DSE accuracy 2.3558e-03.
# 17867   WARN err DSE accuracy 2.9967e-02.
# 17868   WARN err DSE accuracy 6.0155e-03.
# 17869   WARN err DSE accuracy 9.4541e-03.
# 17871   WARN err DSE accuracy 1.3027e-04.
# 17872   WARN err DSE accuracy 6.5954e-04.
# 17875   WARN err DSE accuracy 4.2054e-04.
# 17880   WARN err DSE accuracy 7.2480e-03.
# 17889   WARN err DSE accuracy 1.2297e-03.
# 17891   WARN err DSE accuracy 2.6833e-02.
# 17892   WARN err DSE accuracy 2.2574e-03.
# 17894   WARN err DSE accuracy 9.7258e-03.
# 17895   WARN err DSE accuracy 2.6441e-04.
# 17897   WARN err DSE accuracy 2.3077e-03.
# 17898   WARN err DSE accuracy 2.3459e-03.
# 17901   WARN err DSE accuracy 3.9678e-04.
# 17904   WARN err DSE accuracy 6.0138e-03.
# 17905   WARN err DSE accuracy 3.9693e-03.
# 17906   WARN err DSE accuracy 1.6306e-03.
# 17907   WARN err DSE accuracy 9.4920e-03.
# 17913   WARN err DSE accuracy 9.0528e-04.
# 17915   WARN err DSE accuracy 8.3837e-04.
# 17918   WARN err DSE accuracy 1.6013e-02.
# 17920   WARN err DSE accuracy 2.1254e-04.
# 17921   WARN err DSE accuracy 5.8135e-04.
# 17922   WARN err DSE accuracy 1.5975e-03.
# 17924   WARN err DSE accuracy 2.5173e-03.
# 17925   WARN err DSE accuracy 2.6634e-03.
# 17929   WARN err DSE accuracy 5.2770e-04.
# 17930   WARN err DSE accuracy 1.6310e-03.
# 17932   WARN err DSE accuracy 2.1372e-02.
# 17934   WARN err DSE accuracy 1.2381e-03.
# 17938   WARN err DSE accuracy 7.3512e-03.
# 17942   WARN err DSE accuracy 1.0952e-03.
# 17952   WARN err DSE accuracy 3.4175e-04.
# 17956   WARN err DSE accuracy 5.0106e-03.
# 17957   WARN err DSE accuracy 2.1055e-04.
# 17961   WARN err DSE accuracy 9.3433e-02.
# 17970   WARN err DSE accuracy 9.4557e-04.
# 17971   WARN err DSE accuracy 3.5746e-02.
# 17978   WARN err DSE accuracy 1.6080e-02.
# 17982   WARN err DSE accuracy 1.3992e-02.
# 17983   WARN err DSE accuracy 4.3281e-04.
# 17984   WARN err DSE accuracy 6.3195e-04.
# 17986   WARN err DSE accuracy 4.4728e-03.
# 17987   WARN err DSE accuracy 2.4196e-03.
# 17988   WARN err DSE accuracy 8.4532e-04.
# 17999   WARN err DSE accuracy 3.5733e-02.
# 18000   Obj Primal 1.1243e+07 Dual 1.1243e+07  Primal Inf 2.3621e+03 (1094)
# 18000   WARN err DSE accuracy 9.3668e-02.
# 18004   WARN err DSE accuracy 1.9513e-04.
# 18005   WARN err DSE accuracy 2.5563e-02.
# 18009   WARN err DSE accuracy 4.9631e-02.
# 18012   WARN err DSE accuracy 5.4950e-03.
# 18014   WARN err DSE accuracy 1.5464e-03.
# 18015   WARN err DSE accuracy 2.6832e-04.
# 18018   WARN err DSE accuracy 5.1558e-03.
# 18023   WARN err DSE accuracy 5.4579e-04.
# 18027   WARN err DSE accuracy 1.2885e-02.
# 18029   WARN err DSE accuracy 1.5458e-03.
# 18044   WARN err DSE accuracy 1.6002e-02.
# 18045   WARN err DSE accuracy 1.8611e-04.
# 18046   WARN err DSE accuracy 1.2215e-03.
# 18049   WARN err DSE accuracy 1.7960e-04.
# 18050   WARN err DSE accuracy 5.1074e-03.
# 18052   WARN err DSE accuracy 2.0130e-02.
# 18055   WARN err DSE accuracy 7.3513e-03.
# 18060   WARN err DSE accuracy 5.7472e-03.
# 18061   WARN err DSE accuracy 5.8349e-04.
# 18063   WARN err DSE accuracy 2.3092e-04.
# 18064   WARN err DSE accuracy 5.8511e-04.
# 18066   WARN err DSE accuracy 8.1236e-02.
# 18068   WARN err DSE accuracy 2.4242e-04.
# 18070   WARN err DSE accuracy 1.2674e-03.
# 18073   WARN err DSE accuracy 4.2957e-03.
# 18075   WARN err DSE accuracy 1.4021e-03.
# 18077   WARN err DSE accuracy 2.9377e-04.
# 18079   WARN err DSE accuracy 4.7405e-03.
# 18080   WARN err DSE accuracy 1.2902e-02.
# 18081   WARN err DSE accuracy 5.8167e-04.
# 18089   WARN err DSE accuracy 1.7107e-03.
# 18090   WARN err DSE accuracy 6.4877e-02.
# 18091   WARN err DSE accuracy 1.1935e-04.
# 18095   WARN err DSE accuracy 8.3599e-02.
# 18098   WARN err DSE accuracy 9.4840e-02.
# 18099   WARN err DSE accuracy 6.0912e-02.
# 18100   WARN err DSE accuracy 2.9338e-03.
# 18108   WARN err DSE accuracy 8.6871e-04.
# 18114   WARN err DSE accuracy 1.3751e-03.
# 18116   WARN err DSE accuracy 8.6260e-03.
# 18117   WARN err DSE accuracy 2.5120e-03.
# 18118   WARN err DSE accuracy 1.5542e-03.
# 18120   WARN err DSE accuracy 1.2155e-03.
# 18121   WARN err DSE accuracy 8.5214e-03.
# 18127   WARN err DSE accuracy 2.1253e-04.
# 18131   WARN err DSE accuracy 2.9270e-03.
# 18136   WARN err DSE accuracy 1.8467e-03.
# 18138   WARN err DSE accuracy 2.9717e-02.
# 18140   WARN err DSE accuracy 4.4684e-03.
# 18143   WARN err DSE accuracy 9.3664e-02.
# 18145   WARN err DSE accuracy 1.4206e-01.
# 18146   WARN err DSE accuracy 3.3060e-03.
# 18149   WARN err DSE accuracy 4.3452e-04.
# 18150   WARN err DSE accuracy 2.2851e-03.
# 18152   WARN err DSE accuracy 4.0267e-04.
# 18153   WARN err DSE accuracy 4.7406e-03.
# 18154   WARN err DSE accuracy 5.1658e-03.
# 18155   WARN err DSE accuracy 4.6228e-03.
# 18156   WARN err DSE accuracy 2.5227e-03.
# 18169   WARN err DSE accuracy 1.9855e-04.
# 18171   WARN err DSE accuracy 5.0322e-03.
# 18174   WARN err DSE accuracy 1.5518e-03.
# 18176   WARN err DSE accuracy 7.2119e-04.
# 18182   WARN err DSE accuracy 1.2725e-03.
# 18183   WARN err DSE accuracy 2.5701e-04.
# 18199   WARN err DSE accuracy 1.2669e-03.
# 18202   WARN err DSE accuracy 3.2184e-03.
# 18206   WARN err DSE accuracy 1.5411e-03.
# 18208   WARN err DSE accuracy 2.9731e-02.
# 18210   WARN err DSE accuracy 2.0703e-03.
# 18213   WARN err DSE accuracy 1.0129e-03.
# 18215   WARN err DSE accuracy 9.3697e-02.
# 18216   WARN err DSE accuracy 5.0485e-04.
# 18217   WARN err DSE accuracy 3.3889e-03.
# 18221   WARN err DSE accuracy 2.2226e-03.
# 18222   WARN err DSE accuracy 7.2767e-04.
# 18223   WARN err DSE accuracy 5.2647e-04.
# 18225   WARN err DSE accuracy 5.2241e-04.
# 18226   WARN err DSE accuracy 1.2238e-03.
# 18229   WARN err DSE accuracy 5.8097e-04.
# 18230   WARN err DSE accuracy 6.7542e-04.
# 18231   WARN err DSE accuracy 7.1992e-03.
# 18233   WARN err DSE accuracy 5.8628e-04.
# 18234   WARN err DSE accuracy 3.7714e-03.
# 18235   WARN err DSE accuracy 1.2711e-03.
# 18238   WARN err DSE accuracy 4.4911e-03.
# 18245   WARN err DSE accuracy 1.0170e-02.
# 18247   WARN err DSE accuracy 1.6169e-03.
# 18248   WARN err DSE accuracy 1.2908e-04.
# 18249   WARN err DSE accuracy 2.0605e-03.
# 18252   WARN err DSE accuracy 3.1955e-04.
# 18255   WARN err DSE accuracy 6.5262e-04.
# 18256   WARN err DSE accuracy 1.5606e-03.
# 18257   WARN err DSE accuracy 4.0574e-03.
# 18259   WARN err DSE accuracy 3.7566e-04.
# 18261   WARN err DSE accuracy 1.0639e-04.
# 18262   WARN err DSE accuracy 5.4682e-04.
# 18274   WARN err DSE accuracy 1.3541e-02.
# 18276   WARN err DSE accuracy 2.2500e-03.
# 18279   WARN err DSE accuracy 2.1142e-04.
# 18285   WARN err DSE accuracy 1.2297e-03.
# 18286   WARN err DSE accuracy 6.5964e-04.
# 18287   WARN err DSE accuracy 2.0702e-03.
# 18288   WARN err DSE accuracy 1.2821e-03.
# 18290   WARN err DSE accuracy 2.9119e-03.
# 18292   WARN err DSE accuracy 2.6478e-03.
# 18297   WARN err DSE accuracy 1.4066e-03.
# 18301   WARN err DSE accuracy 6.0446e-04.
# 18302   WARN err DSE accuracy 1.3660e-03.
# 18303   WARN err DSE accuracy 4.6529e-03.
# 18304   WARN err DSE accuracy 2.5127e-04.
# 18306   WARN err DSE accuracy 1.3541e-02.
# 18307   WARN err DSE accuracy 4.7407e-03.
# 18313   WARN err DSE accuracy 1.6170e-03.
# 18315   WARN err DSE accuracy 6.6947e-04.
# 18316   WARN err DSE accuracy 5.8249e-04.
# 18317   WARN err DSE accuracy 2.8099e-03.
# 18328   WARN err DSE accuracy 4.1135e-02.
# 18332   WARN err DSE accuracy 1.6519e-04.
# 18335   WARN err DSE accuracy 2.8028e-04.
# 18336   WARN err DSE accuracy 2.9417e-04.
# 18337   WARN err DSE accuracy 1.5011e-04.
# 18338   WARN err DSE accuracy 4.9598e-04.
# 18340   WARN err DSE accuracy 4.7945e-04.
# 18341   WARN err DSE accuracy 4.2929e-04.
# 18342   WARN err DSE accuracy 3.7667e-03.
# 18347   WARN err DSE accuracy 4.4262e-04.
# 18349   WARN err DSE accuracy 5.2526e-03.
# 18350   WARN err DSE accuracy 5.0007e-04.
# 18358   WARN err DSE accuracy 1.1693e-04.
# 18367   WARN err DSE accuracy 1.3080e-02.
# 18369   WARN err DSE accuracy 1.3956e-02.
# 18372   WARN err DSE accuracy 1.4519e-03.
# 18373   WARN err DSE accuracy 6.3511e-03.
# 18374   WARN err DSE accuracy 1.7442e-03.
# 18375   WARN err DSE accuracy 1.0184e-02.
# 18379   WARN err DSE accuracy 1.7931e-02.
# 18380   WARN err DSE accuracy 1.0984e-03.
# 18381   WARN err DSE accuracy 4.2243e-04.
# 18382   WARN err DSE accuracy 5.0135e-03.
# 18384   WARN err DSE accuracy 3.1149e-04.
# 18385   WARN err DSE accuracy 3.0372e-03.
# 18387   WARN err DSE accuracy 4.1789e-03.
# 18389   WARN err DSE accuracy 6.4218e-03.
# 18391   WARN err DSE accuracy 4.7407e-03.
# 18392   WARN err DSE accuracy 2.9734e-02.
# 18395   WARN err DSE accuracy 2.3703e-03.
# 18412   WARN err DSE accuracy 1.5555e-04.
# 18413   WARN err DSE accuracy 4.6324e-03.
# 18419   WARN err DSE accuracy 8.4597e-04.
# 18420   WARN err DSE accuracy 5.8465e-04.
# 18422   WARN err DSE accuracy 1.6013e-02.
# 18423   WARN err DSE accuracy 5.8650e-04.
# 18426   WARN err DSE accuracy 9.8988e-03.
# 18431   WARN err DSE accuracy 1.9904e-02.
# 18435   WARN err DSE accuracy 1.0654e-02.
# 18437   WARN err DSE accuracy 2.6968e-02.
# 18442   WARN err DSE accuracy 5.4950e-03.
# 18446   WARN err DSE accuracy 3.7668e-03.
# 18450   WARN err DSE accuracy 9.2481e-04.
# 18454   WARN err DSE accuracy 5.3137e-03.
# 18457   WARN err DSE accuracy 1.2143e-03.
# 18464   WARN err DSE accuracy 1.2756e-04.
# 18465   WARN err DSE accuracy 2.0637e-02.
# 18466   WARN err DSE accuracy 2.0249e-02.
# 18467   WARN err DSE accuracy 1.4227e-02.
# 18469   WARN err DSE accuracy 2.5898e-04.
# 18471   WARN err DSE accuracy 3.9808e-03.
# 18472   WARN err DSE accuracy 4.2665e-04.
# 18473   WARN err DSE accuracy 3.2334e-03.
# 18476   WARN err DSE accuracy 1.5416e-03.
# 18477   WARN err DSE accuracy 1.5416e-03.
# 18481   WARN err DSE accuracy 2.2307e-02.
# 18488   WARN err DSE accuracy 5.6632e-03.
# 18493   WARN err DSE accuracy 2.8735e-03.
# 18503   WARN err DSE accuracy 7.2162e-03.
# 18504   WARN err DSE accuracy 9.1154e-04.
# 18509   WARN err DSE accuracy 2.1350e-02.
# 18510   WARN err DSE accuracy 2.4531e-03.
# 18512   WARN err DSE accuracy 1.3311e-03.
# 18516   WARN err DSE accuracy 1.0466e-04.
# 18517   WARN err DSE accuracy 5.9130e-04.
# 18527   WARN err DSE accuracy 7.2080e-03.
# 18530   WARN err DSE accuracy 3.8645e-03.
# 18541   WARN err DSE accuracy 4.4475e-03.
# 18543   WARN err DSE accuracy 2.7096e-03.
# 18545   WARN err DSE accuracy 1.5964e-04.
# 18547   WARN err DSE accuracy 1.5411e-03.
# 18552   WARN err DSE accuracy 5.7467e-04.
# 18554   WARN err DSE accuracy 1.3414e-04.
# 18561   WARN err DSE accuracy 2.5057e-03.
# 18562   WARN err DSE accuracy 5.6200e-04.
# 18564   WARN err DSE accuracy 1.0226e-04.
# 18570   WARN err DSE accuracy 1.0764e-02.
# 18571   WARN err DSE accuracy 4.3992e-04.
# 18572   WARN err DSE accuracy 1.1409e-04.
# 18573   WARN err DSE accuracy 9.2482e-04.
# 18577   WARN err DSE accuracy 5.4983e-03.
# 18579   WARN err DSE accuracy 1.2700e-03.
# 18581   WARN err DSE accuracy 3.0067e-02.
# 18583   WARN err DSE accuracy 4.9403e-04.
# 18591   WARN err DSE accuracy 2.2287e-03.
# 18593   WARN err DSE accuracy 2.2199e-04.
# 18597   WARN err DSE accuracy 5.2776e-04.
# 18599   WARN err DSE accuracy 2.3219e-04.
# 18610   WARN err DSE accuracy 5.1741e-04.
# 18612   WARN err DSE accuracy 7.8895e-03.
# 18615   WARN err DSE accuracy 7.7585e-04.
# 18619   WARN err DSE accuracy 1.6610e-04.
# 18626   WARN err DSE accuracy 6.3751e-04.
# 18631   WARN err DSE accuracy 9.8845e-04.
# 18638   WARN err DSE accuracy 1.5412e-03.
# 18639   WARN err DSE accuracy 1.5588e-03.
# 18640   WARN err DSE accuracy 7.5589e-03.
# 18644   WARN err DSE accuracy 3.5689e-02.
# 18646   WARN err DSE accuracy 1.6000e-02.
# 18647   WARN err DSE accuracy 1.7198e-03.
# 18653   WARN err DSE accuracy 5.4305e-04.
# 18654   WARN err DSE accuracy 9.9014e-04.
# 18659   WARN err DSE accuracy 5.3764e-03.
# 18671   WARN err DSE accuracy 2.5711e-04.
# 18673   WARN err DSE accuracy 5.8828e-03.
# 18676   WARN err DSE accuracy 6.5939e-04.
# 18698   WARN err DSE accuracy 5.8153e-04.
# 18709   WARN err DSE accuracy 2.6620e-04.
# 18721   WARN err DSE accuracy 7.1077e-02.
# 18734   WARN err DSE accuracy 2.1757e-04.
# 18737   WARN err DSE accuracy 2.8113e-03.
# 18739   WARN err DSE accuracy 1.1248e-03.
# 18744   WARN err DSE accuracy 7.2493e-04.
# 18747   WARN err DSE accuracy 2.4268e-02.
# 18749   WARN err DSE accuracy 1.2680e-04.
# 18750   WARN err DSE accuracy 1.8605e-03.
# 18760   WARN err DSE accuracy 2.2538e-02.
# 18761   WARN err DSE accuracy 2.0358e-02.
# 18767   WARN err DSE accuracy 2.1342e-03.
# 18774   WARN err DSE accuracy 7.1070e-03.
# 18779   WARN err DSE accuracy 2.7299e-03.
# 18781   WARN err DSE accuracy 1.0653e-02.
# 18788   WARN err DSE accuracy 5.4952e-03.
# 18789   WARN err DSE accuracy 1.6479e-03.
# 18797   WARN err DSE accuracy 3.6921e-02.
# 18800   WARN err DSE accuracy 2.6221e-03.
# 18808   WARN err DSE accuracy 7.2059e-03.
# 18809   WARN err DSE accuracy 1.3091e-03.
# 18813   WARN err DSE accuracy 7.2733e-04.
# 18815   WARN err DSE accuracy 6.4053e-03.
# 18822   WARN err DSE accuracy 2.9171e-03.
# 18834   WARN err DSE accuracy 4.6075e-03.
# 18837   WARN err DSE accuracy 2.1354e-02.
# 18839   WARN err DSE accuracy 4.9631e-02.
# 18847   WARN err DSE accuracy 7.2210e-03.
# 18849   WARN err DSE accuracy 1.9899e-02.
# 18855   WARN err DSE accuracy 1.1602e-04.
# 18859   WARN err DSE accuracy 2.3731e-03.
# 18863   WARN err DSE accuracy 6.2148e-04.
# 18864   WARN err DSE accuracy 9.1725e-03.
# 18866   WARN err DSE accuracy 2.7124e-03.
# 18870   WARN err DSE accuracy 2.5282e-03.
# 18872   WARN err DSE accuracy 1.5369e-03.
# 18873   WARN err DSE accuracy 1.8707e-04.
# 18874   WARN err DSE accuracy 3.6724e-03.
# 18879   WARN err DSE accuracy 7.2080e-03.
# 18881   WARN err DSE accuracy 2.0722e-03.
# 18883   WARN err DSE accuracy 5.5661e-04.
# 18888   WARN err DSE accuracy 1.3124e-04.
# 18889   WARN err DSE accuracy 2.3055e-03.
# 18900   WARN err DSE accuracy 9.3662e-02.
# 18901   WARN err DSE accuracy 3.6925e-02.
# 18903   WARN err DSE accuracy 1.9471e-03.
# 18907   WARN err DSE accuracy 2.9989e-04.
# 18909   WARN err DSE accuracy 5.5152e-03.
# 18912   WARN err DSE accuracy 4.2139e-04.
# 18913   WARN err DSE accuracy 1.0653e-02.
# 18920   WARN err DSE accuracy 2.1748e-04.
# 18922   WARN err DSE accuracy 5.3005e-03.
# 18931   WARN err DSE accuracy 7.3609e-03.
# 18932   WARN err DSE accuracy 6.4220e-03.
# 18937   WARN err DSE accuracy 2.4691e-04.
# 18945   WARN err DSE accuracy 1.3238e-03.
# 18947   WARN err DSE accuracy 1.6523e-04.
# 18950   WARN err DSE accuracy 1.4967e-03.
# 18952   WARN err DSE accuracy 5.0034e-03.
# 18956   WARN err DSE accuracy 1.0937e-04.
# 18964   WARN err DSE accuracy 5.8262e-04.
# 18969   WARN err DSE accuracy 1.3080e-02.
# 18987   WARN err DSE accuracy 1.9302e-03.
# 18988   WARN err DSE accuracy 2.0270e-04.
# 18989   WARN err DSE accuracy 9.1153e-04.
# 18990   WARN err DSE accuracy 2.9417e-03.
# 18996   WARN err DSE accuracy 7.3509e-03.
# 18998   WARN err DSE accuracy 4.4518e-02.
# 19000   Obj Primal 1.1251e+07 Dual 1.1251e+07  Primal Inf 4.2535e+03 (1047)
# 19000   WARN err DSE accuracy 1.3099e-02.
# 19002   WARN err DSE accuracy 1.9535e-03.
# 19018   WARN err DSE accuracy 4.1700e-03.
# 19022   WARN err DSE accuracy 7.4759e-04.
# 19024   WARN err DSE accuracy 7.2001e-03.
# 19036   WARN err DSE accuracy 7.3376e-04.
# 19039   WARN err DSE accuracy 2.9572e-03.
# 19040   WARN err DSE accuracy 4.6266e-03.
# 19041   WARN err DSE accuracy 1.6751e-03.
# 19047   WARN err DSE accuracy 5.0221e-03.
# 19049   WARN err DSE accuracy 5.9437e-04.
# 19051   WARN err DSE accuracy 7.7504e-04.
# 19053   WARN err DSE accuracy 1.1708e-04.
# 19056   WARN err DSE accuracy 6.5922e-04.
# 19058   WARN err DSE accuracy 1.3670e-02.
# 19060   WARN err DSE accuracy 3.2255e-03.
# 19061   WARN err DSE accuracy 7.0060e-03.
# 19076   WARN err DSE accuracy 7.2090e-03.
# 19079   WARN err DSE accuracy 1.4966e-03.
# 19084   WARN err DSE accuracy 1.0282e-04.
# 19092   WARN err DSE accuracy 1.4576e-04.
# 19095   WARN err DSE accuracy 7.5676e-03.
# 19101   WARN err DSE accuracy 1.2512e-03.
# 19119   WARN err DSE accuracy 2.5939e-04.
# 19126   WARN err DSE accuracy 6.6626e-04.
# 19135   WARN err DSE accuracy 2.0124e-02.
# 19138   WARN err DSE accuracy 1.9908e-02.
# 19139   WARN err DSE accuracy 7.2583e-02.
# 19146   WARN err DSE accuracy 2.5170e-04.
# 19155   WARN err DSE accuracy 1.5464e-03.
# 19164   WARN err DSE accuracy 3.3499e-03.
# 19167   WARN err DSE accuracy 2.6768e-03.
# 19176   WARN err DSE accuracy 1.0296e-03.
# 19191   WARN err DSE accuracy 9.6867e-03.
# 19202   WARN err DSE accuracy 1.3781e-03.
# 19203   WARN err DSE accuracy 9.1471e-03.
# 19237   WARN err DSE accuracy 1.1350e-03.
# 19240   WARN err DSE accuracy 6.7309e-03.
# 19243   WARN err DSE accuracy 5.2970e-04.
# 19248   WARN err DSE accuracy 1.6267e-04.
# 19249   WARN err DSE accuracy 2.6242e-02.
# 19251   WARN err DSE accuracy 2.5614e-04.
# 19258   WARN err DSE accuracy 5.3996e-03.
# 19265   WARN err DSE accuracy 5.9761e-04.
# 19270   WARN err DSE accuracy 8.9240e-03.
# 19282   WARN err DSE accuracy 3.6632e-03.
# 19283   WARN err DSE accuracy 5.1960e-04.
# 19288   WARN err DSE accuracy 9.1149e-04.
# 19296   WARN err DSE accuracy 1.2236e-03.
# 19297   WARN err DSE accuracy 1.5025e-03.
# 19301   WARN err DSE accuracy 1.2420e-03.
# 19303   WARN err DSE accuracy 8.6479e-04.
# 19307   WARN err DSE accuracy 5.8534e-04.
# 19311   WARN err DSE accuracy 2.3586e-03.
# 19316   WARN err DSE accuracy 2.2590e-03.
# 19317   WARN err DSE accuracy 1.5585e-03.
# 19322   WARN err DSE accuracy 2.0129e-02.
# 19340   WARN err DSE accuracy 4.2918e-02.
# 19350   WARN err DSE accuracy 6.7070e-02.
# 19351   WARN err DSE accuracy 3.3109e-02.
# 19355   WARN err DSE accuracy 1.2594e-04.
# 19372   WARN err DSE accuracy 9.5313e-04.
# 19378   WARN err DSE accuracy 1.6187e-03.
# 19388   WARN err DSE accuracy 7.3483e-04.
# 19391   WARN err DSE accuracy 2.3650e-03.
# 19400   WARN err DSE accuracy 1.3433e-04.
# 19412   WARN err DSE accuracy 2.9418e-04.
# 19416   WARN err DSE accuracy 1.5313e-03.
# 19420   WARN err DSE accuracy 1.3023e-04.
# 19425   WARN err DSE accuracy 2.3238e-02.
# 19435   WARN err DSE accuracy 9.3668e-02.
# 19437   WARN err DSE accuracy 1.5323e-03.
# 19442   WARN err DSE accuracy 9.2603e-04.
# 19448   WARN err DSE accuracy 5.5028e-03.
# 19470   WARN err DSE accuracy 1.9907e-02.
# 19478   WARN err DSE accuracy 1.2002e-04.
# 19482   WARN err DSE accuracy 1.5416e-03.
# 19485   WARN err DSE accuracy 2.9653e-03.
# 19486   WARN err DSE accuracy 3.0672e-04.
# 19534   WARN err DSE accuracy 1.4963e-03.
# 19555   WARN err DSE accuracy 4.3532e-04.
# 19560   WARN err DSE accuracy 1.1072e-03.
# 19566   WARN err DSE accuracy 6.7569e-04.
# 19577   WARN err DSE accuracy 1.1027e-04.
# 19581   WARN err DSE accuracy 1.9258e-02.
# 19585   WARN err DSE accuracy 5.8627e-04.
# 19597   WARN err DSE accuracy 5.2203e-04.
# 19602   WARN err DSE accuracy 5.2047e-04.
# 19605   WARN err DSE accuracy 9.8913e-04.
# 19606   WARN err DSE accuracy 5.4528e-04.
# 19607   WARN err DSE accuracy 9.5313e-04.
# 19613   WARN err DSE accuracy 9.9552e-02.
# 19614   WARN err DSE accuracy 9.3291e-04.
# 19616   WARN err DSE accuracy 1.6170e-03.
# 19630   WARN err DSE accuracy 7.9621e-04.
# 19633   WARN err DSE accuracy 1.2672e-03.
# 19642   WARN err DSE accuracy 3.3503e-03.
# 19649   WARN err DSE accuracy 1.4969e-03.
# 19651   WARN err DSE accuracy 1.3015e-03.
# 19681   WARN err DSE accuracy 2.0865e-04.
# 19690   WARN err DSE accuracy 3.8928e-02.
# 19697   WARN err DSE accuracy 1.5027e-03.
# 19702   WARN err DSE accuracy 2.4569e-03.
# 19705   WARN err DSE accuracy 1.0078e-04.
# 19725   WARN err DSE accuracy 8.8178e-04.
# 19730   WARN err DSE accuracy 1.1057e-02.
# 19734   WARN err DSE accuracy 5.2075e-04.
# 19737   WARN err DSE accuracy 2.5137e-04.
# 19744   WARN err DSE accuracy 3.9985e-04.
# 19760   WARN err DSE accuracy 1.4186e-04.
# 19767   WARN err DSE accuracy 1.8016e-04.
# 19768   WARN err DSE accuracy 5.1887e-04.
# 19772   WARN err DSE accuracy 3.9519e-03.
# 19779   WARN err DSE accuracy 2.3564e-03.
# 19785   WARN err DSE accuracy 3.4176e-04.
# 19798   WARN err DSE accuracy 3.6348e-04.
# 19805   WARN err DSE accuracy 7.2523e-04.
# 19823   WARN err DSE accuracy 3.7738e-03.
# 19831   WARN err DSE accuracy 1.5402e-03.
# 19838   WARN err DSE accuracy 3.9875e-04.
# 19852   WARN err DSE accuracy 9.3424e-02.
# 19854   WARN err DSE accuracy 1.0651e-02.
# 19856   WARN err DSE accuracy 7.2763e-04.
# 19866   WARN err DSE accuracy 5.2555e-03.
# 19870   WARN err DSE accuracy 2.1123e-04.
# 19871   WARN err DSE accuracy 2.9694e-03.
# 19874   WARN err DSE accuracy 3.6155e-03.
# 19875   WARN err DSE accuracy 2.3231e-02.
# 19877   WARN err DSE accuracy 7.3497e-04.
# 19883   WARN err DSE accuracy 4.9858e-04.
# 19884   WARN err DSE accuracy 1.4043e-03.
# 19886   WARN err DSE accuracy 5.8219e-04.
# 19890   WARN err DSE accuracy 9.3667e-02.
# 19892   WARN err DSE accuracy 3.2827e-03.
# 19895   WARN err DSE accuracy 2.4254e-02.
# 19898   WARN err DSE accuracy 5.5124e-03.
# 19906   WARN err DSE accuracy 5.1616e-04.
# 19917   WARN err DSE accuracy 4.2682e-04.
# 19925   WARN err DSE accuracy 2.1831e-03.
# 19941   WARN err DSE accuracy 1.9306e-03.
# 19948   WARN err DSE accuracy 1.5051e-03.
# 19952   WARN err DSE accuracy 1.1029e-04.
# 19957   WARN err DSE accuracy 2.1911e-02.
# 19958   WARN err DSE accuracy 1.4450e-04.
# 19962   WARN err DSE accuracy -1.6355e-04.
# 19979   WARN err DSE accuracy 1.4039e-03.
# 19989   WARN err DSE accuracy 5.6331e-04.
# 19994   WARN err DSE accuracy 5.4527e-04.
# 19996   WARN err DSE accuracy -1.9413e-04.
# 20000   Obj Primal 1.1258e+07 Dual 1.1258e+07  Primal Inf 6.1663e+03 (986)
# resetting the DSE weights!
# 20732   WARN err DSE accuracy -1.7492e-04.
# 21000   Obj Primal 1.1262e+07 Dual 1.1262e+07  Primal Inf 5.8501e+03 (1133)
# 21154   WARN err DSE accuracy -1.0493e-04.
# 21159   WARN err DSE accuracy -1.2597e-04.
# 21203   WARN err DSE accuracy -1.1714e-04.
# 21204   WARN err DSE accuracy -1.2141e-04.
# 21206   WARN err DSE accuracy -1.1714e-04.
# 21244   WARN err DSE accuracy -1.9372e-04.
# 21254   WARN err DSE accuracy -1.1675e-04.
# 21291   WARN err DSE accuracy -1.4932e-04.
# 21292   WARN err DSE accuracy -1.2574e-04.
# 21404   WARN err DSE accuracy -1.1651e-04.
# 21407   WARN err DSE accuracy -1.6481e-04.
# 21408   WARN err DSE accuracy -1.2317e-04.
# 21481   WARN err DSE accuracy -1.6272e-04.
# 21494   WARN err DSE accuracy -1.2578e-04.
# 21507   WARN err DSE accuracy -1.1692e-04.
# 21518   WARN err DSE accuracy -1.2691e-04.
# 21609   WARN err DSE accuracy -1.0149e-04.
# 21630   WARN err DSE accuracy -1.1477e-04.
# 21648   WARN err DSE accuracy 1.3673e-04.
# 21654   WARN err DSE accuracy 1.4365e-04.
# 21690   WARN err DSE accuracy 1.3565e-04.
# 21693   WARN err DSE accuracy 1.5851e-04.
# 21773   WARN err DSE accuracy 2.6692e-04.
# 21774   WARN err DSE accuracy 1.5925e-04.
# 21779   WARN err DSE accuracy 1.4222e-04.
# 21789   WARN err DSE accuracy 5.1064e-04.
# 21802   WARN err DSE accuracy -1.1469e-04.
# 21822   WARN err DSE accuracy -1.0903e-04.
# 21834   WARN err DSE accuracy 1.3432e-04.
# 21853   WARN err DSE accuracy 1.3444e-04.
# 21898   WARN err DSE accuracy 4.7766e-04.
# 21908   WARN err DSE accuracy 2.8857e-04.
# 21919   WARN err DSE accuracy -1.4374e-04.
# 21923   WARN err DSE accuracy 5.3309e-04.
# 21926   WARN err DSE accuracy 3.3892e-04.
# 21935   WARN err DSE accuracy -1.1670e-04.
# 21942   WARN err DSE accuracy 1.7000e-04.
# 21959   WARN err DSE accuracy 4.7738e-04.
# 21974   WARN err DSE accuracy 4.2147e-04.
# 21994   WARN err DSE accuracy 5.7329e-04.
# 22000   Obj Primal 1.1265e+07 Dual 1.1265e+07  Primal Inf 6.0454e+03 (1029)
# 22035   WARN err DSE accuracy 1.6312e-04.
# 22066   WARN err DSE accuracy 1.9353e-04.
# 22092   WARN err DSE accuracy 2.3139e-03.
# 22098   WARN err DSE accuracy 2.8103e-04.
# 22100   WARN err DSE accuracy 2.7445e-04.
# 22106   WARN err DSE accuracy 2.1594e-04.
# 22121   WARN err DSE accuracy 1.1944e-04.
# 22122   WARN err DSE accuracy 1.8794e-04.
# 22129   WARN err DSE accuracy 1.0087e-04.
# 22131   WARN err DSE accuracy 6.3194e-04.
# 22139   WARN err DSE accuracy 1.6238e-03.
# 22140   WARN err DSE accuracy 2.7521e-04.
# 22141   WARN err DSE accuracy 1.7548e-04.
# 22142   WARN err DSE accuracy 2.1995e-04.
# 22148   WARN err DSE accuracy 1.7217e-04.
# 22151   WARN err DSE accuracy 1.7132e-03.
# 22156   WARN err DSE accuracy 8.4379e-04.
# 22157   WARN err DSE accuracy 5.8872e-03.
# 22158   WARN err DSE accuracy 5.3568e-03.
# 22160   WARN err DSE accuracy 9.2268e-04.
# 22162   WARN err DSE accuracy -1.7805e-04.
# 22165   WARN err DSE accuracy 2.7328e-04.
# 22166   WARN err DSE accuracy 1.0503e-03.
# 22175   WARN err DSE accuracy 1.0646e-04.
# 22178   WARN err DSE accuracy 4.0998e-04.
# 22184   WARN err DSE accuracy 1.4548e-03.
# 22185   WARN err DSE accuracy 1.5971e-04.
# 22186   WARN err DSE accuracy 5.2937e-04.
# 22188   WARN err DSE accuracy 3.5420e-04.
# 22189   WARN err DSE accuracy 3.5416e-04.
# 22190   WARN err DSE accuracy 2.0019e-04.
# 22193   WARN err DSE accuracy 3.8837e-04.
# 22194   WARN err DSE accuracy 1.0605e-03.
# 22195   WARN err DSE accuracy 2.4148e-04.
# 22197   WARN err DSE accuracy 2.7330e-04.
# 22198   WARN err DSE accuracy 7.3610e-04.
# ...
# 23386   WARN err DSE accuracy 6.2005e-02.
# 23388   WARN err DSE accuracy 7.8254e-03.
# 23390   WARN err DSE accuracy 1.1412e-01.
# 23408   WARN err DSE accuracy 6.8387e-04.
# 23412   WARN err DSE accuracy 1.7523e-03.
# 23416   WARN err DSE accuracy 1.1541e-04.
# 23431   WARN err DSE accuracy 7.4135e-03.
# 23444   WARN err DSE accuracy 1.6465e-04.
# 23445   WARN err DSE accuracy 1.8215e-02.
# 23450   WARN err DSE accuracy 1.2195e-02.
# 23452   WARN err DSE accuracy 1.0331e-03.
# 23457   WARN err DSE accuracy 4.5032e-04.
# 23460   WARN err DSE accuracy 5.0176e-04.
# 23468   WARN err DSE accuracy 1.9169e-04.
# 23475   WARN err DSE accuracy 2.4899e-03.
# 23484   WARN err DSE accuracy 8.9187e-04.
# 23487   WARN err DSE accuracy 1.3509e-02.
# 23489   WARN err DSE accuracy 5.8300e-03.
# 23492   WARN err DSE accuracy 1.8517e-03.
# 23494   WARN err DSE accuracy 5.8213e-03.
# 23503   WARN err DSE accuracy 1.1350e-04.
# 23504   WARN err DSE accuracy 2.0501e-04.
# 23515   WARN err DSE accuracy 4.0783e-03.
# 23519   WARN err DSE accuracy 2.0598e-01.
# 23524   WARN err DSE accuracy 9.1427e-02.
# 23545   WARN err DSE accuracy -1.7467e-04.
# 23547   WARN err DSE accuracy 1.3398e-04.
# 23550   WARN err DSE accuracy 5.6650e-04.
# 23551   WARN err DSE accuracy 2.1159e-03.
# 23552   WARN err DSE accuracy 4.0011e-03.
# 23555   WARN err DSE accuracy 1.1419e-04.
# 23564   WARN err DSE accuracy 2.3502e-04.
# 23565   WARN err DSE accuracy 2.8684e-04.
# 23570   WARN err DSE accuracy 5.1976e-02.
# 23577   WARN err DSE accuracy 8.1823e-03.
# 23580   WARN err DSE accuracy -2.1972e-04.
# 23582   WARN err DSE accuracy 1.3639e-04.
# 23584   WARN err DSE accuracy 7.5424e-04.
# 23595   WARN err DSE accuracy 1.2063e-04.
# 23598   WARN err DSE accuracy 1.1084e-01.
# 23605   WARN err DSE accuracy 1.8417e-03.
# 23613   WARN err DSE accuracy 9.0953e-03.
# 23619   WARN err DSE accuracy 2.0381e-03.
# 23627   WARN err DSE accuracy 4.4986e-02.
# 23638   WARN err DSE accuracy 1.3458e-04.
# 23648   WARN err DSE accuracy 1.0420e-02.
# 23649   WARN err DSE accuracy 4.4595e-04.
# 23657   WARN err DSE accuracy 8.2485e-04.
# 23658   WARN err DSE accuracy 7.6976e-03.
# 23668   WARN err DSE accuracy 7.7858e-04.
# 23669   WARN err DSE accuracy -1.3707e-04.
# 23675   WARN err DSE accuracy 7.5255e-04.
# 23682   WARN err DSE accuracy 1.2586e-04.
# 23691   WARN err DSE accuracy 3.3928e-02.
# 23694   WARN err DSE accuracy 7.8678e-04.
# 23706   WARN err DSE accuracy 7.3772e-04.
# 23722   WARN err DSE accuracy -1.4627e-04.
# 23723   WARN err DSE accuracy 1.7034e-03.
# 23729   WARN err DSE accuracy 1.8417e-03.
# 23737   WARN err DSE accuracy 5.2354e-03.
# 23745   WARN err DSE accuracy 8.6493e-04.
# 23747   WARN err DSE accuracy 2.4340e-03.
# 23749   WARN err DSE accuracy 5.0200e-04.
# 23752   WARN err DSE accuracy 7.0514e-03.
# 23756   WARN err DSE accuracy 1.5079e-01.
# 23760   WARN err DSE accuracy 1.2233e-02.
# 23774   WARN err DSE accuracy 7.5387e-04.
# 23786   WARN err DSE accuracy 7.5673e-04.
# 23794   WARN err DSE accuracy 1.0741e-03.
# 23816   WARN err DSE accuracy 2.7705e-04.
# 23822   WARN err DSE accuracy 4.9416e-04.
# 23903   WARN err DSE accuracy 1.3356e-04.
# 23918   Obj Primal 1.1266e+07 Dual 1.1266e+07
# Eval: con inf=5.6491e-08,var inf=9.3724e-08,obj=1.1266e+07. Status: SolveStatus.OPT. Elapsed time: 118.846.
#
# Problem name: FIT1P, size:((627, 1677),9868).
# Eval: con inf=1.9123e-04,var inf=0.0000e+00,obj=9.1464e+03. Status: 1. Elapsed time: 0.162.
#
# 872   Obj Primal 9.1464e+03 Dual 9.1464e+03
# Eval: con inf=1.2612e-08,var inf=0.0000e+00,obj=9.1464e+03. Status: SolveStatus.OPT. Elapsed time: 0.585.
#
# Problem name: GROW15, size:((300, 645),5620).
# Eval: con inf=4.5275e-01,var inf=3.8815e-10,obj=-1.0687e+08. Status: 1. Elapsed time: 0.075.
#
# 1000   Obj Primal -1.0762e+08 Dual -1.0762e+08  Primal Inf 4.8591e+07 (147)
# 2000   Obj Primal -1.0687e+08 Dual -1.0687e+08  Primal Inf 1.6404e+07 (67)
# 2218   Obj Primal -1.0687e+08 Dual -1.0687e+08
# Eval: con inf=2.0161e-06,var inf=0.0000e+00,obj=-1.0687e+08. Status: SolveStatus.OPT. Elapsed time: 1.527.
#
# Problem name: GROW22, size:((440, 946),8252).
# Eval: con inf=5.6737e-01,var inf=2.2941e-09,obj=-1.6083e+08. Status: 1. Elapsed time: 0.117.
#
# 1000   Obj Primal -1.6541e+08 Dual -1.6541e+08  Primal Inf 1.5522e+08 (330)
# 2000   Obj Primal -1.6261e+08 Dual -1.6261e+08  Primal Inf 1.4905e+09 (293)
# 3000   Obj Primal -1.6084e+08 Dual -1.6084e+08  Primal Inf 1.7939e+08 (278)
# 4000   Obj Primal -1.6083e+08 Dual -1.6083e+08  Primal Inf 3.1140e+06 (50)
# 4169   Obj Primal -1.6083e+08 Dual -1.6083e+08
# Eval: con inf=9.6480e-06,var inf=0.0000e+00,obj=-1.6083e+08. Status: SolveStatus.OPT. Elapsed time: 3.470.
#
# Problem name: GROW7, size:((140, 301),2612).
# Eval: con inf=2.0063e-01,var inf=2.9632e-10,obj=-4.7788e+07. Status: 1. Elapsed time: 0.050.
#
# 807   Obj Primal -4.7788e+07 Dual -4.7788e+07
# Eval: con inf=2.1473e-07,var inf=0.0000e+00,obj=-4.7788e+07. Status: SolveStatus.OPT. Elapsed time: 0.447.
#
# Problem name: KEN-07, size:((2426, 3602),8404).
# Eval: con inf=0.0000e+00,var inf=0.0000e+00,obj=-6.7952e+08. Status: 1. Elapsed time: 0.234.
#
# 1000   Obj Primal -8.5264e+08 Dual -8.5264e+08  Primal Inf 3.0022e+04 (1359)
# 2000   Obj Primal -7.3545e+08 Dual -7.3545e+08  Primal Inf 1.4604e+04 (886)
# 2927   Obj Primal -6.7952e+08 Dual -6.7952e+08
# Eval: con inf=4.1176e-12,var inf=2.2027e-13,obj=-6.7952e+08. Status: SolveStatus.OPT. Elapsed time: 2.922.
#
# Problem name: KEN-11, size:((14694, 21349),49058).
# Eval: con inf=0.0000e+00,var inf=0.0000e+00,obj=-6.9724e+09. Status: 1. Elapsed time: 1.541.
#
# 1000   Obj Primal -7.1731e+11 Dual -7.1731e+11  Primal Inf 1.7660e+08 (10943)
# 2000   Obj Primal -3.6347e+11 Dual -3.6347e+11  Primal Inf 9.6120e+07 (10089)
# 3000   Obj Primal -1.1156e+10 Dual -1.1156e+10  Primal Inf 9.5689e+05 (9056)
# 4000   Obj Primal -9.0200e+09 Dual -9.0200e+09  Primal Inf 6.1492e+05 (8293)
# 5000   Obj Primal -8.4766e+09 Dual -8.4766e+09  Primal Inf 2.5478e+05 (6644)
# resetting the DSE weights!
# 6000   Obj Primal -8.1934e+09 Dual -8.1934e+09  Primal Inf 1.9828e+05 (6112)
# 7000   Obj Primal -8.0519e+09 Dual -8.0519e+09  Primal Inf 1.7798e+05 (5615)
# 8000   Obj Primal -7.9060e+09 Dual -7.9060e+09  Primal Inf 1.5950e+05 (5366)
# 9000   Obj Primal -7.7871e+09 Dual -7.7871e+09  Primal Inf 1.5042e+05 (5118)
# 10000   Obj Primal -7.6802e+09 Dual -7.6802e+09  Primal Inf 1.4073e+05 (4761)
# resetting the DSE weights!
# 11000   Obj Primal -7.5804e+09 Dual -7.5804e+09  Primal Inf 1.3181e+05 (4431)
# 12000   Obj Primal -7.4592e+09 Dual -7.4592e+09  Primal Inf 1.0396e+05 (3789)
# 13000   Obj Primal -7.3367e+09 Dual -7.3367e+09  Primal Inf 8.3641e+04 (3164)
# 14000   Obj Primal -7.2048e+09 Dual -7.2048e+09  Primal Inf 6.5581e+04 (2651)
# 15000   Obj Primal -7.0888e+09 Dual -7.0888e+09  Primal Inf 4.0884e+04 (2062)
# resetting the DSE weights!
# 16000   Obj Primal -7.0019e+09 Dual -7.0019e+09  Primal Inf 2.1256e+04 (1330)
# 17000   Obj Primal -6.9737e+09 Dual -6.9737e+09  Primal Inf 9.0000e+02 (256)
# 17273   Obj Primal -6.9724e+09 Dual -6.9724e+09
# Eval: con inf=1.3104e-10,var inf=1.0509e-11,obj=-6.9724e+09. Status: SolveStatus.OPT. Elapsed time: 127.691.
#
# Problem name: MODSZK1, size:((687, 1620),3168).
# Eval: con inf=4.1902e-03,var inf=3.4025e+05,obj=5.9454e+05. Status: -1. Elapsed time: 0.337.
#
# 1   Obj Primal 0.0000e+00 Dual 0.0000e+00  Primal Inf 1.0464e+06 (16)
# Eval: con inf=1.0464e+06,var inf=0.0000e+00,obj=0.0000e+00. Status: SolveStatus.PRIMAL_INFEAS. Elapsed time: 0.007.
#
# Problem name: QAP12, size:((3192, 8856),38304).
# Eval: con inf=3.7434e-06,var inf=3.0478e-09,obj=5.2289e+02. Status: 1. Elapsed time: 76.948.
#
# 1000   Obj Primal 6.7500e+01 Dual 6.7500e+01  Primal Inf 2.9894e+04 (881)
# 1548   WARN err DSE accuracy 3.8993e-04.
# 1611   WARN err DSE accuracy 1.3456e-04.
# 1621   WARN err DSE accuracy 3.1143e-04.
# 1641   WARN err DSE accuracy 1.3129e-03.
# 1682   WARN err DSE accuracy 2.8643e-04.
# 1685   WARN err DSE accuracy 6.1670e-04.
# 1686   WARN err DSE accuracy 1.6888e-03.
# 1688   WARN err DSE accuracy 2.0337e-04.
# 1693   WARN err DSE accuracy 5.0484e-04.
# 1702   WARN err DSE accuracy 3.7703e-03.
# 1703   WARN err DSE accuracy 9.1477e-04.
# 1705   WARN err DSE accuracy 3.2861e-04.
# 1714   WARN err DSE accuracy 2.7781e-02.
# 1722   WARN err DSE accuracy 2.1572e-03.
# 1731   WARN err DSE accuracy 1.0687e-03.
# 1733   WARN err DSE accuracy 1.8328e-04.
# 1769   WARN err DSE accuracy 1.0737e-03.
# 1773   WARN err DSE accuracy 1.0695e-03.
# 1789   WARN err DSE accuracy 1.4394e-03.
# 1790   WARN err DSE accuracy 7.2676e-03.
# 1793   WARN err DSE accuracy 2.0807e-03.
# 1794   WARN err DSE accuracy 4.6651e-03.
# 1795   WARN err DSE accuracy 2.1086e-03.
# 1796   WARN err DSE accuracy 1.3172e-02.
# 1799   WARN err DSE accuracy 2.2122e-02.
# 1800   WARN err DSE accuracy 1.6479e-03.
# 1810   WARN err DSE accuracy 2.1720e-03.
# 1846   WARN err DSE accuracy 1.6658e-03.
# 1848   WARN err DSE accuracy 1.6652e-03.
# 1856   WARN err DSE accuracy 1.0693e-03.
# 1900   WARN err DSE accuracy 4.1091e-04.
# 1909   WARN err DSE accuracy 1.6630e-03.
# 1910   WARN err DSE accuracy 1.3295e-02.
# 1911   WARN err DSE accuracy 2.8737e-04.
# 1915   WARN err DSE accuracy 4.9811e-03.
# 1916   WARN err DSE accuracy 2.5412e-02.
# 1920   WARN err DSE accuracy 1.4759e-03.
# 1921   WARN err DSE accuracy 3.1254e-02.
# 1923   WARN err DSE accuracy 2.0650e-03.
# 1924   WARN err DSE accuracy 2.6386e-03.
# 1925   WARN err DSE accuracy 1.0602e-02.
# 1927   WARN err DSE accuracy 2.1452e-03.
# 1931   WARN err DSE accuracy 6.4966e-03.
# 1934   WARN err DSE accuracy 1.1249e-03.
# 1945   WARN err DSE accuracy 1.0514e-02.
# 1948   WARN err DSE accuracy 1.4627e-04.
# 1949   WARN err DSE accuracy -1.8350e-04.
# 1953   WARN err DSE accuracy 1.6653e-03.
# 1960   WARN err DSE accuracy 1.5972e-04.
# 1966   WARN err DSE accuracy 1.2077e-04.
# 1969   WARN err DSE accuracy 1.5982e-02.
# 1974   WARN err DSE accuracy 5.7262e-03.
# 1975   WARN err DSE accuracy 3.4085e-04.
# 1980   WARN err DSE accuracy 7.7946e-04.
# 1999   WARN err DSE accuracy 6.1720e-04.
# 2000   Obj Primal 6.7500e+01 Dual 6.7500e+01  Primal Inf 4.1749e+05 (1259)
# /Users/hanqiu/anaconda3/lib/python3.6/site-packages/scikits/umfpack/umfpack.py:563: UmfpackWarning: Singular matrix
#   warnings.warn('Singular matrix', UmfpackWarning)
# /Users/hanqiu/anaconda3/lib/python3.6/site-packages/scikits/umfpack/umfpack.py:712: UmfpackWarning: Zeroing nan and inf entries...
#   warnings.warn('Zeroing nan and inf entries...', UmfpackWarning)
# /Users/hanqiu/anaconda3/lib/python3.6/site-packages/scikits/umfpack/umfpack.py:717: RuntimeWarning: divide by zero encountered in double_scalars
#   econd = 1.0 / self.info[UMFPACK_RCOND]
# /Users/hanqiu/anaconda3/lib/python3.6/site-packages/scikits/umfpack/umfpack.py:721: UmfpackWarning: (almost) singular matrix! (estimated cond. number: inf)
#   warnings.warn(msg, UmfpackWarning)
# /Users/hanqiu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:100: RuntimeWarning: divide by zero encountered in double_scalars
# /Users/hanqiu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:101: RuntimeWarning: invalid value encountered in multiply
# /Users/hanqiu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:113: RuntimeWarning: invalid value encountered in true_divide
# /Users/hanqiu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:114: RuntimeWarning: divide by zero encountered in double_scalars
# /Users/hanqiu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:134: RuntimeWarning: divide by zero encountered in double_scalars
# /Users/hanqiu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:135: RuntimeWarning: invalid value encountered in multiply
# /Users/hanqiu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:135: RuntimeWarning: divide by zero encountered in double_scalars
# /Users/hanqiu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:10: RuntimeWarning: invalid value encountered in greater
#   # Remove the CWD from sys.path while we load stuff.
# /Users/hanqiu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: RuntimeWarning: invalid value encountered in less
#   # This is added back by InteractiveShellApp.init_path()
# /Users/hanqiu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:19: RuntimeWarning: invalid value encountered in true_divide
# /Users/hanqiu/dual_simplex_solve/util_lec_2.py:157: RuntimeWarning: invalid value encountered in greater
#   primal_inf_cnt = np.sum((primal_inf > self.primal_upper_bound_tol) | \
# /Users/hanqiu/dual_simplex_solve/util_lec_2.py:158: RuntimeWarning: invalid value encountered in less
#   (primal_inf < self.primal_lower_bound_tol))
# /Users/hanqiu/dual_simplex_solve/util_lec_2.py:172: RuntimeWarning: invalid value encountered in greater
#   con_inf_cnt = np.sum(np.abs(primal_con_inf) > CON_TOL) + np.sum(np.abs(dual_con_inf) > CON_TOL)
# /Users/hanqiu/dual_simplex_solve/util.py:207: RuntimeWarning: invalid value encountered in greater_equal
#   return ( np.sum(err[(err >= 0) & (self.sense <= 0)]) - \
# /Users/hanqiu/dual_simplex_solve/util.py:208: RuntimeWarning: invalid value encountered in less_equal
#   np.sum(err[(err <= 0) & (self.sense >= 0)]) )
# 2086   WARN err FTRAN/BTRAN pivot consistency -1.0000e+00.
# 2088   Obj Primal nan Dual 6.7500e+01  Primal Inf nan (1)  Con Inf nan (1)
# Eval: con inf=0.0000e+00,var inf=nan,obj=nan. Status: SolveStatus.PRIMAL_INFEAS. Elapsed time: 4.045.
#
# Problem name: QAP8, size:((912, 1632),7296).
# Eval: con inf=2.2323e-10,var inf=3.3529e-11,obj=2.0350e+02. Status: 1. Elapsed time: 0.748.
# /Users/hanqiu/anaconda3/lib/python3.6/site-packages/scikits/umfpack/umfpack.py:721: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 7.61e+16)
#   warnings.warn(msg, UmfpackWarning)
# 580   WARN err DSE accuracy -3.3283e+06.
# 586   WARN err DSE accuracy 2.4933e+01.
# 587   WARN err DSE accuracy -4.1321e+01.
# 589   WARN err DSE accuracy 2.9012e+02.
# 590   WARN err FTRAN/BTRAN pivot consistency 2.0068e+00.
# 590   WARN err DSE accuracy 4.7616e+01.
# 591   WARN err DSE accuracy 3.5245e+03.
# 592   WARN err FTRAN/BTRAN pivot consistency -5.8647e+00.
# 592   WARN err DSE accuracy 3.7629e+03.
# 593   WARN err DSE accuracy 1.4699e+04.
# 598   WARN err DSE accuracy -3.8176e+02.
# 599   WARN err FTRAN/BTRAN pivot consistency -6.5876e+01.
# 599   WARN err DSE accuracy 6.5005e+04.
# 601   Obj Primal 6.4000e+02 Dual 7.2000e+01  Primal Inf 3.5616e+19 (597)  Con Inf 1.7706e+04 (324)
# Eval: con inf=1.8629e+19,var inf=1.5805e+19,obj=6.4000e+02. Status: SolveStatus.PRIMAL_INFEAS. Elapsed time: 0.416.
#
# Problem name: SCSD1, size:((77, 760),2388).
# Eval: con inf=1.9562e-08,var inf=0.0000e+00,obj=8.6667e+00. Status: 1. Elapsed time: 0.043.
#
# 119   Obj Primal 8.6667e+00 Dual 8.6667e+00
# Eval: con inf=5.8984e-10,var inf=1.5675e-10,obj=8.6667e+00. Status: SolveStatus.OPT. Elapsed time: 0.053.
#
# Problem name: SCSD6, size:((147, 1350),4316).
# Eval: con inf=1.0431e-07,var inf=0.0000e+00,obj=5.0500e+01. Status: 1. Elapsed time: 0.072.
#
# 280   Obj Primal 5.0500e+01 Dual 5.0500e+01
# Eval: con inf=1.5659e-09,var inf=5.3490e-10,obj=5.0500e+01. Status: SolveStatus.OPT. Elapsed time: 0.140.
#
# Problem name: SCSD8, size:((397, 2750),8584).
# Eval: con inf=5.8315e-06,var inf=0.0000e+00,obj=9.0500e+02. Status: 1. Elapsed time: 0.201.
#
# 1000   Obj Primal 9.0395e+02 Dual 9.0395e+02  Primal Inf 1.7871e+02 (95)
# 1075   Obj Primal 9.0500e+02 Dual 9.0500e+02
# Eval: con inf=2.3785e-09,var inf=8.2518e-10,obj=9.0500e+02. Status: SolveStatus.OPT. Elapsed time: 0.691.
#
# Problem name: TRUSS, size:((1000, 8806),27836).
# Eval: con inf=2.8473e-04,var inf=0.0000e+00,obj=4.5882e+05. Status: 1. Elapsed time: 4.335.
#
# 680   WARN err FTRAN/BTRAN pivot consistency -1.2645e-01.
# 680   WARN err DSE accuracy -9.5956e+02.
# 683   Obj Primal nan Dual -3.8461e+06  Con Inf nan (3)
# Eval: con inf=3.2800e+01,var inf=nan,obj=nan. Status: SolveStatus.OPT. Elapsed time: 0.538.
# /Users/hanqiu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:113: RuntimeWarning: divide by zero encountered in true_divide
# /Users/hanqiu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:135: RuntimeWarning: invalid value encountered in subtract
# /Users/hanqiu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:107: RuntimeWarning: invalid value encountered in multiply

# %% [markdown]
# 根据上面的测试结果可以看出，在优化线性代数相关计算后，DS算法的速度显著上升，因此我们可以求解更大规模的问题。然而，迭代步中的校核显示，这些优化可能会引发更多的数值问题，从而导致计算结果不准确或者计算过程出错。在本系列的后续文章/代码中，我将进一步介绍解决这些新问题的方法。
